# %%
import os
import pandas as pd

import subprocess

from run_WBM import run_WBM

# %%
# Read all climate drivers 
df_climate_drivers = pd.read_csv("../utils/climate_drivers.csv")

# %%
for _, row in df_climate_drivers.iterrows():
    if row['ensemble'] == "OakRidge":
        sim_ID = f"{row['ensemble']}_{row['model']}_{row['member']}_{row['method']}_{row['ssp']}"
        sim_path = main_path + sim_ID
    else:
        sim_ID = f"{row['ensemble']}_{row['model']}_{row['member']}_{row['ssp']}"
        sim_path = main_path + sim_ID
    check_spool_out = subprocess.run(
            ["tail", "-n", "5", f"{sim_path}/spool_WBM.out"],
            capture_output=True,
            text=True,
        ).stdout.split("\n")
    if len(check_spool_out) > 5:
        check_spool_out = check_spool_out[-4]
    if check_spool_out == "All Done!":
            subprocess.run(["touch", f"{sim_path}/spool_done.out"])

# %%
for _, row in df_climate_drivers.iterrows():
    if row['ensemble'] == "OakRidge":
        sim_ID = f"{row['ensemble']}_{row['model']}_{row['member']}_{row['method']}_{row['ssp']}"
        sim_path = main_path + sim_ID
    else:
        sim_ID = f"{row['ensemble']}_{row['model']}_{row['member']}_{row['ssp']}"
        sim_path = main_path + sim_ID
    check_spool_out = subprocess.run(
            ["tail", "-n", "5", f"{sim_path}/spool_WBM.out"],
            capture_output=True,
            text=True,
        ).stdout.split("\n")
    if len(check_spool_out) > 5:
        check_spool_out = check_spool_out[-4]
    if check_spool_out == "All Done!":
            # print('done')
            subprocess.run(["touch", f"{sim_path}/spool_done.out"])

# %%
for _, row in df_climate_drivers.iterrows():
    if row['ensemble'] == "OakRidge":
        sim_ID = f"{row['ensemble']}_{row['model']}_{row['member']}_{row['method']}_{row['ssp']}"
        sim_path = main_path + sim_ID
    else:
        sim_ID = f"{row['ensemble']}_{row['model']}_{row['member']}_{row['ssp']}"
        sim_path = main_path + sim_ID
    check_job_out = subprocess.run(
                ["tail", "-n", "100", f"{sim_path}/run_WBM.out"],
                capture_output=True, text=True,
            ).stdout.split("\n")
    if len(check_job_out) < 100:
        pass
    else:
        check_message = "* INFO: WBM model runs completed with exit code"
        check_job_out = [line for line in check_job_out if check_message in line]
        if len(check_job_out) > 0 and check_job_out[0][-1] == "0":
                    # print(sim_ID)
                    subprocess.run(["touch", f"{sim_path}/run_done.out"])

# %%
######################
# Common to all runs #
######################

# Main directory
main_path = "/gpfs/group/kaf26/default/dcl5300/wbm_soilM_crop_uc_lafferty-etal-2024-tbd_DATA/wbm/"

# Output variables
output_vars=["soilMoist", "soilMoistFrac"]

# PET method
pet_method = "Hamon"

# Rooting depth
rootingDepth = "Effective_Rooting_Depth_mod.init"

# Available water capacity
# soilAWC = "/gpfs/group/kaf26/default/private/WBM_data/squam.sr.unh.edu/US_CDL_v3_data/soil/SSURGO_SoilData_awc_frac_mm_m_CONUS_1km.tif"
soilAWC = "SSURGO_HARMON_AWC_05min_NAM_US.init"

# Canopy height
canopyHt = "/gpfs/group/kaf26/default/private/WBM_data/squam.sr.unh.edu/US_CDL_v3_data/canopy/Simard_Pinto_3DGlobalVeg_JGR_10km.tif"

# Leaf Area Index
lai = "merra2_lai2_dc.init"

# Lan collapse method
land_collapse="average"

# Project ID
project_ID = "PCHES_crop_yield_UC_climate_param"

# %% [markdown]
# # Historical runs (observational data)

# %%
#######################
# Common to hist runs #
#######################

# Simulation length
run_start="1980-01-01"
run_end="2014-12-31"

# Spinup
spinup_start="1980-01-01"
spinup_end="1980-12-31"
spinup_loops = 5

# Cloud fraction
cloudFr_primary = "merra2_cldtot_d.init"

# Crop parameter file
crop_par = "CDL-US-M_CropParameters_hist.csv"

# Crop area timeseries
crop_area_frac="cdl_cropland_hist.init"

# %%
########
# GMFD #
########
run_WBM(
    run_type="obs",
    main_path=main_path,
    sim_ID="OBS_GMFD_historical",
    model_info={},
    project_ID=project_ID,
    
    
    run_start=run_start,
    run_end=run_end,
    spinup_start=spinup_start,
    spinup_end=spinup_end,
    spinup_loops=spinup_loops,
    output_vars=output_vars,
    pet_method=pet_method,
    airT_primary="GMFD_tas_daily.init",
    airT_secondary="",
    airT_min="",
    airT_max="",
    precip_primary="GMFD_prcp_daily.init",
    precip_secondary="",
    cloudFr_primary=cloudFr_primary,
    windU_primary="",
    windV_primary="",
    humidity_primary="",
    albedo_primary="",
    rootingDepth=rootingDepth,
    soilAWC=soilAWC,
    canopyHt=canopyHt,
    lai=lai,
    land_collapse=land_collapse,
    crop_area_frac=crop_area_frac,
    crop_area_frac_patch="",
    crop_par=crop_par,
    crop_par_patch=""
)
# Out:
# check jobid: 44106071
# spool jobid: 44106096
# run jobid: 44106098

# %%
###########
# Livneh2 #
###########
run_WBM(
    run_type="obs",
    main_path=main_path,
    sim_ID="OBS_Livneh2_historical",
    model_info={},
    project_ID=project_ID,
    
    
    run_start=run_start,
    run_end=run_end,
    spinup_start=spinup_start,
    spinup_end=spinup_end,
    spinup_loops=spinup_loops,
    output_vars=output_vars,
    pet_method=pet_method,
    airT_primary="XXX",
    airT_secondary="XXX",
    airT_min="Livneh2_Tmax_daily.init",
    airT_max="Livneh2_Tmin_daily.init",
    precip_primary="Livneh2_precip_daily.init",
    precip_secondary="",
    cloudFr_primary=cloudFr_primary,
    windU_primary="",
    windV_primary="",
    humidity_primary="",
    albedo_primary="",
    rootingDepth=rootingDepth,
    soilAWC=soilAWC,
    canopyHt=canopyHt,
    lai=lai,
    land_collapse=land_collapse,
    crop_area_frac=crop_area_frac,
    crop_area_frac_patch="",
    crop_par=crop_par,
    crop_par_patch="",
    
)
# Out:
# check jobid: 44106100
# spool jobid: 44106122
# run jobid: 44106123

# %%
###########
# gridMET #
###########
run_WBM(
    run_type="obs",
    main_path=main_path,
    sim_ID="OBS_gridMET_historical",
    model_info={},
    project_ID=project_ID,
    
    
    run_start=run_start,
    run_end=run_end,
    spinup_start=spinup_start,
    spinup_end=spinup_end,
    spinup_loops=spinup_loops,
    output_vars=output_vars,
    pet_method=pet_method,
    airT_primary="XXX",
    airT_secondary="XXX",
    airT_min="gridMET_tmmn_daily.init",
    airT_max="gridMET_tmmx_daily.init",
    precip_primary="gridMET_pr_daily.init",
    precip_secondary="",
    cloudFr_primary=cloudFr_primary,
    windU_primary="",
    windV_primary="",
    humidity_primary="",
    albedo_primary="",
    rootingDepth=rootingDepth,
    soilAWC=soilAWC,
    canopyHt=canopyHt,
    lai=lai,
    land_collapse=land_collapse,
    crop_area_frac=crop_area_frac,
    crop_area_frac_patch="",
    crop_par=crop_par,
    crop_par_patch="",
    
)
# Out:
# check jobid: 44106135
# spool jobid: 44106160
# run jobid: 44106162

# %%
#########
# PRISM #
#########
run_start="1981-01-01" # only PRISM

spinup_start="1981-01-01"
spinup_end="1981-12-31"
spinup_loops = 5

run_WBM(
    run_type="obs",
    main_path=main_path,
    sim_ID="OBS_PRISM_historical",
    model_info={},
    project_ID=project_ID,
    
    
    run_start=run_start,
    run_end=run_end,
    spinup_start=spinup_start,
    spinup_end=spinup_end,
    spinup_loops=spinup_loops,
    output_vars=output_vars,
    pet_method=pet_method,
    airT_primary="PRISM_tmean_4kmD2_d.init",
    airT_secondary="",
    airT_min="",
    airT_max="",
    precip_primary="PRISM_ppt_4kmD2_d.init",
    precip_secondary="",
    cloudFr_primary=cloudFr_primary,
    windU_primary="",
    windV_primary="",
    humidity_primary="",
    albedo_primary="",
    rootingDepth=rootingDepth,
    soilAWC=soilAWC,
    canopyHt=canopyHt,
    lai=lai,
    land_collapse=land_collapse,
    crop_area_frac=crop_area_frac,
    crop_area_frac_patch="",
    crop_par=crop_par,
    crop_par_patch="",
    
)
# Out:
# check jobid: 44106124
# spool jobid: 44106130
# run jobid: 44106132

# %% [markdown]
# # Hindcast runs (climate models)

# %%
#######################
# Common to hindcasts #
#######################

# Simulation length
run_start="1980-01-01"
run_end="2014-12-31"

# Spunup
spinup_start="1980-01-01"
spinup_end="1980-12-31"
spinup_loops = 5

# Cloud fraction
cloudFr_primary = "merra2_cldtot_d.init"

# Crop parameter file
crop_par = "CDL-US-M_CropParameters_hist.csv"

# Crop area timeseries
crop_area_frac="cdl_cropland_hist.init"

# Only used for LOCA projections
state_id = ""

# %% [markdown]
# ### NEX-GDDP

# %%
# Constants
ensemble = "NEX-GDDP"
vars_ = ["tasmin", "tasmax", "pr"]

# Get run infos
run_info = df_climate_drivers[(df_climate_drivers.ensemble == ensemble) & (df_climate_drivers.ssp == "historical")].copy()

# %%
len(run_info)
# Out:
# 31

# %%
#################
# NEX hindcasts #
#################
for _, info in run_info.iterrows():
    
    print(info['model'])
    sim_ID = f"{info['ensemble']}_{info['model']}_{info['member']}_{info['ssp']}"
    
    run_WBM(
        run_type="model",
        main_path=main_path,
        sim_ID=sim_ID,
        run_info=info,
        project_ID=project_ID,
        run_start=run_start,
        run_end=run_end,
        spinup_start=spinup_start,
        spinup_end=spinup_end,
        spinup_loops=spinup_loops,
        state_id=state_id,
        output_vars=output_vars,
        pet_method=pet_method,
        vars_=vars_,
        airT_primary="XXX",
        airT_secondary="XXX",
        airT_min=f"{sim_ID}_tasmin_daily.init",
        airT_max=f"{sim_ID}_tasmax_daily.init",
        precip_primary=f"{sim_ID}_pr_daily.init",
        precip_secondary="",
        cloudFr_primary=cloudFr_primary,
        windU_primary="",
        windV_primary="",
        humidity_primary="",
        albedo_primary="",
        rootingDepth=rootingDepth,
        soilAWC=soilAWC,
        canopyHt=canopyHt,
        lai=lai,
        land_collapse=land_collapse,
        crop_area_frac=crop_area_frac,
        crop_area_frac_patch="",
        crop_par=crop_par,
        crop_par_patch="",
    )
    
    print('\n')
# Out:
# IPSL-CM6A-LR
# Directory already exists!
# spooling already done.
# run jobid: 44232874
#
#
# ACCESS-CM2
# Directory already exists!
# spooling already done.
# run already done.
#
#
# GFDL-CM4_gr2
# Directory already exists!
# spooling already done.
# run jobid: 44232875
#
#
# INM-CM5-0
# Directory already exists!
# spooling already done.
# run jobid: 44232876
#
#
# KACE-1-0-G
# Directory already exists!
# spooling already done.
# run jobid: 44232877
#
#
# MPI-ESM1-2-LR
# Directory already exists!
# spooling already done.
# run jobid: 44232878
#
#
# NorESM2-LM
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5
# Directory already exists!
# spooling already done.
# run already done.
#
#
# UKESM1-0-LL
# Directory already exists!
# spool jobid: 44232879
# run already done.
#
#
# GFDL-ESM4
# Directory already exists!
# spooling already done.
# run jobid: 44232880
#
#
# ACCESS-ESM1-5
# Directory already exists!
# spooling already done.
# run jobid: 44232881
#
#
# GFDL-CM4
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC-ES2L
# Directory already exists!
# spooling already done.
# run jobid: 44232882
#
#
# GISS-E2-1-G
# Directory already exists!
# spooling already done.
# run jobid: 44232883
#
#
# CMCC-ESM2
# Directory already exists!
# spooling already done.
# run jobid: 44232884
#
#
# EC-Earth3-Veg-LR
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM4-8
# Directory already exists!
# spooling already done.
# run jobid: 44232885
#
#
# KIOST-ESM
# Directory already exists!
# spooling already done.
# run jobid: 44232886
#
#
# EC-Earth3
# Directory already exists!
# spooling already done.
# run jobid: 44232887
#
#
# BCC-CSM2-MR
# Directory already exists!
# spooling already done.
# run jobid: 44232888
#
#
# MPI-ESM1-2-HR
# Directory already exists!
# spooling already done.
# run already done.
#
#
# TaiESM1
# Directory already exists!
# spooling already done.
# run already done.
#
#
# HadGEM3-GC31-LL
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-CM6-1
# Directory already exists!
# spooling already done.
# run jobid: 44232889
#
#
# FGOALS-g3
# Directory already exists!
# spooling already done.
# run already done.
#
#
# HadGEM3-GC31-MM
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CMCC-CM2-SR5
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-ESM2-1
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-MM
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0
# Directory already exists!
# spooling already done.
# run already done.

# %% [markdown]
# ### LOCA2

# %%
# Constants
ensemble = "LOCA2"
vars_ = ["tasmax","tasmin","pr"]

# Get run infos
run_info = df_climate_drivers[(df_climate_drivers.ensemble == ensemble) & (df_climate_drivers.ssp == "historical")].copy()

# %%
len(run_info)
# Out:
# 108

# %%
##################
# LOCA2 hindcasts
##################
for idx, info in run_info.iterrows():
    
    if idx <= 21:
        continue
    
    print(f"{info['model']} {info['member']}")
    sim_ID = f"{ensemble}_{info['model']}_{info['member']}_{info['ssp']}"
    
    run_WBM(
        run_type="model",
        main_path=main_path,
        sim_ID=sim_ID,
        run_info=info,
        project_ID=project_ID,
        run_start=run_start,
        run_end=run_end,
        spinup_start=spinup_start,
        spinup_end=spinup_end,
        spinup_loops=spinup_loops,
        state_id=state_id,
        output_vars=output_vars,
        pet_method=pet_method,
        vars_=vars_,
        airT_primary="XXX",
        airT_secondary="XXX",
        airT_min=f"{sim_ID}_tasmin_daily.init",
        airT_max=f"{sim_ID}_tasmax_daily.init",
        precip_primary=f"{sim_ID}_pr_daily.init",
        precip_secondary="",
        cloudFr_primary=cloudFr_primary,
        windU_primary="",
        windV_primary="",
        humidity_primary="",
        albedo_primary="",
        rootingDepth=rootingDepth,
        soilAWC=soilAWC,
        canopyHt=canopyHt,
        lai=lai,
        land_collapse=land_collapse,
        crop_area_frac=crop_area_frac,
        crop_area_frac_patch="",
        crop_par=crop_par,
        crop_par_patch=""
    )
    
    print('\n')
# Out:
# AWI-CM-1-1-MR r2i1p1f1
# Directory already exists!
# spooling already done.
# run already done.
#
#
# AWI-CM-1-1-MR r5i1p1f1
# Directory already exists!
# spool jobid: 44234477
# run already done.
#
#
# AWI-CM-1-1-MR r1i1p1f1
# Directory already exists!
# spooling already done.
# run already done.
#
#
# AWI-CM-1-1-MR r4i1p1f1
# Directory already exists!
# spooling already done.
# run already done.
#
#
# AWI-CM-1-1-MR r3i1p1f1
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r2i1p1f1
# Directory already exists!
# spool jobid: 44234478
# run jobid: 44234479
#
#
# IPSL-CM6A-LR r5i1p1f1
# Directory already exists!
# spool jobid: 44234480
# run jobid: 44234482
#
#
# IPSL-CM6A-LR r1i1p1f1
# Directory already exists!
# spool jobid: 44234483
# run jobid: 44234484
#
#
# IPSL-CM6A-LR r4i1p1f1
# Directory already exists!
# spool jobid: 44234485
# run jobid: 44234486
#
#
# IPSL-CM6A-LR r3i1p1f1
# Directory already exists!
# spool jobid: 44234487
# run jobid: 44234488
#
#
# IPSL-CM6A-LR r9i1p1f1
# Directory already exists!
# spool jobid: 44234490
# run jobid: 44234491
#
#
# IPSL-CM6A-LR r8i1p1f1
# Directory already exists!
# spool jobid: 44234492
# run jobid: 44234493
#
#
# IPSL-CM6A-LR r10i1p1f1
# Directory already exists!
# spool jobid: 44234494
# run jobid: 44234495
#
#
# IPSL-CM6A-LR r7i1p1f1
# Directory already exists!
# spool jobid: 44234497
# run jobid: 44234498
#
#
# IPSL-CM6A-LR r6i1p1f1
# Directory already exists!
# spool jobid: 44234499
# run jobid: 44234500
#
#
# ACCESS-CM2 r2i1p1f1
# Directory already exists!
# spool jobid: 44234501
# run jobid: 44234502
#
#
# ACCESS-CM2 r1i1p1f1
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r3i1p1f1
# Directory already exists!
# spool jobid: 44234503
# run jobid: 44234504
#
#
# INM-CM5-0 r2i1p1f1
# Directory already exists!
# spool jobid: 44234505
# run jobid: 44234507
#
#
# INM-CM5-0 r5i1p1f1
# Directory already exists!
# spool jobid: 44234509
# run jobid: 44234510
#
#
# INM-CM5-0 r1i1p1f1
# Directory already exists!
# spool jobid: 44234511
# run jobid: 44234512
#
#
# INM-CM5-0 r4i1p1f1
# Directory already exists!
# spool jobid: 44234513
# run jobid: 44234514
#
#
# INM-CM5-0 r3i1p1f1
# Directory already exists!
# spool jobid: 44234515
# run jobid: 44234516
#
#
# KACE-1-0-G r2i1p1f1
# check jobid: 44234517
# spool jobid: 44234518
# run jobid: 44234519
#
#
# KACE-1-0-G r1i1p1f1
# check jobid: 44234520
# spool jobid: 44234521
# run jobid: 44234522
#
#
# KACE-1-0-G r3i1p1f1
# check jobid: 44234523
# spool jobid: 44234526
# run jobid: 44234527
#
#
# MPI-ESM1-2-LR r2i1p1f1
# check jobid: 44234528
# spool jobid: 44234529
# run jobid: 44234530
#
#
# MPI-ESM1-2-LR r5i1p1f1
# check jobid: 44234531
# spool jobid: 44234532
# run jobid: 44234533
#
#
# MPI-ESM1-2-LR r1i1p1f1
# check jobid: 44234534
# spool jobid: 44234535
# run jobid: 44234536
#
#
# MPI-ESM1-2-LR r4i1p1f1
# check jobid: 44234538
# spool jobid: 44234542
# run jobid: 44234543
#
#
# MPI-ESM1-2-LR r3i1p1f1
# check jobid: 44234544
# spool jobid: 44234559
# run jobid: 44234560
#
#
# MPI-ESM1-2-LR r8i1p1f1
# check jobid: 44234561
# spool jobid: 44234610
# run jobid: 44234611
#
#
# MPI-ESM1-2-LR r10i1p1f1
# check jobid: 44234614
# spool jobid: 44234620
# run jobid: 44234621
#
#
# MPI-ESM1-2-LR r7i1p1f1
# check jobid: 44234622
# spool jobid: 44234623
# run jobid: 44234624
#
#
# MPI-ESM1-2-LR r6i1p1f1
# check jobid: 44234625
# spool jobid: 44234626
# run jobid: 44234627
#
#
# NorESM2-LM r2i1p1f1
# check jobid: 44234628
# spool jobid: 44234629
# run jobid: 44234630
#
#
# NorESM2-LM r1i1p1f1
# check jobid: 44234631
# spool jobid: 44234632
# run jobid: 44234633
#
#
# NorESM2-LM r3i1p1f1
# check jobid: 44234634
# spool jobid: 44234635
# run jobid: 44234636
#
#
# CanESM5 r2i1p1f1
# check jobid: 44234637
# spool jobid: 44234638
# run jobid: 44234639
#
#
# CanESM5 r5i1p1f1
# check jobid: 44234640
# spool jobid: 44234642
# run jobid: 44234643
#
#
# CanESM5 r1i1p1f1
# check jobid: 44234644
# spool jobid: 44234646
# run jobid: 44234647
#
#
# CanESM5 r4i1p1f1
# check jobid: 44234648
# spool jobid: 44234649
# run jobid: 44234650
#
#
# CanESM5 r3i1p1f1
# check jobid: 44234651
# spool jobid: 44234652
# run jobid: 44234653
#
#
# CanESM5 r7i1p1f1
# check jobid: 44234654
# spool jobid: 44234655
# run jobid: 44234656
#
#
# CanESM5 r6i1p1f1
# check jobid: 44234657
# spool jobid: 44234658
# run jobid: 44234659
#
#
# CNRM-CM6-1-HR r1i1p1f2
# Directory already exists!
# spooling already done.
# run already done.
#
#
# GFDL-ESM4 r1i1p1f1
# check jobid: 44234660
# spool jobid: 44234661
# run jobid: 44234662
#
#
# CESM2-LENS r2i1p1f1
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r5i1p1f1
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r1i1p1f1
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r4i1p1f1
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r3i1p1f1
# Directory already exists!
# spool jobid: 44234663
# run already done.
#
#
# CESM2-LENS r9i1p1f1
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r8i1p1f1
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r10i1p1f1
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r7i1p1f1
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r6i1p1f1
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r2i1p1f1
# check jobid: 44234664
# spool jobid: 44234665
# run jobid: 44234666
#
#
# ACCESS-ESM1-5 r5i1p1f1
# check jobid: 44234667
# spool jobid: 44234668
# run jobid: 44234669
#
#
# ACCESS-ESM1-5 r1i1p1f1
# check jobid: 44234670
# spool jobid: 44234672
# run jobid: 44234673
#
#
# ACCESS-ESM1-5 r4i1p1f1
# check jobid: 44234674
# spool jobid: 44234677
# run jobid: 44234678
#
#
# ACCESS-ESM1-5 r3i1p1f1
# check jobid: 44234679
# spool jobid: 44234681
# run jobid: 44234682
#
#
# GFDL-CM4 r1i1p1f1
# check jobid: 44234683
# spool jobid: 44234685
# run jobid: 44234687
#
#
# INM-CM4-8 r1i1p1f1
# check jobid: 44234688
# spool jobid: 44234689
# run jobid: 44234690
#
#
# EC-Earth3 r2i1p1f1
# check jobid: 44234692
# spool jobid: 44234695
# run jobid: 44234696
#
#
# EC-Earth3 r1i1p1f1
# check jobid: 44234697
# spool jobid: 44234698
# run jobid: 44234699
#
#
# EC-Earth3 r4i1p1f1
# check jobid: 44234700
# spool jobid: 44234701
# run jobid: 44234702
#
#
# EC-Earth3 r3i1p1f1
# check jobid: 44234703
# spool jobid: 44234704
# run jobid: 44234705
#
#
# BCC-CSM2-MR r1i1p1f1
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r2i1p1f1
# check jobid: 44234706
# spool jobid: 44234707
# run jobid: 44234708
#
#
# MPI-ESM1-2-HR r5i1p1f1
# check jobid: 44234709
# spool jobid: 44234710
# run jobid: 44234711
#
#
# MPI-ESM1-2-HR r1i1p1f1
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r4i1p1f1
# check jobid: 44234712
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 12
#       9 print(f"{info['model']} {info['member']}")
#      10 sim_ID = f"{ensemble}_{info['model']}_{info['member']}_{info['ssp']}"
# ---> 12 run_WBM(
#      13     run_type="model",
#      14     main_path=main_path,
#      15     sim_ID=sim_ID,
#      16     run_info=info,
#      17     project_ID=project_ID,
#      18     run_start=run_start,
#      19     run_end=run_end,
#      20     spinup_start=spinup_start,
#      21     spinup_end=spinup_end,
#      22     spinup_loops=spinup_loops,
#      23     state_id=state_id,
#      24     output_vars=output_vars,
#      25     pet_method=pet_method,
#      26     vars_=vars_,
#      27     airT_primary="XXX",
#      28     airT_secondary="XXX",
#      29     airT_min=f"{sim_ID}_tasmin_daily.init",
#      30     airT_max=f"{sim_ID}_tasmax_daily.init",
#      31     precip_primary=f"{sim_ID}_pr_daily.init",
#      32     precip_secondary="",
#      33     cloudFr_primary=cloudFr_primary,
#      34     windU_primary="",
#      35     windV_primary="",
#      36     humidity_primary="",
#      37     albedo_primary="",
#      38     rootingDepth=rootingDepth,
#      39     soilAWC=soilAWC,
#      40     canopyHt=canopyHt,
#      41     lai=lai,
#      42     land_collapse=land_collapse,
#      43     crop_area_frac=crop_area_frac,
#      44     crop_area_frac_patch="",
#      45     crop_par=crop_par,
#      46     crop_par_patch=""
#      47 )
#      49 print('\n')
#
# File /storage/work/d/dcl5300/current_projects/wbm_soilM_crop_uc_lafferty-etal-2024-tbd/code/run_WBM.py:287, in run_WBM(run_type, main_path, sim_ID, project_ID, run_start, run_end, spinup_start, spinup_end, spinup_loops, state_id, output_vars, run_info, pet_method, vars_, airT_primary, airT_secondary, airT_min, airT_max, precip_primary, precip_secondary, cloudFr_primary, windU_primary, windV_primary, humidity_primary, albedo_primary, rootingDepth, soilAWC, canopyHt, lai, land_collapse, crop_area_frac, crop_area_frac_patch, crop_par, crop_par_patch)
#     285 # check for errors in setup
#     286 while not os.path.isfile(f"{sim_path}/check_run_WBM.out"):
# --> 287     time.sleep(60)
#     288 check_job_out = subprocess.run(
#     289     ["tail", "-n", "5", f"{sim_path}/check_run_WBM.out"],
#     290     capture_output=True, text=True).stdout.split("\n")[-4]
#     292 if check_job_out != "All Done!":
#
# KeyboardInterrupt:

# %% [markdown]
# ### OakRidge

# %%
# Get NEX historical run infos
run_info = df_climate_drivers[(df_climate_drivers.ensemble == "OakRidge") & (df_climate_drivers.ssp == "historical")].copy()

# Constants
ensemble = "OakRidge"
vars_ = ["tmax","tmin","prcp"]

# %%
#####################
# OakRidge hindcasts
#####################
for _, info in run_info.iterrows():
        
    print(f"{info['model']} {info['method']}")
    sim_ID = f"{ensemble}_{info['model']}_{info['member']}_{info['method']}_{info['ssp']}"
        
    run_WBM(
        run_type="model",
        main_path=main_path,
        sim_ID=sim_ID,
        run_info=info,
        project_ID=project_ID,
        run_start=run_start,
        run_end=run_end,
        spinup_start=spinup_start,
        spinup_end=spinup_end,
        spinup_loops=spinup_loops,
        state_id=state_id,
        output_vars=output_vars,
        pet_method=pet_method,
        vars_=vars_,
        airT_primary="XXX",
        airT_secondary="XXX",
        airT_min=f"{sim_ID}_tmin_daily.init",
        airT_max=f"{sim_ID}_tmax_daily.init",
        precip_primary=f"{sim_ID}_prcp_daily.init",
        precip_secondary="",
        cloudFr_primary=cloudFr_primary,
        windU_primary="",
        windV_primary="",
        humidity_primary="",
        albedo_primary="",
        rootingDepth=rootingDepth,
        soilAWC=soilAWC,
        canopyHt=canopyHt,
        lai=lai,
        land_collapse=land_collapse,
        crop_area_frac=crop_area_frac,
        crop_area_frac_patch="",
        crop_par=crop_par,
        crop_par_patch="",
    )
    print('\n')
# Out:
# ACCESS-CM2 DBCCA_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# BCC-CSM2-MR DBCCA_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-ESM2-1 DBCCA_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR DBCCA_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 DBCCA_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-MM DBCCA_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 RegCM_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# BCC-CSM2-MR RegCM_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-ESM2-1 RegCM_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR RegCM_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 RegCM_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-MM RegCM_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 DBCCA_Livneh
# Directory already exists!
# spooling already done.
# run already done.
#
#
# BCC-CSM2-MR DBCCA_Livneh
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-ESM2-1 DBCCA_Livneh
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR DBCCA_Livneh
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 DBCCA_Livneh
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-MM DBCCA_Livneh
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 RegCM_Livneh
# Directory already exists!
# spooling already done.
# run already done.
#
#
# BCC-CSM2-MR RegCM_Livneh
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-ESM2-1 RegCM_Livneh
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR RegCM_Livneh
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 RegCM_Livneh
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-MM RegCM_Livneh
# Directory already exists!
# spooling already done.
# run already done.

# %% [markdown]
# # Projections

# %% [markdown]
# ### NEX-GDDP

# %%
# Constants
ensemble = "NEX-GDDP"
vars_ = ["tasmin", "tasmax", "pr"]

# Get run infos
run_info = df_climate_drivers[(df_climate_drivers.ensemble == ensemble) & (df_climate_drivers.ssp != "historical")].copy()

# %%
len(run_info)
# Out:
# 119

# %%
# Simulation length
run_start="2015-01-01"
run_end="2099-12-31"

# Spin up
spinup_start="2015-01-01"
spinup_end="2015-12-31"
spinup_loops = 5

# Cloud fraction
cloudFr_primary = "merra2_cldtot_dc.init"

# Crop parameter file
crop_par = "CDL-US-M_CropParameters_proj.csv"

# Crop area timeseries
crop_area_frac="cdl_cropland_proj.init"

# Only used for LOCA2 projections
state_id = ""

# %%
##################
# NEX projections
##################
for idx, info in run_info.iterrows():
    
    if idx == 0:
        continue
    
    print(f"{info['model']} {info['ssp']}")
    sim_ID = f"{info['ensemble']}_{info['model']}_{info['member']}_{info['ssp']}"
    
    run_WBM(
        run_type="model",
        main_path=main_path,
        sim_ID=sim_ID,
        run_info=info,
        project_ID=project_ID,
        run_start=run_start,
        run_end=run_end,
        spinup_start=spinup_start,
        spinup_end=spinup_end,
        spinup_loops=spinup_loops,
        state_id=state_id,
        output_vars=output_vars,
        pet_method=pet_method,
        vars_=vars_,
        airT_primary="XXX",
        airT_secondary="XXX",
        airT_min=f"{sim_ID}_tasmin_daily.init",
        airT_max=f"{sim_ID}_tasmax_daily.init",
        precip_primary=f"{sim_ID}_pr_daily.init",
        precip_secondary="",
        cloudFr_primary=cloudFr_primary,
        windU_primary="",
        windV_primary="",
        humidity_primary="",
        albedo_primary="",
        rootingDepth=rootingDepth,
        soilAWC=soilAWC,
        canopyHt=canopyHt,
        lai=lai,
        land_collapse=land_collapse,
        crop_area_frac=crop_area_frac,
        crop_area_frac_patch="",
        crop_par=crop_par,
        crop_par_patch="",
    )
    
    print('\n')
# Out:
# IPSL-CM6A-LR {'ssp585'}
# Directory already exists!
# spool jobid: 44232996
# run jobid: 44232997
#
#
# IPSL-CM6A-LR {'ssp370'}
# check jobid: 44233095
# spool jobid: 44233098
# run jobid: 44233099
#
#
# IPSL-CM6A-LR {'ssp126'}
# check jobid: 44233100
# spool jobid: 44233101
# run jobid: 44233102
#
#
# ACCESS-CM2 {'ssp245'}
# check jobid: 44233103
# spool jobid: 44233104
# run jobid: 44233105
#
#
# ACCESS-CM2 {'ssp585'}
# Directory already exists!
# check jobid: 44233106
# Something went wrong!
#
#
# ACCESS-CM2 {'ssp370'}
# check jobid: 44233107
# spool jobid: 44233108
# run jobid: 44233109
#
#
# ACCESS-CM2 {'ssp126'}
# check jobid: 44233110
# spool jobid: 44233111
# run jobid: 44233112
#
#
# GFDL-CM4_gr2 {'ssp245'}
# check jobid: 44233113
# spool jobid: 44233116
# run jobid: 44233117
#
#
# GFDL-CM4_gr2 {'ssp585'}
# check jobid: 44233118
# spool jobid: 44233119
# run jobid: 44233120
#
#
# INM-CM5-0 {'ssp245'}
# check jobid: 44233121
# spool jobid: 44233122
# run jobid: 44233123
#
#
# INM-CM5-0 {'ssp585'}
# check jobid: 44233124
# spool jobid: 44233125
# run jobid: 44233126
#
#
# INM-CM5-0 {'ssp370'}
# check jobid: 44233127
# spool jobid: 44233128
# run jobid: 44233129
#
#
# INM-CM5-0 {'ssp126'}
# check jobid: 44233130
# spool jobid: 44233131
# run jobid: 44233132
#
#
# NESM3 {'ssp245'}
# check jobid: 44233133
# spool jobid: 44233135
# run jobid: 44233136
#
#
# NESM3 {'ssp585'}
# check jobid: 44233137
# spool jobid: 44233138
# run jobid: 44233139
#
#
# NESM3 {'ssp126'}
# check jobid: 44233140
# spool jobid: 44233141
# run jobid: 44233142
#
#
# KACE-1-0-G {'ssp245'}
# check jobid: 44233143
# spool jobid: 44233144
# run jobid: 44233145
#
#
# KACE-1-0-G {'ssp585'}
# check jobid: 44233146
# spool jobid: 44233147
# run jobid: 44233148
#
#
# KACE-1-0-G {'ssp370'}
# check jobid: 44233150
# spool jobid: 44233151
# run jobid: 44233152
#
#
# KACE-1-0-G {'ssp126'}
# check jobid: 44233153
# spool jobid: 44233155
# run jobid: 44233156
#
#
# MPI-ESM1-2-LR {'ssp245'}
# check jobid: 44233157
# spool jobid: 44233159
# run jobid: 44233160
#
#
# MPI-ESM1-2-LR {'ssp585'}
# check jobid: 44233162
# spool jobid: 44233163
# run jobid: 44233164
#
#
# MPI-ESM1-2-LR {'ssp370'}
# check jobid: 44233165
# spool jobid: 44233166
# run jobid: 44233167
#
#
# MPI-ESM1-2-LR {'ssp126'}
# check jobid: 44233168
# spool jobid: 44233169
# run jobid: 44233170
#
#
# NorESM2-LM {'ssp245'}
# check jobid: 44233171
# spool jobid: 44233172
# run jobid: 44233173
#
#
# NorESM2-LM {'ssp585'}
# check jobid: 44233174
# spool jobid: 44233175
# run jobid: 44233176
#
#
# NorESM2-LM {'ssp370'}
# check jobid: 44233177
# spool jobid: 44233178
# run jobid: 44233179
#
#
# NorESM2-LM {'ssp126'}
# check jobid: 44233180
# spool jobid: 44233182
# run jobid: 44233183
#
#
# CanESM5 {'ssp245'}
# check jobid: 44233184
# spool jobid: 44233185
# run jobid: 44233186
#
#
# CanESM5 {'ssp585'}
# check jobid: 44233187
# spool jobid: 44233189
# run jobid: 44233190
#
#
# CanESM5 {'ssp370'}
# check jobid: 44233191
# spool jobid: 44233192
# run jobid: 44233193
#
#
# CanESM5 {'ssp126'}
# check jobid: 44233194
# spool jobid: 44233195
# run jobid: 44233196
#
#
# UKESM1-0-LL {'ssp245'}
# check jobid: 44233197
# spool jobid: 44233198
# run jobid: 44233199
#
#
# UKESM1-0-LL {'ssp585'}
# check jobid: 44233200
# spool jobid: 44233201
# run jobid: 44233202
#
#
# UKESM1-0-LL {'ssp370'}
# check jobid: 44233203
# spool jobid: 44233204
# run jobid: 44233205
#
#
# UKESM1-0-LL {'ssp126'}
# check jobid: 44233206
# spool jobid: 44233207
# run jobid: 44233208
#
#
# GFDL-ESM4 {'ssp245'}
# check jobid: 44233209
# spool jobid: 44233211
# run jobid: 44233212
#
#
# GFDL-ESM4 {'ssp585'}
# check jobid: 44233213
# spool jobid: 44233214
# run jobid: 44233215
#
#
# GFDL-ESM4 {'ssp370'}
# check jobid: 44233216
# spool jobid: 44233217
# run jobid: 44233218
#
#
# GFDL-ESM4 {'ssp126'}
# check jobid: 44233219
# spool jobid: 44233220
# run jobid: 44233221
#
#
# ACCESS-ESM1-5 {'ssp245'}
# check jobid: 44233222
# spool jobid: 44233223
# run jobid: 44233224
#
#
# ACCESS-ESM1-5 {'ssp585'}
# check jobid: 44233225
# spool jobid: 44233226
# run jobid: 44233227
#
#
# ACCESS-ESM1-5 {'ssp370'}
# check jobid: 44233228
# spool jobid: 44233229
# run jobid: 44233230
#
#
# ACCESS-ESM1-5 {'ssp126'}
# check jobid: 44233231
# spool jobid: 44233233
# run jobid: 44233234
#
#
# GFDL-CM4 {'ssp245'}
# check jobid: 44233235
# spool jobid: 44233236
# run jobid: 44233237
#
#
# GFDL-CM4 {'ssp585'}
# check jobid: 44233238
# spool jobid: 44233239
# run jobid: 44233240
#
#
# MIROC-ES2L {'ssp245'}
# check jobid: 44233241
# spool jobid: 44233242
# run jobid: 44233243
#
#
# MIROC-ES2L {'ssp585'}
# check jobid: 44233244
# spool jobid: 44233246
# run jobid: 44233247
#
#
# MIROC-ES2L {'ssp370'}
# check jobid: 44233248
# spool jobid: 44233249
# run jobid: 44233250
#
#
# MIROC-ES2L {'ssp126'}
# check jobid: 44233251
# spool jobid: 44233252
# run jobid: 44233253
#
#
# GISS-E2-1-G {'ssp245'}
# check jobid: 44233254
# spool jobid: 44233255
# run jobid: 44233256
#
#
# GISS-E2-1-G {'ssp585'}
# check jobid: 44233257

# %% [markdown]
# ### LOCA

# %%
# Constants
ensemble = "LOCA2"
vars_ = ["tasmax","tasmin","pr"]

# Get run infos
run_info = df_climate_drivers[(df_climate_drivers.ensemble == ensemble) & (df_climate_drivers.ssp != "historical")].copy()

# %%
len(run_info)
# Out:
# 221

# %%
### Constant for all runs
# Simulation length
run_starts = ["2015-01-01", "2045-01-01", "2075-01-01"]
run_ends = ["2044-12-31", "2074-12-31", "2100-12-31"]
run_IDs = ["early", "mid", "late"]

# Cloud fraction
cloudFr_primary = "merra2_cldtot_dc.init"

# Crop parameter file
crop_par = "CDL-US-M_CropParameters_proj.csv"

# Crop area timeseries
crop_area_frac="cdl_cropland_proj.init"

# %%
############################
# LOCA projections: EARLY
############################
# Spin up
spinup_start="2015-01-01"
spinup_end="2015-12-31"
spinup_loops = 5
state_id = ""

# Early
time_id = 0

for _, info in run_info.iterrows():
    
    print(f"{info['model']} {info['member']} {info['ssp']}")
    sim_ID = f"{info['ensemble']}_{info['model']}_{info['member']}_{info['ssp']}_{run_IDs[time_id]}"

    run_WBM(
        run_type="model",
        main_path=main_path,
        sim_ID=sim_ID,
        run_info=info,
        project_ID=project_ID,
        run_start=run_starts[time_id],
        run_end=run_ends[time_id],
        spinup_start=spinup_start,
        spinup_end=spinup_end,
        spinup_loops=spinup_loops,
        state_id = state_id,
        output_vars=output_vars,
        pet_method=pet_method,
        vars_=vars_,
        airT_primary="XXX",
        airT_secondary="XXX",
        airT_min=f"{sim_ID}_tasmin_daily.init",
        airT_max=f"{sim_ID}_tasmax_daily.init",
        precip_primary=f"{sim_ID}_pr_daily.init",
        precip_secondary="",
        cloudFr_primary=cloudFr_primary,
        windU_primary="",
        windV_primary="",
        humidity_primary="",
        albedo_primary="",
        rootingDepth=rootingDepth,
        soilAWC=soilAWC,
        canopyHt=canopyHt,
        lai=lai,
        land_collapse=land_collapse,
        crop_area_frac=crop_area_frac,
        crop_area_frac_patch="",
        crop_par=crop_par,
        crop_par_patch=""
    )
    print('\n')
# Out:
# AWI-CM-1-1-MR r2i1p1f1 ssp370
# Directory already exists!
# spool jobid: 44234732
# run jobid: 44234733
#
#
# AWI-CM-1-1-MR r5i1p1f1 ssp370
# check jobid: 44234734
# spool jobid: 44234735
# run jobid: 44234736
#
#
# AWI-CM-1-1-MR r1i1p1f1 ssp245
# check jobid: 44234737
# spool jobid: 44234738
# run jobid: 44234739
#
#
# AWI-CM-1-1-MR r1i1p1f1 ssp585
# check jobid: 44234740
# spool jobid: 44234743
# run jobid: 44234744
#
#
# AWI-CM-1-1-MR r1i1p1f1 ssp370
# check jobid: 44234745
# spool jobid: 44234746
# run jobid: 44234747
#
#
# AWI-CM-1-1-MR r4i1p1f1 ssp370
# check jobid: 44234748
# spool jobid: 44234749
# run jobid: 44234750
#
#
# AWI-CM-1-1-MR r3i1p1f1 ssp370
# check jobid: 44234751
# spool jobid: 44234752
# run jobid: 44234753
#
#
# IPSL-CM6A-LR r2i1p1f1 ssp245
# check jobid: 44234754
# spool jobid: 44234755
# run jobid: 44234756
#
#
# IPSL-CM6A-LR r2i1p1f1 ssp585
# check jobid: 44234757
# spool jobid: 44234775
# run jobid: 44234776
#
#
# IPSL-CM6A-LR r2i1p1f1 ssp370
# check jobid: 44234788
# spool jobid: 44234826
# run jobid: 44234827
#
#
# IPSL-CM6A-LR r5i1p1f1 ssp245
# check jobid: 44234828
# spool jobid: 44234829
# run jobid: 44234830
#
#
# IPSL-CM6A-LR r5i1p1f1 ssp370
# check jobid: 44234831
# spool jobid: 44234832
# run jobid: 44234833
#
#
# IPSL-CM6A-LR r1i1p1f1 ssp245
# check jobid: 44234834
# spool jobid: 44234835
# run jobid: 44234837
#
#
# IPSL-CM6A-LR r1i1p1f1 ssp585
# check jobid: 44234838
# spool jobid: 44234840
# run jobid: 44234841
#
#
# IPSL-CM6A-LR r1i1p1f1 ssp370
# check jobid: 44234843
# spool jobid: 44234846
# run jobid: 44234847
#
#
# IPSL-CM6A-LR r4i1p1f1 ssp245
# check jobid: 44234848
# spool jobid: 44234849
# run jobid: 44234850
#
#
# IPSL-CM6A-LR r4i1p1f1 ssp585
# check jobid: 44234851
# spool jobid: 44234853
# run jobid: 44234854
#
#
# IPSL-CM6A-LR r4i1p1f1 ssp370
# check jobid: 44234855
# spool jobid: 44234857
# run jobid: 44234859
#
#
# IPSL-CM6A-LR r3i1p1f1 ssp245
# check jobid: 44234860
# spool jobid: 44234864
# run jobid: 44234865
#
#
# IPSL-CM6A-LR r3i1p1f1 ssp585
# check jobid: 44234866
# spool jobid: 44234867
# run jobid: 44234868
#
#
# IPSL-CM6A-LR r3i1p1f1 ssp370
# check jobid: 44234869
# spool jobid: 44234872
# run jobid: 44234873
#
#
# IPSL-CM6A-LR r9i1p1f1 ssp370
# check jobid: 44234874
# spool jobid: 44234876
# run jobid: 44234877
#
#
# IPSL-CM6A-LR r8i1p1f1 ssp370
# check jobid: 44234878
# spool jobid: 44234879
# run jobid: 44234880
#
#
# IPSL-CM6A-LR r10i1p1f1 ssp370
# check jobid: 44234881
# spool jobid: 44234882
# run jobid: 44234883
#
#
# IPSL-CM6A-LR r7i1p1f1 ssp370
# check jobid: 44234884
# spool jobid: 44234891
# run jobid: 44234892
#
#
# IPSL-CM6A-LR r6i1p1f1 ssp370
# check jobid: 44234894
# spool jobid: 44234899
# run jobid: 44234901
#
#
# ACCESS-CM2 r2i1p1f1 ssp245
# check jobid: 44234904
# spool jobid: 44234950
# run jobid: 44234954
#
#
# ACCESS-CM2 r2i1p1f1 ssp585
# check jobid: 44234958
# spool jobid: 44234970
# run jobid: 44234971
#
#
# ACCESS-CM2 r2i1p1f1 ssp370
# check jobid: 44234972
# spool jobid: 44234974
# run jobid: 44234975
#
#
# ACCESS-CM2 r1i1p1f1 ssp245
# check jobid: 44234976
# spool jobid: 44234977
# run jobid: 44234978
#
#
# ACCESS-CM2 r1i1p1f1 ssp585
# Directory already exists!
# check jobid: 44234979
# spool jobid: 44234980
# run jobid: 44234981
#
#
# ACCESS-CM2 r1i1p1f1 ssp370
# check jobid: 44234982
# spool jobid: 44234983
# run jobid: 44234984
#
#
# ACCESS-CM2 r3i1p1f1 ssp245
# check jobid: 44234985
# spool jobid: 44234986
# run jobid: 44234987
#
#
# ACCESS-CM2 r3i1p1f1 ssp585
# check jobid: 44234988
# spool jobid: 44234989
# run jobid: 44234990
#
#
# ACCESS-CM2 r3i1p1f1 ssp370
# check jobid: 44234991
# spool jobid: 44234992
# run jobid: 44234993
#
#
# INM-CM5-0 r2i1p1f1 ssp370
# check jobid: 44234994
# spool jobid: 44234996
# run jobid: 44234997
#
#
# INM-CM5-0 r5i1p1f1 ssp370
# check jobid: 44234998
# spool jobid: 44234999
# run jobid: 44235000
#
#
# INM-CM5-0 r1i1p1f1 ssp245
# check jobid: 44235001
# spool jobid: 44235002
# run jobid: 44235003
#
#
# INM-CM5-0 r1i1p1f1 ssp585
# check jobid: 44235004
# spool jobid: 44235005
# run jobid: 44235006
#
#
# INM-CM5-0 r1i1p1f1 ssp370
# check jobid: 44235007
# spool jobid: 44235009
# run jobid: 44235010
#
#
# INM-CM5-0 r4i1p1f1 ssp370
# check jobid: 44235011
# spool jobid: 44235013
# run jobid: 44235014
#
#
# INM-CM5-0 r3i1p1f1 ssp370
# check jobid: 44235015
# spool jobid: 44235016
# run jobid: 44235017
#
#
# KACE-1-0-G r2i1p1f1 ssp245
# check jobid: 44235018
# spool jobid: 44235023
# run jobid: 44235024
#
#
# KACE-1-0-G r2i1p1f1 ssp585
# check jobid: 44235025
# spool jobid: 44235029
# run jobid: 44235030
#
#
# KACE-1-0-G r2i1p1f1 ssp370
# check jobid: 44235031
# spool jobid: 44235033
# run jobid: 44235034
#
#
# KACE-1-0-G r1i1p1f1 ssp245
# check jobid: 44235035
# spool jobid: 44235036
# run jobid: 44235037
#
#
# KACE-1-0-G r1i1p1f1 ssp585
# check jobid: 44235038
# spool jobid: 44235041
# run jobid: 44235042
#
#
# KACE-1-0-G r1i1p1f1 ssp370
# check jobid: 44235043
# spool jobid: 44235046
# run jobid: 44235048
#
#
# KACE-1-0-G r3i1p1f1 ssp245
# check jobid: 44235049
# spool jobid: 44235050
# run jobid: 44235051
#
#
# KACE-1-0-G r3i1p1f1 ssp585
# check jobid: 44235052
# spool jobid: 44235053
# run jobid: 44235054
#
#
# KACE-1-0-G r3i1p1f1 ssp370
# check jobid: 44235055
# spool jobid: 44235057
# run jobid: 44235058
#
#
# MPI-ESM1-2-LR r2i1p1f1 ssp245
# check jobid: 44235059
# spool jobid: 44235060
# run jobid: 44235061
#
#
# MPI-ESM1-2-LR r2i1p1f1 ssp585
# check jobid: 44235062
# spool jobid: 44235063
# run jobid: 44235064
#
#
# MPI-ESM1-2-LR r2i1p1f1 ssp370
# check jobid: 44235065
# spool jobid: 44235066
# run jobid: 44235067
#
#
# MPI-ESM1-2-LR r5i1p1f1 ssp245
# check jobid: 44235068
# spool jobid: 44235069
# run jobid: 44235070
#
#
# MPI-ESM1-2-LR r5i1p1f1 ssp585
# check jobid: 44235071
# spool jobid: 44235072
# run jobid: 44235073
#
#
# MPI-ESM1-2-LR r5i1p1f1 ssp370
# check jobid: 44235074
# spool jobid: 44235075
# run jobid: 44235076
#
#
# MPI-ESM1-2-LR r1i1p1f1 ssp245
# check jobid: 44235077
# spool jobid: 44235078
# run jobid: 44235079
#
#
# MPI-ESM1-2-LR r1i1p1f1 ssp585
# check jobid: 44235080
# spool jobid: 44235082
# run jobid: 44235083
#
#
# MPI-ESM1-2-LR r1i1p1f1 ssp370
# check jobid: 44235084
# spool jobid: 44235085
# run jobid: 44235086
#
#
# MPI-ESM1-2-LR r4i1p1f1 ssp245
# check jobid: 44235087
# spool jobid: 44235088
# run jobid: 44235089
#
#
# MPI-ESM1-2-LR r4i1p1f1 ssp585
# check jobid: 44235090
# spool jobid: 44235091
# run jobid: 44235092
#
#
# MPI-ESM1-2-LR r4i1p1f1 ssp370
# check jobid: 44235093
# spool jobid: 44235094
# run jobid: 44235095
#
#
# MPI-ESM1-2-LR r3i1p1f1 ssp245
# check jobid: 44235096
# spool jobid: 44235097
# run jobid: 44235098
#
#
# MPI-ESM1-2-LR r3i1p1f1 ssp585
# check jobid: 44235100
# spool jobid: 44235101
# run jobid: 44235102
#
#
# MPI-ESM1-2-LR r3i1p1f1 ssp370
# check jobid: 44235103
# spool jobid: 44235104
# run jobid: 44235105
#
#
# MPI-ESM1-2-LR r8i1p1f1 ssp245
# check jobid: 44235106
# spool jobid: 44235107
# run jobid: 44235108
#
#
# MPI-ESM1-2-LR r8i1p1f1 ssp585
# check jobid: 44235109
# spool jobid: 44235110
# run jobid: 44235111
#
#
# MPI-ESM1-2-LR r8i1p1f1 ssp370
# check jobid: 44235112
# spool jobid: 44235114
# run jobid: 44235115
#
#
# MPI-ESM1-2-LR r10i1p1f1 ssp245
# check jobid: 44235116
# spool jobid: 44235117
# run jobid: 44235118
#
#
# MPI-ESM1-2-LR r10i1p1f1 ssp585
# check jobid: 44235119
# spool jobid: 44235120
# run jobid: 44235121
#
#
# MPI-ESM1-2-LR r10i1p1f1 ssp370
# check jobid: 44235122
# spool jobid: 44235123
# run jobid: 44235124
#
#
# MPI-ESM1-2-LR r7i1p1f1 ssp245
# check jobid: 44235125
# spool jobid: 44235126
# run jobid: 44235127
#
#
# MPI-ESM1-2-LR r7i1p1f1 ssp585
# check jobid: 44235128
# spool jobid: 44235129
# run jobid: 44235130
#
#
# MPI-ESM1-2-LR r7i1p1f1 ssp370
# check jobid: 44235131
# spool jobid: 44235132
# run jobid: 44235133
#
#
# MPI-ESM1-2-LR r6i1p1f1 ssp245
# check jobid: 44235134
# spool jobid: 44235135
# run jobid: 44235136
#
#
# MPI-ESM1-2-LR r6i1p1f1 ssp585
# check jobid: 44235137
# spool jobid: 44235138
# run jobid: 44235139
#
#
# NorESM2-LM r2i1p1f1 ssp245
# check jobid: 44235140
# spool jobid: 44235141
# run jobid: 44235142
#
#
# NorESM2-LM r1i1p1f1 ssp245
# check jobid: 44235143
# spool jobid: 44235144
# run jobid: 44235145
#
#
# NorESM2-LM r1i1p1f1 ssp585
# check jobid: 44235146
# spool jobid: 44235147
# run jobid: 44235148
#
#
# NorESM2-LM r1i1p1f1 ssp370
# check jobid: 44235149
# spool jobid: 44235150
# run jobid: 44235151
#
#
# NorESM2-LM r3i1p1f1 ssp245
# check jobid: 44235152
# spool jobid: 44235153
# run jobid: 44235154
#
#
# CanESM5 r2i1p1f1 ssp245
# check jobid: 44235155
# spool jobid: 44235156
# run jobid: 44235157
#
#
# CanESM5 r2i1p1f1 ssp585
# check jobid: 44235158
# spool jobid: 44235159
# run jobid: 44235160
#
#
# CanESM5 r2i1p1f1 ssp370
# check jobid: 44235161
# spool jobid: 44235162
# run jobid: 44235163
#
#
# CanESM5 r5i1p1f1 ssp245
# check jobid: 44235164
# spool jobid: 44235165
# run jobid: 44235166
#
#
# CanESM5 r5i1p1f1 ssp585
# check jobid: 44235167
# spool jobid: 44235168
# run jobid: 44235169
#
#
# CanESM5 r5i1p1f1 ssp370
# check jobid: 44235170
# spool jobid: 44235171
# run jobid: 44235172
#
#
# CanESM5 r1i1p1f1 ssp245
# check jobid: 44235173
# spool jobid: 44235174
# run jobid: 44235175
#
#
# CanESM5 r1i1p1f1 ssp585
# check jobid: 44235176
# spool jobid: 44235177
# run jobid: 44235178
#
#
# CanESM5 r1i1p1f1 ssp370
# check jobid: 44235179
# spool jobid: 44235180
# run jobid: 44235181
#
#
# CanESM5 r4i1p1f1 ssp245
# check jobid: 44235182
# spool jobid: 44235185
# run jobid: 44235186
#
#
# CanESM5 r4i1p1f1 ssp585
# check jobid: 44235187
# spool jobid: 44235189
# run jobid: 44235190
#
#
# CanESM5 r4i1p1f1 ssp370
# check jobid: 44235191
# spool jobid: 44235192
# run jobid: 44235193
#
#
# CanESM5 r3i1p1f1 ssp245
# check jobid: 44235194
# spool jobid: 44235195
# run jobid: 44235196
#
#
# CanESM5 r3i1p1f1 ssp585
# check jobid: 44235197
# spool jobid: 44235199
# run jobid: 44235200
#
#
# CanESM5 r3i1p1f1 ssp370
# check jobid: 44235201
# spool jobid: 44235202
# run jobid: 44235203
#
#
# CanESM5 r7i1p1f1 ssp245
# check jobid: 44235205
# spool jobid: 44235206
# run jobid: 44235207
#
#
# CanESM5 r7i1p1f1 ssp585
# check jobid: 44235208
# spool jobid: 44235210
# run jobid: 44235211
#
#
# CanESM5 r7i1p1f1 ssp370
# check jobid: 44235212
# spool jobid: 44235214
# run jobid: 44235215
#
#
# CanESM5 r6i1p1f1 ssp245
# check jobid: 44235216
# spool jobid: 44235217
# run jobid: 44235218
#
#
# CanESM5 r6i1p1f1 ssp585
# check jobid: 44235219
# spool jobid: 44235220
# run jobid: 44235221
#
#
# CanESM5 r6i1p1f1 ssp370
# check jobid: 44235222
# spool jobid: 44235223
# run jobid: 44235224
#
#
# CNRM-CM6-1-HR r1i1p1f2 ssp585
# check jobid: 44235225
# spool jobid: 44235226
# run jobid: 44235227
#
#
# GFDL-ESM4 r1i1p1f1 ssp245
# check jobid: 44235228
# spool jobid: 44235229
# run jobid: 44235230
#
#
# GFDL-ESM4 r1i1p1f1 ssp585
# check jobid: 44235231
# spool jobid: 44235233
# run jobid: 44235235
#
#
# GFDL-ESM4 r1i1p1f1 ssp370
# check jobid: 44235237
# spool jobid: 44235242
# run jobid: 44235243
#
#
# CESM2-LENS r2i1p1f1 ssp370
# check jobid: 44235244
# spool jobid: 44235246
# run jobid: 44235247
#
#
# CESM2-LENS r5i1p1f1 ssp370
# check jobid: 44235248
# spool jobid: 44235249
# run jobid: 44235250
#
#
# CESM2-LENS r1i1p1f1 ssp370
# check jobid: 44235251
# spool jobid: 44235257
# run jobid: 44235259
#
#
# CESM2-LENS r4i1p1f1 ssp370
# check jobid: 44235260
# spool jobid: 44235261
# run jobid: 44235262
#
#
# CESM2-LENS r3i1p1f1 ssp370
# check jobid: 44235263
# spool jobid: 44235265
# run jobid: 44235266
#
#
# CESM2-LENS r9i1p1f1 ssp370
# check jobid: 44235267
# spool jobid: 44235277
# run jobid: 44235279
#
#
# CESM2-LENS r8i1p1f1 ssp370
# check jobid: 44235281
# spool jobid: 44235292
# run jobid: 44235293
#
#
# CESM2-LENS r10i1p1f1 ssp370
# check jobid: 44235294
# spool jobid: 44235299
# run jobid: 44235300
#
#
# CESM2-LENS r7i1p1f1 ssp370
# check jobid: 44235301
# spool jobid: 44235308
# run jobid: 44235309
#
#
# CESM2-LENS r6i1p1f1 ssp370
# check jobid: 44235310
# spool jobid: 44235313
# run jobid: 44235316
#
#
# ACCESS-ESM1-5 r2i1p1f1 ssp245
# check jobid: 44235318
# spool jobid: 44235372
# run jobid: 44235374
#
#
# ACCESS-ESM1-5 r2i1p1f1 ssp585
# check jobid: 44235375
# spool jobid: 44235379
# run jobid: 44235380
#
#
# ACCESS-ESM1-5 r2i1p1f1 ssp370
# check jobid: 44235381
# spool jobid: 44235382
# run jobid: 44235383
#
#
# ACCESS-ESM1-5 r5i1p1f1 ssp245
# check jobid: 44235384
# spool jobid: 44235445
# run jobid: 44235446
#
#
# ACCESS-ESM1-5 r5i1p1f1 ssp585
# check jobid: 44235447
# spool jobid: 44235448
# run jobid: 44235449
#
#
# ACCESS-ESM1-5 r5i1p1f1 ssp370
# check jobid: 44235450
# spool jobid: 44235461
# run jobid: 44235462
#
#
# ACCESS-ESM1-5 r1i1p1f1 ssp245
# check jobid: 44235463
# spool jobid: 44235470
# run jobid: 44235471
#
#
# ACCESS-ESM1-5 r1i1p1f1 ssp585
# check jobid: 44235472
# spool jobid: 44235473
# run jobid: 44235474
#
#
# ACCESS-ESM1-5 r1i1p1f1 ssp370
# check jobid: 44235475
# spool jobid: 44235478
# run jobid: 44235479
#
#
# ACCESS-ESM1-5 r4i1p1f1 ssp245
# check jobid: 44235480
# spool jobid: 44235482
# run jobid: 44235483
#
#
# ACCESS-ESM1-5 r4i1p1f1 ssp585
# check jobid: 44235484
# spool jobid: 44235488
# run jobid: 44235489
#
#
# ACCESS-ESM1-5 r4i1p1f1 ssp370
# check jobid: 44235490
# spool jobid: 44235493
# run jobid: 44235494
#
#
# ACCESS-ESM1-5 r3i1p1f1 ssp245
# check jobid: 44235495
# spool jobid: 44235496
# run jobid: 44235497
#
#
# ACCESS-ESM1-5 r3i1p1f1 ssp585
# check jobid: 44235498
# spool jobid: 44235499
# run jobid: 44235500
#
#
# ACCESS-ESM1-5 r3i1p1f1 ssp370
# check jobid: 44235501
# spool jobid: 44235502
# run jobid: 44235503
#
#
# GFDL-CM4 r1i1p1f1 ssp245
# check jobid: 44235504
# spool jobid: 44235505
# run jobid: 44235506
#
#
# GFDL-CM4 r1i1p1f1 ssp585
# check jobid: 44235507
# spool jobid: 44235508
# run jobid: 44235509
#
#
# INM-CM4-8 r1i1p1f1 ssp245
# check jobid: 44235510
# spool jobid: 44235512
# run jobid: 44235513
#
#
# INM-CM4-8 r1i1p1f1 ssp585
# check jobid: 44235514
# spool jobid: 44235515
# run jobid: 44235516
#
#
# INM-CM4-8 r1i1p1f1 ssp370
# check jobid: 44235517
# spool jobid: 44235518
# run jobid: 44235519
#
#
# EC-Earth3 r2i1p1f1 ssp245
# check jobid: 44235520
# spool jobid: 44235521
# run jobid: 44235522
#
#
# EC-Earth3 r1i1p1f1 ssp245
# check jobid: 44235523
# spool jobid: 44235524
# run jobid: 44235525
#
#
# EC-Earth3 r1i1p1f1 ssp585
# check jobid: 44235526
# spool jobid: 44235527
# run jobid: 44235528
#
#
# EC-Earth3 r1i1p1f1 ssp370
# check jobid: 44235529
# spool jobid: 44235531
# run jobid: 44235532
#
#
# EC-Earth3 r4i1p1f1 ssp245
# check jobid: 44235533
# spool jobid: 44235535
# run jobid: 44235536
#
#
# EC-Earth3 r4i1p1f1 ssp585
# check jobid: 44235537
# spool jobid: 44235540
# run jobid: 44235541
#
#
# EC-Earth3 r4i1p1f1 ssp370
# check jobid: 44235542
# spool jobid: 44235544
# run jobid: 44235545
#
#
# EC-Earth3 r3i1p1f1 ssp585
# check jobid: 44235546
# spool jobid: 44235548
# run jobid: 44235549
#
#
# BCC-CSM2-MR r1i1p1f1 ssp245
# check jobid: 44235550
# spool jobid: 44235552
# run jobid: 44235553
#
#
# BCC-CSM2-MR r1i1p1f1 ssp585
# Directory already exists!
# check jobid: 44235554
# spool jobid: 44235555
# run jobid: 44235556
#
#
# BCC-CSM2-MR r1i1p1f1 ssp370
# check jobid: 44235557
# spool jobid: 44235558
# run jobid: 44235559
#
#
# MPI-ESM1-2-HR r2i1p1f1 ssp245
# check jobid: 44235560
# spool jobid: 44235562
# run jobid: 44235563
#
#
# MPI-ESM1-2-HR r2i1p1f1 ssp585
# check jobid: 44235564
# spool jobid: 44235565
# run jobid: 44235566
#
#
# MPI-ESM1-2-HR r2i1p1f1 ssp370
# check jobid: 44235567
# spool jobid: 44235568
# run jobid: 44235569
#
#
# MPI-ESM1-2-HR r5i1p1f1 ssp370
# check jobid: 44235570
# spool jobid: 44235571
# run jobid: 44235572
#
#
# MPI-ESM1-2-HR r1i1p1f1 ssp245
# check jobid: 44235573
# spool jobid: 44235574
# run jobid: 44235575
#
#
# MPI-ESM1-2-HR r1i1p1f1 ssp585
# Directory already exists!
# check jobid: 44235576
# spool jobid: 44235577
# run jobid: 44235578
#
#
# MPI-ESM1-2-HR r1i1p1f1 ssp370
# check jobid: 44235579
# spool jobid: 44235580
# run jobid: 44235581
#
#
# MPI-ESM1-2-HR r4i1p1f1 ssp370
# check jobid: 44235582
# spool jobid: 44235583
# run jobid: 44235584
#
#
# MPI-ESM1-2-HR r3i1p1f1 ssp370
# check jobid: 44235585
# spool jobid: 44235586
# run jobid: 44235587
#
#
# MPI-ESM1-2-HR r9i1p1f1 ssp370
# check jobid: 44235588
# spool jobid: 44235589
# run jobid: 44235590
#
#
# MPI-ESM1-2-HR r8i1p1f1 ssp370
# check jobid: 44235591
# spool jobid: 44235592
# run jobid: 44235593
#
#
# MPI-ESM1-2-HR r10i1p1f1 ssp370
# check jobid: 44235594
# spool jobid: 44235595
# run jobid: 44235596
#
#
# MPI-ESM1-2-HR r7i1p1f1 ssp370
# check jobid: 44235597
# spool jobid: 44235598
# run jobid: 44235599
#
#
# MPI-ESM1-2-HR r6i1p1f1 ssp370
# check jobid: 44235600
# spool jobid: 44235601
# run jobid: 44235602
#
#
# TaiESM1 r1i1p1f1 ssp245
# check jobid: 44235603
# spool jobid: 44235604
# run jobid: 44235605
#
#
# TaiESM1 r1i1p1f1 ssp370
# check jobid: 44235606
# spool jobid: 44235607
# run jobid: 44235608
#
#
# HadGEM3-GC31-LL r2i1p1f3 ssp585
# check jobid: 44235609
# spool jobid: 44235611
# run jobid: 44235612
#
#
# HadGEM3-GC31-LL r1i1p1f3 ssp245
# check jobid: 44235613
# spool jobid: 44235614
# run jobid: 44235615
#
#
# HadGEM3-GC31-LL r1i1p1f3 ssp585
# check jobid: 44235616
# spool jobid: 44235620
# run jobid: 44235621
#
#
# HadGEM3-GC31-LL r3i1p1f3 ssp585
# check jobid: 44235622
# spool jobid: 44235623
# run jobid: 44235624
#
#
# EC-Earth3-Veg r2i1p1f1 ssp245
# check jobid: 44235625
# spool jobid: 44235626
# run jobid: 44235627
#
#
# EC-Earth3-Veg r2i1p1f1 ssp585
# check jobid: 44235628
# spool jobid: 44235629
# run jobid: 44235630
#
#
# EC-Earth3-Veg r2i1p1f1 ssp370
# check jobid: 44235631
# spool jobid: 44235632
# run jobid: 44235633
#
#
# EC-Earth3-Veg r5i1p1f1 ssp245
# check jobid: 44235634
# spool jobid: 44235635
# run jobid: 44235636
#
#
# EC-Earth3-Veg r1i1p1f1 ssp245
# check jobid: 44235637
# spool jobid: 44235638
# run jobid: 44235639
#
#
# EC-Earth3-Veg r1i1p1f1 ssp585
# check jobid: 44235640
# spool jobid: 44235642
# run jobid: 44235643
#
#
# EC-Earth3-Veg r1i1p1f1 ssp370
# check jobid: 44235644
# spool jobid: 44235645
# run jobid: 44235646
#
#
# EC-Earth3-Veg r4i1p1f1 ssp245
# check jobid: 44235647
# spool jobid: 44235648
# run jobid: 44235649
#
#
# EC-Earth3-Veg r4i1p1f1 ssp585
# check jobid: 44235650
# spool jobid: 44235653
# run jobid: 44235654
#
#
# EC-Earth3-Veg r4i1p1f1 ssp370
# check jobid: 44235655
# spool jobid: 44235656
# run jobid: 44235658
#
#
# EC-Earth3-Veg r3i1p1f1 ssp245
# check jobid: 44235660
# spool jobid: 44235662
# run jobid: 44235663
#
#
# EC-Earth3-Veg r3i1p1f1 ssp585
# check jobid: 44235664
# spool jobid: 44235667
# run jobid: 44235668
#
#
# EC-Earth3-Veg r3i1p1f1 ssp370
# check jobid: 44235669
# spool jobid: 44235674
# run jobid: 44235675
#
#
# CNRM-CM6-1 r1i1p1f2 ssp245
# check jobid: 44235676
# spool jobid: 44235682
# run jobid: 44235683
#
#
# CNRM-CM6-1 r1i1p1f2 ssp585
# check jobid: 44235684
# spool jobid: 44235685
# run jobid: 44235686
#
#
# CNRM-CM6-1 r1i1p1f2 ssp370
# check jobid: 44235687
# spool jobid: 44235691
# run jobid: 44235692
#
#
# FGOALS-g3 r5i1p1f1 ssp370
# check jobid: 44235693
# spool jobid: 44235701
# run jobid: 44235702
#
#
# FGOALS-g3 r1i1p1f1 ssp245
# check jobid: 44235703
# spool jobid: 44235713
# run jobid: 44235715
#
#
# FGOALS-g3 r1i1p1f1 ssp585
# check jobid: 44235716
# spool jobid: 44235723
# run jobid: 44235725
#
#
# FGOALS-g3 r1i1p1f1 ssp370
# check jobid: 44235727
# spool jobid: 44235751
# run jobid: 44235753
#
#
# FGOALS-g3 r4i1p1f1 ssp245
# check jobid: 44235756
# spool jobid: 44235771
# run jobid: 44235772
#
#
# FGOALS-g3 r4i1p1f1 ssp585
# check jobid: 44235773
# spool jobid: 44235775
# run jobid: 44235776
#
#
# FGOALS-g3 r4i1p1f1 ssp370
# check jobid: 44235777
# spool jobid: 44235778
# run jobid: 44235779
#
#
# FGOALS-g3 r3i1p1f1 ssp245
# check jobid: 44235780
# spool jobid: 44235781
# run jobid: 44235782
#
#
# FGOALS-g3 r3i1p1f1 ssp585
# check jobid: 44235783
# spool jobid: 44235784
# run jobid: 44235785
#
#
# FGOALS-g3 r3i1p1f1 ssp370
# check jobid: 44235786
# spool jobid: 44235787
# run jobid: 44235788
#
#
# HadGEM3-GC31-MM r2i1p1f3 ssp585
# check jobid: 44235789
# spool jobid: 44235790
# run jobid: 44235791
#
#
# HadGEM3-GC31-MM r1i1p1f3 ssp585
# check jobid: 44235793
# spool jobid: 44235794
# run jobid: 44235795
#
#
# MIROC6 r2i1p1f1 ssp245
# check jobid: 44235796
# spool jobid: 44235799
# run jobid: 44235800
#
#
# MIROC6 r2i1p1f1 ssp585
# check jobid: 44235801
# spool jobid: 44235802
# run jobid: 44235803
#
#
# MIROC6 r2i1p1f1 ssp370
# check jobid: 44235804
# spool jobid: 44235807
# run jobid: 44235808
#
#
# MIROC6 r5i1p1f1 ssp585
# check jobid: 44235809
# spool jobid: 44235810
# run jobid: 44235811
#
#
# MIROC6 r1i1p1f1 ssp245
# check jobid: 44235812
# spool jobid: 44235814
# run jobid: 44235815
#
#
# MIROC6 r1i1p1f1 ssp585
# check jobid: 44235816
# spool jobid: 44235817
# run jobid: 44235818
#
#
# MIROC6 r1i1p1f1 ssp370
# check jobid: 44235819
# spool jobid: 44235820
# run jobid: 44235821
#
#
# MIROC6 r4i1p1f1 ssp585
# check jobid: 44235822
# spool jobid: 44235825
# run jobid: 44235826
#
#
# MIROC6 r3i1p1f1 ssp245
# check jobid: 44235827
# spool jobid: 44235828
# run jobid: 44235830
#
#
# MIROC6 r3i1p1f1 ssp585
# check jobid: 44235831
# spool jobid: 44235835
# run jobid: 44235837
#
#
# MIROC6 r3i1p1f1 ssp370
# check jobid: 44235838
# spool jobid: 44235839
# run jobid: 44235840
#
#
# CNRM-ESM2-1 r1i1p1f2 ssp245
# check jobid: 44235841
# spool jobid: 44235842
# run jobid: 44235843
#
#
# CNRM-ESM2-1 r1i1p1f2 ssp585
# Directory already exists!
# check jobid: 44235844
# spool jobid: 44235845
# run jobid: 44235846
#
#
# CNRM-ESM2-1 r1i1p1f2 ssp370
# check jobid: 44235847
# spool jobid: 44235849
# run jobid: 44235850
#
#
# NorESM2-MM r2i1p1f1 ssp245
# check jobid: 44235851
# spool jobid: 44235859
# run jobid: 44235860
#
#
# NorESM2-MM r1i1p1f1 ssp245
# check jobid: 44235861
# spool jobid: 44235862
# run jobid: 44235863
#
#
# NorESM2-MM r1i1p1f1 ssp585
# Directory already exists!
# check jobid: 44235864
# spool jobid: 44235865
# run jobid: 44235866
#
#
# NorESM2-MM r1i1p1f1 ssp370
# check jobid: 44235867
# spool jobid: 44235868
# run jobid: 44235869
#
#
# MRI-ESM2-0 r2i1p1f1 ssp370
# check jobid: 44235870
# spool jobid: 44235871
# run jobid: 44235872
#
#
# MRI-ESM2-0 r5i1p1f1 ssp370
# check jobid: 44235873
# spool jobid: 44235874
# run jobid: 44235875
#
#
# MRI-ESM2-0 r1i1p1f1 ssp245
# check jobid: 44235876
# spool jobid: 44235877
# run jobid: 44235878
#
#
# MRI-ESM2-0 r1i1p1f1 ssp585
# Directory already exists!
# check jobid: 44235879
# spool jobid: 44235880
# run jobid: 44235881
#
#
# MRI-ESM2-0 r1i1p1f1 ssp370
# check jobid: 44235882
# spool jobid: 44235883
# run jobid: 44235884
#
#
# MRI-ESM2-0 r4i1p1f1 ssp370
# check jobid: 44235885
# spool jobid: 44235886
# run jobid: 44235887
#
#
# MRI-ESM2-0 r3i1p1f1 ssp370
# check jobid: 44235888
# spool jobid: 44235889
# run jobid: 44235890

# %%
############################
# LOCA projections: MID
############################
# Spin up
spinup_start = ""
spinup_end = ""
spinup_loops = ""
state_id = ""

# Mid
time_id = 1

for model_info in model_infos[1:]:
    print(model_info['model'])

    sim_ID = f"{ensemble}_{model_info['model']}_{model_info['member']}_{ssp}_{run_IDs[time_id]}"

    run_WBM(
        run_type="model",
        main_path=main_path,
        sim_ID=sim_ID,
        model_info=model_info,
        project_ID=project_ID,
        
        
        run_start=run_starts[time_id],
        run_end=run_ends[time_id],
        spinup_start=spinup_start,
        spinup_end=spinup_end,
        spinup_loops=spinup_loops,
        state_id = f"{ensemble}_{model_info['model']}_{model_info['member']}_{ssp}_{run_IDs[time_id-1]}",
        output_vars=output_vars,
        pet_method=pet_method,
        airT_primary="XXX",
        airT_secondary="XXX",
        airT_min=f"{sim_ID}_tasmin_daily.init",
        airT_max=f"{sim_ID}_tasmax_daily.init",
        precip_primary=f"{sim_ID}_pr_daily.init",
        precip_secondary="",
        cloudFr_primary=cloudFr_primary,
        windU_primary="",
        windV_primary="",
        humidity_primary="",
        albedo_primary="",
        rootingDepth=rootingDepth,
        soilAWC=soilAWC,
        canopyHt=canopyHt,
        lai=lai,
        land_collapse=land_collapse,
        crop_area_frac=crop_area_frac,
        crop_area_frac_patch="",
        crop_par=crop_par,
        crop_par_patch=""
    )
    print('\n')
# Out:
# BCC-CSM2-MR
# check jobid: 44157151
# spool jobid: 44157177
# run jobid: 44157178
#
#
# CNRM-ESM2-1
# check jobid: 44157181
# spool jobid: 44157195
# run jobid: 44157196
#
#
# MPI-ESM1-2-HR
# check jobid: 44157198
# spool jobid: 44157218
# run jobid: 44157219
#
#
# MRI-ESM2-0
# check jobid: 44157222
# spool jobid: 44157266
# run jobid: 44157267
#
#
# NorESM2-MM
# check jobid: 44157268
# spool jobid: 44157299
# run jobid: 44157301

# %%
############################
# LOCA projections: LATE
############################
# Spin up
spinup_start=""
spinup_end=""
spinup_loops = ""
state_id = ""

# Late
time_id = 2

for model_info in model_infos:
    print(model_info['model'])

    sim_ID = f"{ensemble}_{model_info['model']}_{model_info['member']}_{ssp}_{run_IDs[time_id]}"

    run_WBM(
        run_type="model",
        main_path=main_path,
        sim_ID=sim_ID,
        model_info=model_info,
        project_ID=project_ID,
        
        
        run_start=run_starts[time_id],
        run_end=run_ends[time_id],
        spinup_start=spinup_start,
        spinup_end=spinup_end,
        spinup_loops=spinup_loops,
        state_id = f"{ensemble}_{model_info['model']}_{model_info['member']}_{ssp}_{run_IDs[time_id-1]}",
        output_vars=output_vars,
        pet_method=pet_method,
        airT_primary="XXX",
        airT_secondary="XXX",
        airT_min=f"{sim_ID}_tasmin_daily.init",
        airT_max=f"{sim_ID}_tasmax_daily.init",
        precip_primary=f"{sim_ID}_pr_daily.init",
        precip_secondary="",
        cloudFr_primary=cloudFr_primary,
        windU_primary="",
        windV_primary="",
        humidity_primary="",
        albedo_primary="",
        rootingDepth=rootingDepth,
        soilAWC=soilAWC,
        canopyHt=canopyHt,
        lai=lai,
        land_collapse=land_collapse,
        crop_area_frac=crop_area_frac,
        crop_area_frac_patch="",
        crop_par=crop_par,
        crop_par_patch=""
    )
    print('\n')
# Out:
# ACCESS-CM2
# check jobid: 44162124
# spool jobid: 44162125
# run jobid: 44162127
#
#
# BCC-CSM2-MR
# check jobid: 44162129
# spool jobid: 44162139
# run jobid: 44162141
#
#
# CNRM-ESM2-1
# check jobid: 44162143
# spool jobid: 44162167
# run jobid: 44162169
#
#
# MPI-ESM1-2-HR
# check jobid: 44162172
# spool jobid: 44162198
# run jobid: 44162200
#
#
# MRI-ESM2-0
# check jobid: 44162202
# spool jobid: 44162236
# run jobid: 44162238
#
#
# NorESM2-MM
# check jobid: 44162240
# spool jobid: 44162254
# run jobid: 44162256

# %% [markdown]
# ### OakRidge

# %%
# Get run infos
run_info = df_climate_drivers[(df_climate_drivers.ensemble == "OakRidge") & (df_climate_drivers.ssp == "ssp585")].copy()

# Constants
ensemble = "OakRidge"
vars_ = ["tmax","tmin","prcp"]

# %%
#####################
# OakRidge hindcasts
#####################
for _, info in run_info.iterrows():
        
    print(f"{model} {method}")
    sim_ID = f"{info['ensemble']}_{info['model']}_{info['member']}_{info['method']}_{info['ssp']}"
        
    run_WBM(
        run_type="model",
        main_path=main_path,
        sim_ID=sim_ID,
        run_info=info,
        project_ID=project_ID,
        run_start=run_start,
        run_end=run_end,
        spinup_start=spinup_start,
        spinup_end=spinup_end,
        spinup_loops=spinup_loops,
        state_id=state_id,
        output_vars=output_vars,
        pet_method=pet_method,
        vars_=vars_,
        airT_primary="XXX",
        airT_secondary="XXX",
        airT_min=f"{sim_ID}_tmin_daily.init",
        airT_max=f"{sim_ID}_tmax_daily.init",
        precip_primary=f"{sim_ID}_prcp_daily.init",
        precip_secondary="",
        cloudFr_primary=cloudFr_primary,
        windU_primary="",
        windV_primary="",
        humidity_primary="",
        albedo_primary="",
        rootingDepth=rootingDepth,
        soilAWC=soilAWC,
        canopyHt=canopyHt,
        lai=lai,
        land_collapse=land_collapse,
        crop_area_frac=crop_area_frac,
        crop_area_frac_patch="",
        crop_par=crop_par,
        crop_par_patch="",
    )
    print('\n')
