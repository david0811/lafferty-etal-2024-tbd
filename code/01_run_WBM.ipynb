# %%
from run_WBM import run_WBM

# %%
######################
# Common to all runs #
######################

# Main directory
main_path = "/gpfs/group/kaf26/default/dcl5300/wbm_soilM_crop_uc_lafferty-etal-2024-tbd_DATA/"

# Output variables
output_vars=["soilMoist", "soilMoistFrac"]

# PET method
pet_method = "Hamon"

# Rooting depth
rootingDepth = "Effective_Rooting_Depth_mod.init"

# Available water capacity
soilAWC = "/gpfs/group/kaf26/default/private/WBM_data/squam.sr.unh.edu/US_CDL_v3_data/soil/SSURGO_SoilData_awc_frac_mm_m_CONUS_1km.tif"

# Canopy height
canopyHt = "/gpfs/group/kaf26/default/private/WBM_data/squam.sr.unh.edu/US_CDL_v3_data/canopy/Simard_Pinto_3DGlobalVeg_JGR_10km.tif"

# Leaf Area Index
lai = "merra2_lai2_dc.init"

# Lan collapse method
land_collapse="average"

# Project ID
project_ID = "PCHES_crop_yield_UC_climate_param"

# %% [markdown]
# # Historical runs (observational data)

# %%
#######################
# Common to hist runs #
#######################

# Simulation length
run_start="1980-01-01"
run_end="2014-12-31"

# Spunup
spinup_start="1981-01-01"
spinup_end="1981-12-31"
spinup_loops = 5

# Cloud fraction
cloudFr_primary = "merra2_cldtot_d.init"

# Crop parameter file
crop_par = "CDL-US-M_CropParameters_hist.csv"

# Crop area timeseries
crop_area_frac="cdl_cropland_hist.init"

# %%
########
# GMFD #
########
run_WBM(
    run_type="obs",
    main_path=main_path,
    sim_ID="OBS_GMFD_historical",
    model_info={},
    project_ID=project_ID,
    perform_spool=True,
    perform_run=True,
    run_start=run_start,
    run_end=run_end,
    spinup_start=spinup_start,
    spinup_end=spinup_end,
    spinup_loops=spinup_loops,
    output_vars=output_vars,
    pet_method=pet_method,
    airT_primary="GMFD_tas_daily.init",
    airT_secondary="",
    airT_min="",
    airT_max="",
    precip_primary="GMFD_prcp_daily.init",
    precip_secondary="",
    cloudFr_primary=cloudFr_primary,
    windU_primary="",
    windV_primary="",
    humidity_primary="",
    albedo_primary="",
    rootingDepth=rootingDepth,
    soilAWC=soilAWC,
    canopyHt=canopyHt,
    lai=lai,
    land_collapse=land_collapse,
    crop_area_frac=crop_area_frac,
    crop_area_frac_patch="",
    crop_par=crop_par,
    crop_par_patch=""
)
# Out:
# Directory already exists!
# Check already completed.
# spool jobid: 44083699
# run jobid: 44083702

# %%
###########
# Livneh2 #
###########
run_WBM(
    run_type="obs",
    main_path=main_path,
    sim_ID="OBS_Livneh2_historical",
    model_info={},
    project_ID=project_ID,
    run_start=run_start,
    run_end=run_end,
    spinup_start=spinup_start,
    spinup_end=spinup_end,
    spinup_loops=spinup_loops,
    output_vars=output_vars,
    pet_method=pet_method,
    airT_primary="XXX",
    airT_secondary="XXX",
    airT_min="Livneh2_Tmax_daily.init",
    airT_max="Livneh2_Tmin_daily.init",
    precip_primary="Livneh2_precip_daily.init",
    precip_secondary="",
    cloudFr_primary=cloudFr_primary,
    windU_primary="",
    windV_primary="",
    humidity_primary="",
    albedo_primary="",
    rootingDepth=rootingDepth,
    soilAWC=soilAWC,
    canopyHt=canopyHt,
    lai=lai,
    land_collapse=land_collapse,
    crop_area_frac=crop_area_frac,
    crop_area_frac_patch="",
    crop_par=crop_par,
    crop_par_patch="",
    
)
# Out:
# check jobid: 44048267
# spool jobid: 44048281
# run jobid: 44048282

# %%
#########
# PRISM #
#########
run_start="1981-01-01" # only PRISM

run_WBM(
    run_type="obs",
    main_path=main_path,
    sim_ID="OBS_PRISM_historical",
    model_info={},
    project_ID=project_ID,
    run_start=run_start,
    run_end=run_end,
    spinup_start=spinup_start,
    spinup_end=spinup_end,
    spinup_loops=spinup_loops,
    output_vars=output_vars,
    pet_method=pet_method,
    airT_primary="PRISM_tmean_4kmD2_d.init",
    airT_secondary="",
    airT_min="",
    airT_max="",
    precip_primary="PRISM_ppt_4kmD2_d.init",
    precip_secondary="",
    cloudFr_primary=cloudFr_primary,
    windU_primary="",
    windV_primary="",
    humidity_primary="",
    albedo_primary="",
    rootingDepth=rootingDepth,
    soilAWC=soilAWC,
    canopyHt=canopyHt,
    lai=lai,
    land_collapse=land_collapse,
    crop_area_frac=crop_area_frac,
    crop_area_frac_patch="",
    crop_par=crop_par,
    crop_par_patch="",
    
)
# Out:
# check jobid: 44050217
# spool jobid: 44050230
# run jobid: 44050231

# %%
###########
# gridMET #
###########
run_WBM(
    run_type="obs",
    main_path=main_path,
    sim_ID="OBS_gridMET_historical",
    model_info={},
    project_ID=project_ID,
    run_start=run_start,
    run_end=run_end,
    spinup_start=spinup_start,
    spinup_end=spinup_end,
    spinup_loops=spinup_loops,
    output_vars=output_vars,
    pet_method=pet_method,
    airT_primary="XXX",
    airT_secondary="XXX",
    airT_min="gridMET_tmmn_daily.init",
    airT_max="gridMET_tmmx_daily.init",
    precip_primary="gridMET_pr_daily.init",
    precip_secondary="",
    cloudFr_primary=cloudFr_primary,
    windU_primary="",
    windV_primary="",
    humidity_primary="",
    albedo_primary="",
    rootingDepth=rootingDepth,
    soilAWC=soilAWC,
    canopyHt=canopyHt,
    lai=lai,
    land_collapse=land_collapse,
    crop_area_frac=crop_area_frac,
    crop_area_frac_patch="",
    crop_par=crop_par,
    crop_par_patch="",
    
)
# Out:
# check jobid: 44048293
# spool jobid: 44048304
# run jobid: 44048306

# %% [markdown]
# # Hindcast runs (climate models)

# %%
#######################
# Common to hist runs #
#######################

# Simulation length
run_start="1981-01-01"
run_end="2014-12-31"

# Spunup
spinup_start="1981-01-01"
spinup_end="1981-12-31"
spinup_loops = 5

# Cloud fraction
cloudFr_primary = "merra2_cldtot_d.init"

# Crop parameter file
crop_par = "CDL-US-M_CropParameters_hist.csv"

# Crop area timeseries
crop_area_frac="cdl_cropland_hist.init"

# %% [markdown]
# ### NEX-GDDP

# %%
ensemble = "NEX-GDDP"
ssp = "historical"
vars_ = ["tas", "pr"]

model_infos = [{"model": "ACCESS-CM2", "member": "r1i1p1f1", "grid": "gn", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "BCC-CSM2-MR", "member": "r1i1p1f1", "grid": "gn", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "CNRM-ESM2-1", "member": "r1i1p1f2", "grid": "gr", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "MPI-ESM1-2-HR", "member": "r1i1p1f1", "grid": "gn", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "MRI-ESM2-0", "member": "r1i1p1f1", "grid": "gn", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
              {"model": "NorESM2-MM", "member": "r1i1p1f1", "grid": "gn", "ensemble": ensemble, "ssp":ssp, "vars":vars_}]

# %%
ensemble = "NEX-GDDP"
ssp = "historical"
vars_ = ["tas", "pr"]

model_infos = [{"model": "ACCESS-CM2", "member": "r1i1p1f1", "grid": "gn", "ensemble": ensemble, "ssp":ssp, "vars":vars_}]

# %%
##################
# NEX hindcasts
##################
for model_info in model_infos:
    print(model_info['model'])
    
    sim_ID = f"{ensemble}_{model_info['model']}_{model_info['member']}_{ssp}"
    
    run_WBM(
        run_type="model",
        main_path=main_path,
        sim_ID=sim_ID,
        model_info=model_info,
        project_ID=project_ID,
        perform_spool=True,
        perform_run=True,
        run_start=run_start,
        run_end=run_end,
        spinup_start=spinup_start,
        spinup_end=spinup_end,
        spinup_loops=spinup_loops,
        output_vars=output_vars,
        pet_method=pet_method,
        airT_primary=f"{sim_ID}_tas_daily.init",
        airT_secondary="",
        airT_min="",
        airT_max="",
        precip_primary=f"{sim_ID}_pr_daily.init",
        precip_secondary="",
        cloudFr_primary=cloudFr_primary,
        windU_primary="",
        windV_primary="",
        humidity_primary="",
        albedo_primary="",
        rootingDepth=rootingDepth,
        soilAWC=soilAWC,
        canopyHt=canopyHt,
        lai=lai,
        land_collapse=land_collapse,
        crop_area_frac=crop_area_frac,
        crop_area_frac_patch="",
        crop_par=crop_par,
        crop_par_patch="",
    )
    print('\n')
# Out:
# ACCESS-CM2
# check jobid: 44084130
# spool jobid: 44084159
# run jobid: 44084161

# %% [markdown]
# ### LOCA2

# %%
ensemble = "LOCA2"
ssp = "historical"
vars_ = ["tasmax","tasmin","pr"]

model_infos = [{"model": "ACCESS-CM2", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "BCC-CSM2-MR", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "CNRM-ESM2-1", "member": "r1i1p1f2", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "MPI-ESM1-2-HR", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "MRI-ESM2-0", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
              {"model": "NorESM2-MM", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_}]

# %%
##################
# LOCA2 hindcasts
##################
for model_info in model_infos:
    print(model_info['model'])

    sim_ID = f"{ensemble}_{model_info['model']}_{model_info['member']}_{ssp}"
    
    run_WBM(
        run_type="model",
        main_path=main_path,
        sim_ID=sim_ID,
        model_info=model_info,
        project_ID=project_ID,
        perform_spool=True,
        perform_run=True,
        run_start=run_start,
        run_end=run_end,
        spinup_start=spinup_start,
        spinup_end=spinup_end,
        spinup_loops=spinup_loops,
        output_vars=output_vars,
        pet_method=pet_method,
        airT_primary="XXX",
        airT_secondary="XXX",
        airT_min=f"{sim_ID}_tasmin_daily.init",
        airT_max=f"{sim_ID}_tasmax_daily.init",
        precip_primary=f"{sim_ID}_pr_daily.init",
        precip_secondary="",
        cloudFr_primary=cloudFr_primary,
        windU_primary="",
        windV_primary="",
        humidity_primary="",
        albedo_primary="",
        rootingDepth=rootingDepth,
        soilAWC=soilAWC,
        canopyHt=canopyHt,
        lai=lai,
        land_collapse=land_collapse,
        crop_area_frac=crop_area_frac,
        crop_area_frac_patch="",
        crop_par=crop_par,
        crop_par_patch=""
    )
    print('\n')
# Out:
# ACCESS-CM2
# check jobid: 44048841
# spool jobid: 44048868
# run jobid: 44048870
#
#
# BCC-CSM2-MR
# check jobid: 44048871
# spool jobid: 44048889
# run jobid: 44048891
#
#
# CNRM-ESM2-1
# check jobid: 44048892
# spool jobid: 44048898
# run jobid: 44048899
#
#
# MPI-ESM1-2-HR
# check jobid: 44048901
# spool jobid: 44048917
# run jobid: 44048919
#
#
# MRI-ESM2-0
# check jobid: 44048921
# spool jobid: 44048944
# run jobid: 44048945
#
#
# NorESM2-MM
# check jobid: 44048946
# spool jobid: 44048968
# run jobid: 44048970

# %% [markdown]
# ### OakRidge

# %%
#######################
# Common to hist runs #
#######################

# Simulation length
run_start="1981-01-01"
run_end="1982-12-31"

# Spunup
spinup_start="1981-01-01"
spinup_end="1981-12-31"
spinup_loops = 1

# Cloud fraction
cloudFr_primary = "merra2_cldtot_d.init"

# Crop parameter file
crop_par = "CDL-US-M_CropParameters_hist.csv"

# Crop area timeseries
crop_area_frac="cdl_cropland_hist.init"

# %%
ensemble = "OakRidge"
ssp = "historical"
vars_ = ["tmax","tmin","prcp"]
methods = ["DBCCA_Daymet"]

model_infos = [{"model": "NorESM2-MM", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_}]

# %%
#####################
# OakRidge hindcasts
#####################
# Loop through models
for model_info in model_infos:
    # Loop through methods
    for method in methods:
        # Update method
        model_info_upd = model_info
        model_info_upd["method"] = method
        print(model_info_upd["model"], method)
        # Simulation ID
        sim_ID = f"{ensemble}_{model_info_upd['model']}_{model_info_upd['member']}_{model_info_upd['method']}_{ssp}"
        # Run
        run_WBM(
            run_type="model",
            main_path=main_path,
            sim_ID=sim_ID,
            model_info=model_info,
            project_ID=project_ID,
            perform_spool=True,
            perform_run=True,
            run_start=run_start,
            run_end=run_end,
            spinup_start=spinup_start,
            spinup_end=spinup_end,
            spinup_loops=spinup_loops,
            output_vars=output_vars,
            pet_method=pet_method,
            airT_primary="XXX",
            airT_secondary="XXX",
            airT_min=f"{sim_ID}_tmin_daily.init",
            airT_max=f"{sim_ID}_tmax_daily.init",
            precip_primary=f"{sim_ID}_prcp_daily.init",
            precip_secondary="",
            cloudFr_primary=cloudFr_primary,
            windU_primary="",
            windV_primary="",
            humidity_primary="",
            albedo_primary="",
            rootingDepth=rootingDepth,
            soilAWC=soilAWC,
            canopyHt=canopyHt,
            lai=lai,
            land_collapse=land_collapse,
            crop_area_frac=crop_area_frac,
            crop_area_frac_patch="",
            crop_par=crop_par,
            crop_par_patch="",
        )
        print('\n')
# Out:
# NorESM2-MM DBCCA_Daymet
# check jobid: 44083106
# spool jobid: 44083108
# run jobid: 44083109

# %%
ensemble = "OakRidge"
ssp = "historical"
vars_ = ["tmax","tmin","prcp"]
methods = ["RegCM_Livneh"]

model_infos = [{"model": "NorESM2-MM", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_}]

# %%
#####################
# OakRidge hindcasts
#####################
for model_info in model_infos:
    for method in methods:
        model_info_upd = model_info
        model_info_upd["method"] = method
        print(model_info_upd["model"], method)
        run_WBM(
            run_type="model",
            main_path=main_path,
            sim_ID=f"{ensemble}_{model_info_upd['model']}_{model_info_upd['member']}_{model_info_upd['method']}_{ssp}",
            model_info=model_info,
            project_ID=project_ID,
            perform_spool=True,
            perform_run=True,
            run_start=run_start,
            run_end=run_end,
            spinup_start=spinup_start,
            spinup_end=spinup_end,
            spinup_loops=spinup_loops,
            output_vars=output_vars,
            pet_method=pet_method,
            airT_primary="XXX",
            airT_secondary="XXX",
            airT_min=f"{model_info_upd['ensemble']}_tmin_daily.init",
            # airT_max=f"{model_info_upd['ensemble']}_tmax_daily.init",
            precip_primary=f"{model_info_upd['ensemble']}_prcp_daily.init",
            precip_secondary="",
            cloudFr_primary=cloudFr_primary,
            windU_primary="",
            windV_primary="",
            humidity_primary="",
            albedo_primary="",
            rootingDepth=rootingDepth,
            soilAWC=soilAWC,
            canopyHt=canopyHt,
            lai=lai,
            land_collapse=land_collapse,
            crop_area_frac=crop_area_frac,
            crop_area_frac_patch="",
            crop_par=crop_par,
            crop_par_patch="",
            
        )
        print('\n')
# Out:
# NorESM2-MM RegCM_Livneh
# check jobid: 44076119

# %%
ensemble = "OakRidge"
ssp = "historical"
vars_ = ["tmax","tmin","prcp"]
methods = ["DBCCA_Daymet", "RegCM_Daymet", "DBCCA_Livneh", "RegCM_Livneh"]

model_infos = [{"model": "ACCESS-CM2", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "BCC-CSM2-MR", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "CNRM-ESM2-1", "member": "r1i1p1f2", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "MPI-ESM1-2-HR", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "MRI-ESM2-0", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
              {"model": "NorESM2-MM", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_}]

# %%
#####################
# OakRidge hindcasts
#####################
for model_info in model_infos:
    for method in methods:
        model_info_upd = model_info
        model_info_upd["method"] = method
        print(model_info_upd["model"], method)
        run_WBM(
            run_type="model",
            main_path=main_path,
            sim_ID=f"{ensemble}_{model_info_upd['model']}_{model_info_upd['member']}_{model_info_upd['method']}_{ssp}",
            model_info=model_info,
            project_ID=project_ID,
            run_start=run_start,
            run_end=run_end,
            spinup_start=spinup_start,
            spinup_end=spinup_end,
            spinup_loops=spinup_loops,
            output_vars=output_vars,
            pet_method=pet_method,
            airT_primary="XXX",
            airT_secondary="XXX",
            airT_min=f"{model_info_upd['ensemble']}_tmin_daily.init",
            airT_max=f"{model_info_upd['ensemble']}_tmax_daily.init",
            precip_primary=f"{model_info_upd['ensemble']}_prcp_daily.init",
            precip_secondary="",
            cloudFr_primary=cloudFr_primary,
            windU_primary="",
            windV_primary="",
            humidity_primary="",
            albedo_primary="",
            rootingDepth=rootingDepth,
            soilAWC=soilAWC,
            canopyHt=canopyHt,
            lai=lai,
            land_collapse=land_collapse,
            crop_area_frac=crop_area_frac,
            crop_area_frac_patch="",
            crop_par=crop_par,
            crop_par_patch="",
            
        )
        print('\n')

# %% [markdown]
# # Projections

# %%
#######################
# Constant for all runs
#######################

# Main directory
main_path = "/gpfs/group/kaf26/default/dcl5300/wbm_soilM_crop_uc_lafferty-etal-2024-tbd_DATA/"

# Simulation length
run_start="2015-01-01"
run_end="2099-12-31"

# Spunup
spinup_start="2015-01-01"
spinup_end="2015-12-31"
spinup_loops = 5

# Output variables
output_vars=["soilMoist", "soilMoistFrac"]

# PET method
pet_method = "Hamon"

# Cloud fraction
cloudFr_primary = "merra2_cldtot_dc.init"

# Rooting depth
rootingDepth = "Effective_Rooting_Depth_mod.init"

# Available water capacity
soilAWC = "/gpfs/group/kaf26/default/private/WBM_data/squam.sr.unh.edu/US_CDL_v3_data/soil/SSURGO_SoilData_awc_frac_mm_m_CONUS_1km.tif"

# Canopy height
canopyHt = "/gpfs/group/kaf26/default/private/WBM_data/squam.sr.unh.edu/US_CDL_v3_data/canopy/Simard_Pinto_3DGlobalVeg_JGR_10km.tif"

# Lan collapse method
land_collapse="average"

# Crop parameter file
crop_par = "CDL-US-M_CropParameters_proj.csv"

# Crop area timeseries
crop_area_frac="cdl_cropland_proj.init"

# Project ID
project_ID = "PCHES_crop_yield_UC_climate_param"

# %% [markdown]
# ### NEX-GDDP

# %%
ensemble = "NEX-GDDP"
ssp = "ssp585"
vars_ = ["tas", "pr"]

model_infos = [{"model": "ACCESS-CM2", "member": "r1i1p1f1", "grid": "gn", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "BCC-CSM2-MR", "member": "r1i1p1f1", "grid": "gn", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "CNRM-ESM2-1", "member": "r1i1p1f2", "grid": "gr", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "MPI-ESM1-2-HR", "member": "r1i1p1f1", "grid": "gn", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "MRI-ESM2-0", "member": "r1i1p1f1", "grid": "gn", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
              {"model": "NorESM2-MM", "member": "r1i1p1f1", "grid": "gn", "ensemble": ensemble, "ssp":ssp, "vars":vars_}]

# %%
##################
# NEX projections
##################
for model_info in model_infos[4:]:
    print(model_info['model'])
    run_WBM(
        run_type="model",
        main_path=main_path,
        sim_ID=f"{ensemble}_{model_info['model']}_{model_info['member']}_{ssp}",
        model_info=model_info,
        project_ID=project_ID,
        run_start=run_start,
        run_end=run_end,
        spinup_start=spinup_start,
        spinup_end=spinup_end,
        spinup_loops=spinup_loops,
        output_vars=output_vars,
        pet_method=pet_method,
        airT_primary=f"{model_info['ensemble']}_tas_daily.init",
        airT_secondary="",
        airT_min="",
        airT_max="",
        precip_primary=f"{model_info['ensemble']}_pr_daily.init",
        precip_secondary="",
        cloudFr_primary=cloudFr_primary,
        windU_primary="",
        windV_primary="",
        humidity_primary="",
        albedo_primary="",
        rootingDepth=rootingDepth,
        soilAWC=soilAWC,
        canopyHt=canopyHt,
        lai=lai,
        land_collapse=land_collapse,
        crop_area_frac=crop_area_frac,
        crop_area_frac_patch="",
        crop_par=crop_par,
        crop_par_patch="",
        
    )
    print('\n')
# Out:
# MRI-ESM2-0
# Directory already exists!
# check jobid: 44067755
# spool jobid: 44067759
# run jobid: 44067760
#
#
# NorESM2-MM
# check jobid: 44067761
# spool jobid: 44067764
# run jobid: 44067765
