# %%
from run_WBM import run_WBM

# %%
######################
# Common to all runs #
######################

# Main directory
main_path = "/gpfs/group/kaf26/default/dcl5300/wbm_soilM_crop_uc_lafferty-etal-2024-tbd_DATA/"

# Output variables
output_vars=["soilMoist", "soilMoistFrac"]

# PET method
pet_method = "Hamon"

# Rooting depth
rootingDepth = "Effective_Rooting_Depth_mod.init"

# Available water capacity
soilAWC = "/gpfs/group/kaf26/default/private/WBM_data/squam.sr.unh.edu/US_CDL_v3_data/soil/SSURGO_SoilData_awc_frac_mm_m_CONUS_1km.tif"

# Canopy height
canopyHt = "/gpfs/group/kaf26/default/private/WBM_data/squam.sr.unh.edu/US_CDL_v3_data/canopy/Simard_Pinto_3DGlobalVeg_JGR_10km.tif"

# Leaf Area Index
lai = "merra2_lai2_dc.init"

# Lan collapse method
land_collapse="average"

# Project ID
project_ID = "PCHES_crop_yield_UC_climate_param"

# %% [markdown]
# # Historical runs (observational data)

# %%
#######################
# Common to hist runs #
#######################

# Simulation length
run_start="1981-01-01"
run_end="2015-12-31"

# Spunup
spinup_start="1981-01-01"
spinup_end="1981-12-31"
spinup_loops = 5

# Cloud fraction
cloudFr_primary = "merra2_cldtot_d.init"

# Crop parameter file
crop_par = "CDL-US-M_CropParameters_hist.csv"

# Crop area timeseries
crop_area_frac="cdl_cropland_hist.init"

# Spooling already done
pre_spooled=True

# %%
########
# GMFD #
########
run_WBM(
    run_type="obs",
    main_path=main_path,
    sim_ID="OBS_GMFD_historical",
    model_info={},
    project_ID=project_ID,
    run_start=run_start,
    run_end=run_end,
    spinup_start=spinup_start,
    spinup_end=spinup_end,
    spinup_loops=spinup_loops,
    output_vars=output_vars,
    pet_method=pet_method,
    airT_primary="GMFD_tas_daily.init",
    airT_secondary="",
    airT_min="",
    airT_max="",
    precip_primary=f"GMFD_prcp_daily.init",
    precip_secondary="",
    cloudFr_primary=cloudFr_primary,
    windU_primary="",
    windV_primary="",
    humidity_primary="",
    albedo_primary="",
    rootingDepth=rootingDepth,
    soilAWC=soilAWC,
    canopyHt=canopyHt,
    lai=lai,
    land_collapse=land_collapse,
    crop_area_frac=crop_area_frac,
    crop_area_frac_patch="",
    crop_par=crop_par,
    crop_par_patch="",
    pre_spooled=pre_spooled
)
# Out:
# check jobid: 44024857
# spool jobid: 44024868
# run jobid: 44024869

# %%
###########
# Livneh2 #
###########
run_WBM(
    run_type="obs",
    main_path=main_path,
    sim_ID="OBS_Livneh2_historical",
    model_info={},
    project_ID=project_ID,
    run_start=run_start,
    run_end=run_end,
    spinup_start=spinup_start,
    spinup_end=spinup_end,
    spinup_loops=spinup_loops,
    output_vars=output_vars,
    pet_method=pet_method,
    airT_primary="XXX",
    airT_secondary="XXX",
    airT_min="Livneh2_Tmax_daily.init",
    airT_max="Livneh2_Tmin_daily.init",
    precip_primary="Livneh2_precip_daily.init",
    precip_secondary="",
    cloudFr_primary=cloudFr_primary,
    windU_primary="",
    windV_primary="",
    humidity_primary="",
    albedo_primary="",
    rootingDepth=rootingDepth,
    soilAWC=soilAWC,
    canopyHt=canopyHt,
    lai=lai,
    land_collapse=land_collapse,
    crop_area_frac=crop_area_frac,
    crop_area_frac_patch="",
    crop_par=crop_par,
    crop_par_patch="",
    pre_spooled=pre_spooled
)
# Out:
# check jobid: 44024870
# spool jobid: 44024983
# run jobid: 44024984

# %%
#########
# PRISM #
#########
run_WBM(
    run_type="obs",
    main_path=main_path,
    sim_ID="OBS_PRISM_historical",
    model_info={},
    project_ID=project_ID,
    run_start=run_start,
    run_end=run_end,
    spinup_start=spinup_start,
    spinup_end=spinup_end,
    spinup_loops=spinup_loops,
    output_vars=output_vars,
    pet_method=pet_method,
    airT_primary="PRISM_tmean_4kmD2_d.init",
    airT_secondary="",
    airT_min="",
    airT_max="",
    precip_primary="PRISM_ppt_4kmD2_d.init",
    precip_secondary="",
    cloudFr_primary=cloudFr_primary,
    windU_primary="",
    windV_primary="",
    humidity_primary="",
    albedo_primary="",
    rootingDepth=rootingDepth,
    soilAWC=soilAWC,
    canopyHt=canopyHt,
    lai=lai,
    land_collapse=land_collapse,
    crop_area_frac=crop_area_frac,
    crop_area_frac_patch="",
    crop_par=crop_par,
    crop_par_patch="",
    pre_spooled=pre_spooled
)
# Out:
# check jobid: 44025052
# spool jobid: 44025073
# run jobid: 44025074

# %%
###########
# gridMET #
###########
run_WBM(
    run_type="obs",
    main_path=main_path,
    sim_ID="OBS_gridMET_historical",
    model_info={},
    project_ID=project_ID,
    run_start=run_start,
    run_end=run_end,
    spinup_start=spinup_start,
    spinup_end=spinup_end,
    spinup_loops=spinup_loops,
    output_vars=output_vars,
    pet_method=pet_method,
    airT_primary="XXX",
    airT_secondary="XXX",
    airT_min="gridMET_tmmn_daily.init",
    airT_max="gridMET_tmmx_daily.init",
    precip_primary="gridMET_pr_daily.init",
    precip_secondary="",
    cloudFr_primary=cloudFr_primary,
    windU_primary="",
    windV_primary="",
    humidity_primary="",
    albedo_primary="",
    rootingDepth=rootingDepth,
    soilAWC=soilAWC,
    canopyHt=canopyHt,
    lai=lai,
    land_collapse=land_collapse,
    crop_area_frac=crop_area_frac,
    crop_area_frac_patch="",
    crop_par=crop_par,
    crop_par_patch="",
    pre_spooled=pre_spooled
)
# Out:
# check jobid: 44025075
# spool jobid: 44025088
# run jobid: 44025089

# %% [markdown]
# # Hindcast runs (climate models)

# %%
#######################
# Common to hist runs #
#######################

# Simulation length
run_start="1981-01-01"
run_end="2014-12-31"

# Spunup
spinup_start="1981-01-01"
spinup_end="1981-12-31"
spinup_loops = 5

# Cloud fraction
cloudFr_primary = "merra2_cldtot_d.init"

# Crop parameter file
crop_par = "CDL-US-M_CropParameters_hist.csv"

# Crop area timeseries
crop_area_frac="cdl_cropland_hist.init"

# Spooling already done
pre_spooled=True

# %% [markdown]
# ### NEX-GDDP

# %%
ensemble = "NEX-GDDP"
ssp = "historical"
vars_ = ["tas", "pr"]

model_infos = [{"model": "ACCESS-CM2", "member": "r1i1p1f1", "grid": "gn", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "BCC-CSM2-MR", "member": "r1i1p1f1", "grid": "gn", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "CNRM-ESM2-1", "member": "r1i1p1f2", "grid": "gr", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "MPI-ESM1-2-HR", "member": "r1i1p1f1", "grid": "gn", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "MRI-ESM2-0", "member": "r1i1p1f1", "grid": "gn", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
              {"model": "NorESM2-MM", "member": "r1i1p1f1", "grid": "gn", "ensemble": ensemble, "ssp":ssp, "vars":vars_}]

# %%
##################
# NEX hindcasts
##################
for model_info in model_infos:
    print(model_info['model'])
    run_WBM(
        run_type="model",
        main_path=main_path,
        sim_ID=f"{ensemble}_{model_info['model']}_{model_info['member']}_{ssp}",
        model_info=model_info,
        project_ID=project_ID,
        run_start=run_start,
        run_end=run_end,
        spinup_start=spinup_start,
        spinup_end=spinup_end,
        spinup_loops=spinup_loops,
        output_vars=output_vars,
        pet_method=pet_method,
        airT_primary=f"{model_info['ensemble']}_tas_daily.init",
        airT_secondary="",
        airT_min="",
        airT_max="",
        precip_primary=f"{model_info['ensemble']}_pr_daily.init",
        precip_secondary="",
        cloudFr_primary=cloudFr_primary,
        windU_primary="",
        windV_primary="",
        humidity_primary="",
        albedo_primary="",
        rootingDepth=rootingDepth,
        soilAWC=soilAWC,
        canopyHt=canopyHt,
        lai=lai,
        land_collapse=land_collapse,
        crop_area_frac=crop_area_frac,
        crop_area_frac_patch="",
        crop_par=crop_par,
        crop_par_patch="",
        pre_spooled=True
    )
    print('\n')
# Out:
# BCC-CSM2-MR
# check jobid: 44025170
# spool jobid: 44025196
# run jobid: 44025197
#
#
# CNRM-ESM2-1
# check jobid: 44025198
# spool jobid: 44025212
# run jobid: 44025213
#
#
# MPI-ESM1-2-HR
# check jobid: 44025214
# spool jobid: 44025234
# run jobid: 44025235
#
#
# MRI-ESM2-0
# check jobid: 44025236
# spool jobid: 44025250
# run jobid: 44025251
#
#
# NorESM2-MM
# check jobid: 44025252
# spool jobid: 44025259
# run jobid: 44025260

# %% [markdown]
# ### LOCA2

# %%
ensemble = "LOCA2"
ssp = "historical"
vars_ = ["tasmax","tasmin","pr"]

model_infos = [{"model": "ACCESS-CM2", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               # {"model": "BCC-CSM2-MR", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               # {"model": "CNRM-ESM2-1", "member": "r1i1p1f2", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "MPI-ESM1-2-HR", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "MRI-ESM2-0", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
              {"model": "NorESM2-MM", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_}]

# %%
##################
# LOCA2 hindcasts
##################
for model_info in model_infos:
    print(model_info['model'])
    run_WBM(
        run_type="model",
        main_path=main_path,
        sim_ID=f"{ensemble}_{model_info['model']}_{model_info['member']}_{ssp}",
        model_info=model_info,
        project_ID=project_ID,
        run_start=run_start,
        run_end=run_end,
        spinup_start=spinup_start,
        spinup_end=spinup_end,
        spinup_loops=spinup_loops,
        output_vars=output_vars,
        pet_method=pet_method,
        airT_primary="XXX",
        airT_secondary="XXX",
        airT_min=f"{model_info['ensemble']}_tasmin_daily.init",
        airT_max=f"{model_info['ensemble']}_tasmax_daily.init",
        precip_primary=f"{model_info['ensemble']}_pr_daily.init",
        precip_secondary="",
        cloudFr_primary=cloudFr_primary,
        windU_primary="",
        windV_primary="",
        humidity_primary="",
        albedo_primary="",
        rootingDepth=rootingDepth,
        soilAWC=soilAWC,
        canopyHt=canopyHt,
        lai=lai,
        land_collapse=land_collapse,
        crop_area_frac=crop_area_frac,
        crop_area_frac_patch="",
        crop_par=crop_par,
        crop_par_patch="",
        pre_spooled=True
    )
    print('\n')
# Out:
# ACCESS-CM2
# check jobid: 44025343
# spool jobid: 44025459
# run jobid: 44025460
#
#
# MPI-ESM1-2-HR
# check jobid: 44025461
# spool jobid: 44025474
# run jobid: 44025475
#
#
# MRI-ESM2-0
# check jobid: 44025476
# spool jobid: 44025511
# run jobid: 44025512
#
#
# NorESM2-MM
# check jobid: 44025515
# spool jobid: 44025573
# run jobid: 44025574

# %%
ensemble = "LOCA2"
ssp = "historical"
vars_ = ["tasmax","tasmin","pr"]

model_infos = [#{"model": "ACCESS-CM2", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "BCC-CSM2-MR", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "CNRM-ESM2-1", "member": "r1i1p1f2", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
              #  {"model": "MPI-ESM1-2-HR", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
              #  {"model": "MRI-ESM2-0", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
              # {"model": "NorESM2-MM", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_}
]

# %%
##################
# LOCA2 hindcasts
##################
for model_info in model_infos:
    print(model_info['model'])
    run_WBM(
        run_type="model",
        main_path=main_path,
        sim_ID=f"{ensemble}_{model_info['model']}_{model_info['member']}_{ssp}",
        model_info=model_info,
        project_ID=project_ID,
        run_start=run_start,
        run_end=run_end,
        spinup_start=spinup_start,
        spinup_end=spinup_end,
        spinup_loops=spinup_loops,
        output_vars=output_vars,
        pet_method=pet_method,
        airT_primary="XXX",
        airT_secondary="XXX",
        airT_min=f"{model_info['ensemble']}_tasmin_daily.init",
        airT_max=f"{model_info['ensemble']}_tasmax_daily.init",
        precip_primary=f"{model_info['ensemble']}_pr_daily.init",
        precip_secondary="",
        cloudFr_primary=cloudFr_primary,
        windU_primary="",
        windV_primary="",
        humidity_primary="",
        albedo_primary="",
        rootingDepth=rootingDepth,
        soilAWC=soilAWC,
        canopyHt=canopyHt,
        lai=lai,
        land_collapse=land_collapse,
        crop_area_frac=crop_area_frac,
        crop_area_frac_patch="",
        crop_par=crop_par,
        crop_par_patch="",
        pre_spooled=True
    )
    print('\n')
# Out:
# BCC-CSM2-MR
# check jobid: 44025909
# spool jobid: 44025922
# run jobid: 44025923
#
#
# CNRM-ESM2-1
# check jobid: 44025924
# spool jobid: 44025935
# run jobid: 44025936

# %% [markdown]
# ### OakRidge

# %%
ensemble = "OakRidge"
ssp = "historical"
vars_ = ["tmax","tmin","prcp"]
methods = ["DBCCA_Daymet", "RegCM_Daymet", "DBCCA_Livneh", "RegCM_Livneh"]

model_infos = [{"model": "ACCESS-CM2", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "BCC-CSM2-MR", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "CNRM-ESM2-1", "member": "r1i1p1f2", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "MPI-ESM1-2-HR", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "MRI-ESM2-0", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
              {"model": "NorESM2-MM", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_}]

# %%
#####################
# OakRidge hindcasts
#####################
for model_info in model_infos[:1]:
    for method in methods:
        model_info_upd = model_infos[0]
        model_info_upd["method"] = method
        print(model_info_upd['model'], model_info_upd['method'])
        run_WBM(
            run_type="model",
            main_path=main_path,
            sim_ID=f"{ensemble}_{model_info_upd['model']}_{model_info_upd['member']}_{model_info_upd['method']}_{ssp}",
            model_info=model_info,
            project_ID=project_ID,
            run_start=run_start,
            run_end=run_end,
            spinup_start=spinup_start,
            spinup_end=spinup_end,
            spinup_loops=spinup_loops,
            output_vars=output_vars,
            pet_method=pet_method,
            airT_primary="XXX",
            airT_secondary="XXX",
            airT_min=f"{model_info_upd['ensemble']}_tmin_daily.init",
            airT_max=f"{model_info_upd['ensemble']}_tmax_daily.init",
            precip_primary=f"{model_info_upd['ensemble']}_prcp_daily.init",
            precip_secondary="",
            cloudFr_primary=cloudFr_primary,
            windU_primary="",
            windV_primary="",
            humidity_primary="",
            albedo_primary="",
            rootingDepth=rootingDepth,
            soilAWC=soilAWC,
            canopyHt=canopyHt,
            lai=lai,
            land_collapse=land_collapse,
            crop_area_frac=crop_area_frac,
            crop_area_frac_patch="",
            crop_par=crop_par,
            crop_par_patch="",
            pre_spooled=True
        )
        print('\n')
# Out:
# ACCESS-CM2 DBCCA_Daymet
# check jobid: 44025726
# spool jobid: 44025735
# run jobid: 44025736
#
#
# ACCESS-CM2 RegCM_Daymet
# check jobid: 44025737
# spool jobid: 44025757
# run jobid: 44025758
#
#
# ACCESS-CM2 DBCCA_Livneh
# check jobid: 44025759
# spool jobid: 44025781
# run jobid: 44025782
#
#
# ACCESS-CM2 RegCM_Livneh
# check jobid: 44025783
# spool jobid: 44025795
# run jobid: 44025796

# %%
#####################
# OakRidge hindcasts
#####################
for model_info in model_infos[1:]:
    for method in methods:
        model_info_upd = model_infos[0]
        model_info_upd["method"] = method
        print(model_info_upd['model'], model_info_upd['method'])
        run_WBM(
            run_type="model",
            main_path=main_path,
            sim_ID=f"{ensemble}_{model_info_upd['model']}_{model_info_upd['member']}_{model_info_upd['method']}_{ssp}",
            model_info=model_info,
            project_ID=project_ID,
            run_start=run_start,
            run_end=run_end,
            spinup_start=spinup_start,
            spinup_end=spinup_end,
            spinup_loops=spinup_loops,
            output_vars=output_vars,
            pet_method=pet_method,
            airT_primary="XXX",
            airT_secondary="XXX",
            airT_min=f"{model_info_upd['ensemble']}_tmin_daily.init",
            airT_max=f"{model_info_upd['ensemble']}_tmax_daily.init",
            precip_primary=f"{model_info_upd['ensemble']}_prcp_daily.init",
            precip_secondary="",
            cloudFr_primary=cloudFr_primary,
            windU_primary="",
            windV_primary="",
            humidity_primary="",
            albedo_primary="",
            rootingDepth=rootingDepth,
            soilAWC=soilAWC,
            canopyHt=canopyHt,
            lai=lai,
            land_collapse=land_collapse,
            crop_area_frac=crop_area_frac,
            crop_area_frac_patch="",
            crop_par=crop_par,
            crop_par_patch="",
            pre_spooled=True
        )
        print('\n')
# Out:
# ACCESS-CM2 DBCCA_Daymet
# Directory already exists!
# Check already completed.
# spool jobid: 44025797
# run jobid: 44025798
#
#
# ACCESS-CM2 RegCM_Daymet
# Directory already exists!
# Check already completed.
# spool jobid: 44025799
# run jobid: 44025800
#
#
# ACCESS-CM2 DBCCA_Livneh
# Directory already exists!
# Check already completed.
# spool jobid: 44025801
# run jobid: 44025802
#
#
# ACCESS-CM2 RegCM_Livneh
# Directory already exists!
# Check already completed.
# spool jobid: 44025803
# run jobid: 44025804
#
#
# ACCESS-CM2 DBCCA_Daymet
# Directory already exists!
# Check already completed.
# spool jobid: 44025805
# run jobid: 44025806
#
#
# ACCESS-CM2 RegCM_Daymet
# Directory already exists!
# Check already completed.
# spool jobid: 44025807
# run jobid: 44025808
#
#
# ACCESS-CM2 DBCCA_Livneh
# Directory already exists!
# Check already completed.
# spool jobid: 44025809
# run jobid: 44025810
#
#
# ACCESS-CM2 RegCM_Livneh
# Directory already exists!
# Check already completed.
# spool jobid: 44025811
# run jobid: 44025812
#
#
# ACCESS-CM2 DBCCA_Daymet
# Directory already exists!
# Check already completed.
# spool jobid: 44025813
# run jobid: 44025814
#
#
# ACCESS-CM2 RegCM_Daymet
# Directory already exists!
# Check already completed.
# spool jobid: 44025815
# run jobid: 44025816
#
#
# ACCESS-CM2 DBCCA_Livneh
# Directory already exists!
# Check already completed.
# spool jobid: 44025817
# run jobid: 44025818
#
#
# ACCESS-CM2 RegCM_Livneh
# Directory already exists!
# Check already completed.
# spool jobid: 44025819
# run jobid: 44025820
#
#
# ACCESS-CM2 DBCCA_Daymet
# Directory already exists!
# Check already completed.
# spool jobid: 44025821
# run jobid: 44025822
#
#
# ACCESS-CM2 RegCM_Daymet
# Directory already exists!
# Check already completed.
# spool jobid: 44025823
# run jobid: 44025824
#
#
# ACCESS-CM2 DBCCA_Livneh
# Directory already exists!
# Check already completed.
# spool jobid: 44025825
# run jobid: 44025826
#
#
# ACCESS-CM2 RegCM_Livneh
# Directory already exists!
# Check already completed.
# spool jobid: 44025827
# run jobid: 44025828
#
#
# ACCESS-CM2 DBCCA_Daymet
# Directory already exists!
# Check already completed.
# spool jobid: 44025829
# run jobid: 44025830
#
#
# ACCESS-CM2 RegCM_Daymet
# Directory already exists!
# Check already completed.
# spool jobid: 44025831
# run jobid: 44025832
#
#
# ACCESS-CM2 DBCCA_Livneh
# Directory already exists!
# Check already completed.
# spool jobid: 44025833
# run jobid: 44025834
#
#
# ACCESS-CM2 RegCM_Livneh
# Directory already exists!
# Check already completed.
# spool jobid: 44025835
# run jobid: 44025836

# %% [markdown]
# # Projections

# %%
#######################
# Constant for all runs
#######################

# Main directory
main_path = "/gpfs/group/kaf26/default/dcl5300/wbm_soilM_crop_uc_lafferty-etal-2024-tbd_DATA/"

# Simulation length
run_start="2015-01-01"
run_end="2030-12-31"

# Spunup
spinup_start="2015-01-01"
spinup_end="2015-12-31"
spinup_loops = 5

# Output variables
output_vars=["soilMoist", "soilMoistFrac"]

# PET method
pet_method = "Hamon"

# Cloud fraction
cloudFr_primary = "merra2_cldtot_dc.init"

# Rooting depth
rootingDepth = "Effective_Rooting_Depth_mod.init"

# Available water capacity
soilAWC = "/gpfs/group/kaf26/default/private/WBM_data/squam.sr.unh.edu/US_CDL_v3_data/soil/SSURGO_SoilData_awc_frac_mm_m_CONUS_1km.tif"

# Canopy height
canopyHt = "/gpfs/group/kaf26/default/private/WBM_data/squam.sr.unh.edu/US_CDL_v3_data/canopy/Simard_Pinto_3DGlobalVeg_JGR_10km.tif"

# Leaf Area Index
lai = "merra2_lai2_dc.init"

# Lan collapse method
land_collapse="average"

# Crop parameter file
crop_par = "CDL-US-M_CropParameters_proj.csv"

# Crop area timeseries
crop_area_frac="cdl_cropland_proj.init"

# Project ID
project_ID = "PCHES_crop_yield_UC_climate_param"

# %%
##################
# NEX test
##################
model_info = {"ensemble": "NEX-GDDP",
              "vars": ["tas","pr"],
              "model": "CanESM5",
              "ssp": "ssp126",
              "member": "r1i1p1f1",
              "grid": "gn"}

run_WBM(
    run_type="model",
    main_path=main_path,
    sim_ID=f"{model_info['ensemble']}_{model_info['model']}_{model_info['member']}_{model_info['ssp']}",
    model_info=model_info,
    project_ID=project_ID,
    run_start=run_start,
    run_end=run_end,
    spinup_start=spinup_start,
    spinup_end=spinup_end,
    spinup_loops=spinup_loops,
    output_vars=output_vars,
    network="",
    pet_method=pet_method,
    airT_primary=f"{model_info['ensemble']}_tas_daily.init",
    airT_secondary="",
    airT_min="",
    airT_max="",
    precip_primary=f"{model_info['ensemble']}_pr_daily.init",
    precip_secondary="",
    cloudFr_primary=cloudFr_primary,
    windU_primary="",
    windV_primary="",
    humidity_primary="",
    albedo_primary="",
    rootingDepth=rootingDepth,
    soilAWC=soilAWC,
    canopyHt=canopyHt,
    lai=lai,
    land_collapse=land_collapse,
    crop_area_frac=crop_area_frac,
    crop_area_frac_patch="",
    crop_par=crop_par,
    crop_par_patch=""
)
# Out:
# check jobid: 44022776
# spool jobid: 44022786
# run jobid: 44022787
