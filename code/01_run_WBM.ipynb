# %%
from run_WBM import run_WBM

# %%
######################
# Common to all runs #
######################

# Main directory
main_path = "/gpfs/group/kaf26/default/dcl5300/wbm_soilM_crop_uc_lafferty-etal-2024-tbd_DATA/wbm/"

# Output variables
output_vars=["soilMoist", "soilMoistFrac"]

# PET method
pet_method = "Hamon"

# Rooting depth
rootingDepth = "Effective_Rooting_Depth_mod.init"

# Available water capacity
# soilAWC = "/gpfs/group/kaf26/default/private/WBM_data/squam.sr.unh.edu/US_CDL_v3_data/soil/SSURGO_SoilData_awc_frac_mm_m_CONUS_1km.tif"
soilAWC = "SSURGO_HARMON_AWC_05min_NAM_US.init"

# Canopy height
canopyHt = "/gpfs/group/kaf26/default/private/WBM_data/squam.sr.unh.edu/US_CDL_v3_data/canopy/Simard_Pinto_3DGlobalVeg_JGR_10km.tif"

# Leaf Area Index
lai = "merra2_lai2_dc.init"

# Lan collapse method
land_collapse="average"

# Project ID
project_ID = "PCHES_crop_yield_UC_climate_param"

# %% [markdown]
# # Historical runs (observational data)

# %%
#######################
# Common to hist runs #
#######################

# Simulation length
run_start="1980-01-01"
run_end="2014-12-31"

# Spinup
spinup_start="1980-01-01"
spinup_end="1980-12-31"
spinup_loops = 5

# Cloud fraction
cloudFr_primary = "merra2_cldtot_d.init"

# Crop parameter file
crop_par = "CDL-US-M_CropParameters_hist.csv"

# Crop area timeseries
crop_area_frac="cdl_cropland_hist.init"

# %%
########
# GMFD #
########
run_WBM(
    run_type="obs",
    main_path=main_path,
    sim_ID="OBS_GMFD_historical",
    model_info={},
    project_ID=project_ID,
    perform_spool=True,
    perform_run=True,
    run_start=run_start,
    run_end=run_end,
    spinup_start=spinup_start,
    spinup_end=spinup_end,
    spinup_loops=spinup_loops,
    output_vars=output_vars,
    pet_method=pet_method,
    airT_primary="GMFD_tas_daily.init",
    airT_secondary="",
    airT_min="",
    airT_max="",
    precip_primary="GMFD_prcp_daily.init",
    precip_secondary="",
    cloudFr_primary=cloudFr_primary,
    windU_primary="",
    windV_primary="",
    humidity_primary="",
    albedo_primary="",
    rootingDepth=rootingDepth,
    soilAWC=soilAWC,
    canopyHt=canopyHt,
    lai=lai,
    land_collapse=land_collapse,
    crop_area_frac=crop_area_frac,
    crop_area_frac_patch="",
    crop_par=crop_par,
    crop_par_patch=""
)
# Out:
# check jobid: 44106071
# spool jobid: 44106096
# run jobid: 44106098

# %%
###########
# Livneh2 #
###########
run_WBM(
    run_type="obs",
    main_path=main_path,
    sim_ID="OBS_Livneh2_historical",
    model_info={},
    project_ID=project_ID,
    perform_spool=True,
    perform_run=True,
    run_start=run_start,
    run_end=run_end,
    spinup_start=spinup_start,
    spinup_end=spinup_end,
    spinup_loops=spinup_loops,
    output_vars=output_vars,
    pet_method=pet_method,
    airT_primary="XXX",
    airT_secondary="XXX",
    airT_min="Livneh2_Tmax_daily.init",
    airT_max="Livneh2_Tmin_daily.init",
    precip_primary="Livneh2_precip_daily.init",
    precip_secondary="",
    cloudFr_primary=cloudFr_primary,
    windU_primary="",
    windV_primary="",
    humidity_primary="",
    albedo_primary="",
    rootingDepth=rootingDepth,
    soilAWC=soilAWC,
    canopyHt=canopyHt,
    lai=lai,
    land_collapse=land_collapse,
    crop_area_frac=crop_area_frac,
    crop_area_frac_patch="",
    crop_par=crop_par,
    crop_par_patch="",
    
)
# Out:
# check jobid: 44106100
# spool jobid: 44106122
# run jobid: 44106123

# %%
###########
# gridMET #
###########
run_WBM(
    run_type="obs",
    main_path=main_path,
    sim_ID="OBS_gridMET_historical",
    model_info={},
    project_ID=project_ID,
    perform_spool=True,
    perform_run=True,
    run_start=run_start,
    run_end=run_end,
    spinup_start=spinup_start,
    spinup_end=spinup_end,
    spinup_loops=spinup_loops,
    output_vars=output_vars,
    pet_method=pet_method,
    airT_primary="XXX",
    airT_secondary="XXX",
    airT_min="gridMET_tmmn_daily.init",
    airT_max="gridMET_tmmx_daily.init",
    precip_primary="gridMET_pr_daily.init",
    precip_secondary="",
    cloudFr_primary=cloudFr_primary,
    windU_primary="",
    windV_primary="",
    humidity_primary="",
    albedo_primary="",
    rootingDepth=rootingDepth,
    soilAWC=soilAWC,
    canopyHt=canopyHt,
    lai=lai,
    land_collapse=land_collapse,
    crop_area_frac=crop_area_frac,
    crop_area_frac_patch="",
    crop_par=crop_par,
    crop_par_patch="",
    
)
# Out:
# check jobid: 44106135
# spool jobid: 44106160
# run jobid: 44106162

# %%
#########
# PRISM #
#########
run_start="1981-01-01" # only PRISM

spinup_start="1981-01-01"
spinup_end="1981-12-31"
spinup_loops = 5

run_WBM(
    run_type="obs",
    main_path=main_path,
    sim_ID="OBS_PRISM_historical",
    model_info={},
    project_ID=project_ID,
    perform_spool=True,
    perform_run=True,
    run_start=run_start,
    run_end=run_end,
    spinup_start=spinup_start,
    spinup_end=spinup_end,
    spinup_loops=spinup_loops,
    output_vars=output_vars,
    pet_method=pet_method,
    airT_primary="PRISM_tmean_4kmD2_d.init",
    airT_secondary="",
    airT_min="",
    airT_max="",
    precip_primary="PRISM_ppt_4kmD2_d.init",
    precip_secondary="",
    cloudFr_primary=cloudFr_primary,
    windU_primary="",
    windV_primary="",
    humidity_primary="",
    albedo_primary="",
    rootingDepth=rootingDepth,
    soilAWC=soilAWC,
    canopyHt=canopyHt,
    lai=lai,
    land_collapse=land_collapse,
    crop_area_frac=crop_area_frac,
    crop_area_frac_patch="",
    crop_par=crop_par,
    crop_par_patch="",
    
)
# Out:
# check jobid: 44106124
# spool jobid: 44106130
# run jobid: 44106132

# %% [markdown]
# # Hindcast runs (climate models)

# %%
#######################
# Common to hist runs #
#######################

# Simulation length
run_start="1980-01-01"
run_end="2014-12-31"

# Spunup
spinup_start="1980-01-01"
spinup_end="1980-12-31"
spinup_loops = 5

# Cloud fraction
cloudFr_primary = "merra2_cldtot_d.init"

# Crop parameter file
crop_par = "CDL-US-M_CropParameters_hist.csv"

# Crop area timeseries
crop_area_frac="cdl_cropland_hist.init"

# %% [markdown]
# ### NEX-GDDP

# %%
ensemble = "NEX-GDDP"
ssp = "historical"
vars_ = ["tasmin", "tasmax", "pr"]

model_infos = [{"model": "ACCESS-CM2", "member": "r1i1p1f1", "grid": "gn", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "BCC-CSM2-MR", "member": "r1i1p1f1", "grid": "gn", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "CNRM-ESM2-1", "member": "r1i1p1f2", "grid": "gr", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "MPI-ESM1-2-HR", "member": "r1i1p1f1", "grid": "gn", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "MRI-ESM2-0", "member": "r1i1p1f1", "grid": "gn", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
              {"model": "NorESM2-MM", "member": "r1i1p1f1", "grid": "gn", "ensemble": ensemble, "ssp":ssp, "vars":vars_}]

# %%
##################
# NEX hindcasts
##################
for model_info in model_infos:
    print(model_info['model'])
    
    sim_ID = f"{ensemble}_{model_info['model']}_{model_info['member']}_{ssp}"
    
    run_WBM(
        run_type="model",
        main_path=main_path,
        sim_ID=sim_ID,
        model_info=model_info,
        project_ID=project_ID,
        perform_spool=True,
        perform_run=True,
        run_start=run_start,
        run_end=run_end,
        spinup_start=spinup_start,
        spinup_end=spinup_end,
        spinup_loops=spinup_loops,
        output_vars=output_vars,
        pet_method=pet_method,
        airT_primary="XXX",
        airT_secondary="XXX",
        airT_min=f"{sim_ID}_tasmin_daily.init",
        airT_max=f"{sim_ID}_tasmax_daily.init",
        precip_primary=f"{sim_ID}_pr_daily.init",
        precip_secondary="",
        cloudFr_primary=cloudFr_primary,
        windU_primary="",
        windV_primary="",
        humidity_primary="",
        albedo_primary="",
        rootingDepth=rootingDepth,
        soilAWC=soilAWC,
        canopyHt=canopyHt,
        lai=lai,
        land_collapse=land_collapse,
        crop_area_frac=crop_area_frac,
        crop_area_frac_patch="",
        crop_par=crop_par,
        crop_par_patch="",
    )
    print('\n')
# Out:
# BCC-CSM2-MR
# check jobid: 44127980
# spool jobid: 44127996
# run jobid: 44127997
#
#
# CNRM-ESM2-1
# check jobid: 44127998
# spool jobid: 44128029
# run jobid: 44128030
#
#
# MPI-ESM1-2-HR
# check jobid: 44128032
# spool jobid: 44128045
# run jobid: 44128046
#
#
# MRI-ESM2-0
# check jobid: 44128047
# spool jobid: 44128056
# run jobid: 44128057
#
#
# NorESM2-MM
# check jobid: 44128058
# spool jobid: 44128064
# run jobid: 44128065

# %% [markdown]
# ### LOCA2

# %%
ensemble = "LOCA2"
ssp = "historical"
vars_ = ["tasmax","tasmin","pr"]

model_infos = [{"model": "ACCESS-CM2", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "BCC-CSM2-MR", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "CNRM-ESM2-1", "member": "r1i1p1f2", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "MPI-ESM1-2-HR", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "MRI-ESM2-0", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
              {"model": "NorESM2-MM", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_}]

# %%
##################
# LOCA2 hindcasts
##################
for model_info in model_infos:
    print(model_info['model'])

    sim_ID = f"{ensemble}_{model_info['model']}_{model_info['member']}_{ssp}"
    
    run_WBM(
        run_type="model",
        main_path=main_path,
        sim_ID=sim_ID,
        model_info=model_info,
        project_ID=project_ID,
        perform_spool=True,
        perform_run=True,
        run_start=run_start,
        run_end=run_end,
        spinup_start=spinup_start,
        spinup_end=spinup_end,
        spinup_loops=spinup_loops,
        output_vars=output_vars,
        pet_method=pet_method,
        airT_primary="XXX",
        airT_secondary="XXX",
        airT_min=f"{sim_ID}_tasmin_daily.init",
        airT_max=f"{sim_ID}_tasmax_daily.init",
        precip_primary=f"{sim_ID}_pr_daily.init",
        precip_secondary="",
        cloudFr_primary=cloudFr_primary,
        windU_primary="",
        windV_primary="",
        humidity_primary="",
        albedo_primary="",
        rootingDepth=rootingDepth,
        soilAWC=soilAWC,
        canopyHt=canopyHt,
        lai=lai,
        land_collapse=land_collapse,
        crop_area_frac=crop_area_frac,
        crop_area_frac_patch="",
        crop_par=crop_par,
        crop_par_patch=""
    )
    print('\n')
# Out:
# ACCESS-CM2
# Directory already exists!
# Check already completed.
# Spooling already completed.
# run jobid: 44096836
#
#
# BCC-CSM2-MR
# Directory already exists!
# Check already completed.
# Spooling already completed.
# run jobid: 44096837
#
#
# CNRM-ESM2-1
# Directory already exists!
# Check already completed.
# Spooling already completed.
# run jobid: 44096838
#
#
# MPI-ESM1-2-HR
# Directory already exists!
# Check already completed.
# Spooling already completed.
# run jobid: 44096839
#
#
# MRI-ESM2-0
# Directory already exists!
# Check already completed.
# Spooling already completed.
# run jobid: 44096840
#
#
# NorESM2-MM
# Directory already exists!
# Check already completed.
# Spooling already completed.
# run jobid: 44096842

# %% [markdown]
# ### OakRidge

# %%
ensemble = "OakRidge"
ssp = "historical"
vars_ = ["tmax","tmin","prcp"]
methods = ["DBCCA_Daymet", "RegCM_Daymet", "DBCCA_Livneh", "RegCM_Livneh"]

model_infos = [{"model": "ACCESS-CM2", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "BCC-CSM2-MR", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "CNRM-ESM2-1", "member": "r1i1p1f2", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "MPI-ESM1-2-HR", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "MRI-ESM2-0", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
              {"model": "NorESM2-MM", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_}]

# %%
#####################
# OakRidge hindcasts
#####################
for model_info in model_infos:
    for method in methods:
        model_info_upd = model_info
        model_info_upd["method"] = method
        print(model_info_upd["model"], method)
        
        sim_ID = f"{ensemble}_{model_info_upd['model']}_{model_info_upd['member']}_{model_info_upd['method']}_{ssp}"
        
        run_WBM(
            run_type="model",
            main_path=main_path,
            sim_ID=sim_ID,
            model_info=model_info,
            project_ID=project_ID,
            perform_spool=True,
            perform_run=True,
            run_start=run_start,
            run_end=run_end,
            spinup_start=spinup_start,
            spinup_end=spinup_end,
            spinup_loops=spinup_loops,
            output_vars=output_vars,
            pet_method=pet_method,
            airT_primary="XXX",
            airT_secondary="XXX",
            airT_min=f"{sim_ID}_tmin_daily.init",
            airT_max=f"{sim_ID}_tmax_daily.init",
            precip_primary=f"{sim_ID}_prcp_daily.init",
            precip_secondary="",
            cloudFr_primary=cloudFr_primary,
            windU_primary="",
            windV_primary="",
            humidity_primary="",
            albedo_primary="",
            rootingDepth=rootingDepth,
            soilAWC=soilAWC,
            canopyHt=canopyHt,
            lai=lai,
            land_collapse=land_collapse,
            crop_area_frac=crop_area_frac,
            crop_area_frac_patch="",
            crop_par=crop_par,
            crop_par_patch="",
            
        )
        print('\n')
# Out:
# ACCESS-CM2 DBCCA_Daymet
# Directory already exists!
# Check already completed.
# Spooling already completed.
# Run already completed.
#
#
# ACCESS-CM2 RegCM_Daymet
# Directory already exists!
# Check already completed.
# Spooling already completed.
# Run already completed.
#
#
# ACCESS-CM2 DBCCA_Livneh
# Directory already exists!
# Check already completed.
# Spooling already completed.
# Run already completed.
#
#
# ACCESS-CM2 RegCM_Livneh
# Directory already exists!
# Check already completed.
# Spooling already completed.
# Run already completed.
#
#
# BCC-CSM2-MR DBCCA_Daymet
# Directory already exists!
# Check already completed.
# Spooling already completed.
# Run already completed.
#
#
# BCC-CSM2-MR RegCM_Daymet
# Directory already exists!
# Check already completed.
# Spooling already completed.
# Run already completed.
#
#
# BCC-CSM2-MR DBCCA_Livneh
# Directory already exists!
# Check already completed.
# Spooling already completed.
# Run already completed.
#
#
# BCC-CSM2-MR RegCM_Livneh
# Directory already exists!
# Check already completed.
# Spooling already completed.
# Run already completed.
#
#
# CNRM-ESM2-1 DBCCA_Daymet
# Directory already exists!
# Check already completed.
# Spooling already completed.
# Run already completed.
#
#
# CNRM-ESM2-1 RegCM_Daymet
# Directory already exists!
# Check already completed.
# Spooling already completed.
# Run already completed.
#
#
# CNRM-ESM2-1 DBCCA_Livneh
# Directory already exists!
# Check already completed.
# Spooling already completed.
# Run already completed.
#
#
# CNRM-ESM2-1 RegCM_Livneh
# Directory already exists!
# Check already completed.
# Spooling already completed.
# Run already completed.
#
#
# MPI-ESM1-2-HR DBCCA_Daymet
# Directory already exists!
# Check already completed.
# Spooling already completed.
# Run already completed.
#
#
# MPI-ESM1-2-HR RegCM_Daymet
# Directory already exists!
# Check already completed.
# Spooling already completed.
# Run already completed.
#
#
# MPI-ESM1-2-HR DBCCA_Livneh
# Directory already exists!
# Check already completed.
# Spooling already completed.
# Run already completed.
#
#
# MPI-ESM1-2-HR RegCM_Livneh
# Directory already exists!
# Check already completed.
# Spooling already completed.
# Run already completed.
#
#
# MRI-ESM2-0 DBCCA_Daymet
# Directory already exists!
# Check already completed.
# Spooling already completed.
# Run already completed.
#
#
# MRI-ESM2-0 RegCM_Daymet
# Directory already exists!
# Check already completed.
# Spooling already completed.
# Run already completed.
#
#
# MRI-ESM2-0 DBCCA_Livneh
# Directory already exists!
# Check already completed.
# Spooling already completed.
# Run already completed.
#
#
# MRI-ESM2-0 RegCM_Livneh
# Directory already exists!
# Check already completed.
# Spooling already completed.
# Run already completed.
#
#
# NorESM2-MM DBCCA_Daymet
# Directory already exists!
# Check already completed.
# Spooling already completed.
# Run already completed.
#
#
# NorESM2-MM RegCM_Daymet
# Directory already exists!
# Check already completed.
# Spooling already completed.
# Run already completed.
#
#
# NorESM2-MM DBCCA_Livneh
# Directory already exists!
# Check already completed.
# Spooling already completed.
# Run already completed.
#
#
# NorESM2-MM RegCM_Livneh
# Directory already exists!
# Check already completed.
# Spooling already completed.
# run jobid: 44106043

# %% [markdown]
# # Projections

# %% [markdown]
# ### NEX-GDDP

# %%
# Simulation length
run_start="2015-01-01"
run_end="2099-12-31"

# Spunup
spinup_start="2015-01-01"
spinup_end="2015-12-31"
spinup_loops = 5

# Cloud fraction
cloudFr_primary = "merra2_cldtot_dc.init"

# Crop parameter file
crop_par = "CDL-US-M_CropParameters_proj.csv"

# Crop area timeseries
crop_area_frac="cdl_cropland_proj.init"

# %%
ensemble = "NEX-GDDP"
ssp = "ssp585"
vars_ = ["tasmin", "tasmax", "pr"]

model_infos = [{"model": "ACCESS-CM2", "member": "r1i1p1f1", "grid": "gn", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "BCC-CSM2-MR", "member": "r1i1p1f1", "grid": "gn", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "CNRM-ESM2-1", "member": "r1i1p1f2", "grid": "gr", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "MPI-ESM1-2-HR", "member": "r1i1p1f1", "grid": "gn", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "MRI-ESM2-0", "member": "r1i1p1f1", "grid": "gn", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
              {"model": "NorESM2-MM", "member": "r1i1p1f1", "grid": "gn", "ensemble": ensemble, "ssp":ssp, "vars":vars_}]

# %%
##################
# NEX projections
##################
for model_info in model_infos:
    print(model_info['model'])
    
    sim_ID = f"{ensemble}_{model_info['model']}_{model_info['member']}_{ssp}"
    
    run_WBM(
        run_type="model",
        main_path=main_path,
        sim_ID=sim_ID,
        model_info=model_info,
        project_ID=project_ID,
        perform_spool=True,
        perform_run=True,
        run_start=run_start,
        run_end=run_end,
        spinup_start=spinup_start,
        spinup_end=spinup_end,
        spinup_loops=spinup_loops,
        output_vars=output_vars,
        pet_method=pet_method,
        airT_primary="XXX",
        airT_secondary="XXX",
        airT_min=f"{sim_ID}_tasmin_daily.init",
        airT_max=f"{sim_ID}_tasmax_daily.init",
        precip_primary=f"{sim_ID}_pr_daily.init",
        precip_secondary="",
        cloudFr_primary=cloudFr_primary,
        windU_primary="",
        windV_primary="",
        humidity_primary="",
        albedo_primary="",
        rootingDepth=rootingDepth,
        soilAWC=soilAWC,
        canopyHt=canopyHt,
        lai=lai,
        land_collapse=land_collapse,
        crop_area_frac=crop_area_frac,
        crop_area_frac_patch="",
        crop_par=crop_par,
        crop_par_patch="",
        
    )
    print('\n')
# Out:
# BCC-CSM2-MR
# check jobid: 44128543
# spool jobid: 44128558
# run jobid: 44128559
#
#
# CNRM-ESM2-1
# check jobid: 44128560
# spool jobid: 44128569
# run jobid: 44128570
#
#
# MPI-ESM1-2-HR
# check jobid: 44128571
# spool jobid: 44128587
# run jobid: 44128588
#
#
# MRI-ESM2-0
# check jobid: 44128589
# spool jobid: 44128604
# run jobid: 44128605
#
#
# NorESM2-MM
# check jobid: 44128606
# spool jobid: 44128618
# run jobid: 44128619

# %% [markdown]
# ### LOCA

# %%
# Spooling needs to be done first and separately for LOCA
# because the raw netCDF files are grouped into 20-year 
# period

# %%
# Simulation length
run_starts = ["2015-01-01", "2045-01-01", "2075-01-01"]
run_ends = ["2044-12-31", "2074-12-31", "2100-12-31"]
run_IDs = ["early", "mid", "late"]

# Cloud fraction
cloudFr_primary = "merra2_cldtot_dc.init"

# Crop parameter file
crop_par = "CDL-US-M_CropParameters_proj.csv"

# Crop area timeseries
crop_area_frac="cdl_cropland_proj.init"

# %%
ensemble = "LOCA2"
ssp = "historical"
vars_ = ["tasmax","tasmin","pr"]

model_infos = [{"model": "ACCESS-CM2", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "BCC-CSM2-MR", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "CNRM-ESM2-1", "member": "r1i1p1f2", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "MPI-ESM1-2-HR", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "MRI-ESM2-0", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
              {"model": "NorESM2-MM", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_}]

# %%
####################################
# LOCA2 projections SPOOLING ONLY
####################################
for i in range(3):
    for model_info in model_infos:
        print(model_info['model'])

        sim_ID = f"{ensemble}_{model_info['model']}_{model_info['member']}_{ssp}"
    
        run_WBM(
            run_type="model",
            main_path=main_path,
            sim_ID=sim_ID,
            model_info=model_info,
            project_ID=project_ID,
            perform_spool=True,
            perform_run=False,
            run_start=run_start,
            run_end=run_end,
            spinup_start=spinup_start,
            spinup_end=spinup_end,
            spinup_loops=spinup_loops,
            output_vars=output_vars,
            pet_method=pet_method,
            airT_primary="XXX",
            airT_secondary="XXX",
            airT_min=f"{sim_ID}_tasmin_daily.init",
            airT_max=f"{sim_ID}_tasmax_daily.init",
            precip_primary=f"{sim_ID}_pr_daily.init",
            precip_secondary="",
            cloudFr_primary=cloudFr_primary,
            windU_primary="",
            windV_primary="",
            humidity_primary="",
            albedo_primary="",
            rootingDepth=rootingDepth,
            soilAWC=soilAWC,
            canopyHt=canopyHt,
            lai=lai,
            land_collapse=land_collapse,
            crop_area_frac=crop_area_frac,
            crop_area_frac_patch="",
            crop_par=crop_par,
            crop_par_patch=""
        )
        print('\n')

# %% [markdown]
# ### OakRidge

# %%
# Simulation length
run_start="2015-01-01"
run_end="2059-12-31"

# Spinup
spinup_start="2015-01-01"
spinup_end="2015-12-31"
spinup_loops = 5

# Cloud fraction
cloudFr_primary = "merra2_cldtot_dc.init"

# Crop parameter file
crop_par = "CDL-US-M_CropParameters_proj.csv"

# Crop area timeseries
crop_area_frac="cdl_cropland_proj.init"

# %%
ensemble = "OakRidge"
ssp = "ssp585"
vars_ = ["tmax","tmin","prcp"]
methods = ["DBCCA_Daymet", "RegCM_Daymet", "DBCCA_Livneh", "RegCM_Livneh"]

model_infos = [{"model": "ACCESS-CM2", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "BCC-CSM2-MR", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "CNRM-ESM2-1", "member": "r1i1p1f2", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "MPI-ESM1-2-HR", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
               {"model": "MRI-ESM2-0", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_},
              {"model": "NorESM2-MM", "member": "r1i1p1f1", "ensemble": ensemble, "ssp":ssp, "vars":vars_}]

# %%
#####################
# OakRidge projections
#####################
for model_info in model_infos:
    for method in methods:
        model_info_upd = model_info
        model_info_upd["method"] = method
        print(model_info_upd["model"], method)
        
        sim_ID = f"{ensemble}_{model_info_upd['model']}_{model_info_upd['member']}_{model_info_upd['method']}_{ssp}"
        
        run_WBM(
            run_type="model",
            main_path=main_path,
            sim_ID=sim_ID,
            model_info=model_info,
            project_ID=project_ID,
            perform_spool=True,
            perform_run=True,
            run_start=run_start,
            run_end=run_end,
            spinup_start=spinup_start,
            spinup_end=spinup_end,
            spinup_loops=spinup_loops,
            output_vars=output_vars,
            pet_method=pet_method,
            airT_primary="XXX",
            airT_secondary="XXX",
            airT_min=f"{sim_ID}_tmin_daily.init",
            airT_max=f"{sim_ID}_tmax_daily.init",
            precip_primary=f"{sim_ID}_prcp_daily.init",
            precip_secondary="",
            cloudFr_primary=cloudFr_primary,
            windU_primary="",
            windV_primary="",
            humidity_primary="",
            albedo_primary="",
            rootingDepth=rootingDepth,
            soilAWC=soilAWC,
            canopyHt=canopyHt,
            lai=lai,
            land_collapse=land_collapse,
            crop_area_frac=crop_area_frac,
            crop_area_frac_patch="",
            crop_par=crop_par,
            crop_par_patch="",
        )
        print('\n')
# Out:
# ACCESS-CM2 DBCCA_Daymet
# check jobid: 44116125
# spool jobid: 44116170
# run jobid: 44116172
#
#
# ACCESS-CM2 RegCM_Daymet
# check jobid: 44116173
# spool jobid: 44116344
# run jobid: 44116345
#
#
# ACCESS-CM2 DBCCA_Livneh
# check jobid: 44116346
# spool jobid: 44116385
# run jobid: 44116386
#
#
# ACCESS-CM2 RegCM_Livneh
# check jobid: 44116405
# spool jobid: 44116472
# run jobid: 44116473
#
#
# BCC-CSM2-MR DBCCA_Daymet
# check jobid: 44116474
# spool jobid: 44116593
# run jobid: 44116594
#
#
# BCC-CSM2-MR RegCM_Daymet
# check jobid: 44116595
# spool jobid: 44116632
# run jobid: 44116633
#
#
# BCC-CSM2-MR DBCCA_Livneh
# check jobid: 44116634
# spool jobid: 44116669
# run jobid: 44116674
#
#
# BCC-CSM2-MR RegCM_Livneh
# check jobid: 44116683
# spool jobid: 44116735
# run jobid: 44116736
#
#
# CNRM-ESM2-1 DBCCA_Daymet
# check jobid: 44116737
# spool jobid: 44116854
# run jobid: 44116856
#
#
# CNRM-ESM2-1 RegCM_Daymet
# check jobid: 44116869
# spool jobid: 44116889
# run jobid: 44116890
#
#
# CNRM-ESM2-1 DBCCA_Livneh
# check jobid: 44116891
# spool jobid: 44116986
# run jobid: 44116987
#
#
# CNRM-ESM2-1 RegCM_Livneh
# check jobid: 44116989
# spool jobid: 44117050
# run jobid: 44117051
#
#
# MPI-ESM1-2-HR DBCCA_Daymet
# check jobid: 44117066
# spool jobid: 44117124
# run jobid: 44117125
#
#
# MPI-ESM1-2-HR RegCM_Daymet
# check jobid: 44117126
# spool jobid: 44117252
# run jobid: 44117253
#
#
# MPI-ESM1-2-HR DBCCA_Livneh
# check jobid: 44117254
# spool jobid: 44117277
# run jobid: 44117301
#
#
# MPI-ESM1-2-HR RegCM_Livneh
# check jobid: 44117302
# spool jobid: 44117370
# run jobid: 44117372
#
#
# MRI-ESM2-0 DBCCA_Daymet
# check jobid: 44117374
# spool jobid: 44117406
# run jobid: 44117408
#
#
# MRI-ESM2-0 RegCM_Daymet
# check jobid: 44117409
# spool jobid: 44117431
# run jobid: 44117433
#
#
# MRI-ESM2-0 DBCCA_Livneh
# check jobid: 44117441
# spool jobid: 44117471
# run jobid: 44117472
#
#
# MRI-ESM2-0 RegCM_Livneh
# check jobid: 44117473
# spool jobid: 44117483
# run jobid: 44117484
#
#
# NorESM2-MM DBCCA_Daymet
# check jobid: 44117485
# spool jobid: 44117503
# run jobid: 44117505
#
#
# NorESM2-MM RegCM_Daymet
# check jobid: 44117519
# spool jobid: 44117543
# run jobid: 44117544
#
#
# NorESM2-MM DBCCA_Livneh
# check jobid: 44117545
# spool jobid: 44117568
# run jobid: 44117570
#
#
# NorESM2-MM RegCM_Livneh
# check jobid: 44117572
# spool jobid: 44117582
# run jobid: 44117583
