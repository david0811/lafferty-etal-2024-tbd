# %%
import os
import pandas as pd

import subprocess

from run_WBM import run_WBM

# %%
# Read all climate drivers 
df_climate_drivers = pd.read_csv("../utils/climate_drivers.csv")

# %%
for _, row in df_climate_drivers.iterrows():
    if row['ensemble'] == "OakRidge":
        sim_ID = f"{row['ensemble']}_{row['model']}_{row['member']}_{row['method']}_{row['ssp']}"
        sim_path = main_path + sim_ID
        
        if not os.path.isfile(f"{sim_path}/run_done.out"):
            print(sim_ID)
            # subprocess.run(
            #     ["rm", f"{sim_path}/spool_done.out"])
            # subprocess.run(
            #     ["rm", f"{sim_path}/spool_WBM.out"])
            
    elif (row['ensemble'] == "NEX-GDDP"):
        sim_ID = f"{row['ensemble']}_{row['model']}_{row['member']}_{row['ssp']}"
        sim_path = main_path + sim_ID
        
        if not os.path.isfile(f"{sim_path}/run_done.out"):
            print(sim_ID)
            # subprocess.run(
            #     ["rm", f"{sim_path}/spool_done.out"])
            # subprocess.run(
            #     ["rm", f"{sim_path}/spool_WBM.out"])
                
    # elif (row['ensemble'] == "LOCA2") and (row['ssp'] == "historical"):
    #     sim_ID = f"{row['ensemble']}_{row['model']}_{row['member']}_{row['ssp']}"
    #     sim_path = main_path + sim_ID
            
    if (row['ensemble'] == "LOCA2") and (row['ssp'] != "historical"):
        for time_id in ["early", "mid"]:
            sim_ID = f"{row['ensemble']}_{row['model']}_{row['member']}_{row['ssp']}_{time_id}"
            sim_path = main_path + sim_ID
            
            if not os.path.isfile(f"{sim_path}/run_done.out"):
                print(sim_ID)
                # subprocess.run(
                # ["rm", f"{sim_path}/spool_done.out"])
                # subprocess.run(
                # ["rm", f"{sim_path}/spool_WBM.out"])
# Out:
# NEX-GDDP_IPSL-CM6A-LR_r1i1p1f1_historical
# NEX-GDDP_GFDL-CM4_gr2_r1i1p1f1_ssp245
# NEX-GDDP_GFDL-CM4_gr2_r1i1p1f1_historical
# NEX-GDDP_GFDL-CM4_gr2_r1i1p1f1_ssp585
# NEX-GDDP_INM-CM5-0_r1i1p1f1_historical
# NEX-GDDP_KACE-1-0-G_r1i1p1f1_ssp245
# NEX-GDDP_KACE-1-0-G_r1i1p1f1_ssp585
# NEX-GDDP_KACE-1-0-G_r1i1p1f1_ssp370
# NEX-GDDP_KACE-1-0-G_r1i1p1f1_ssp126
# NEX-GDDP_MPI-ESM1-2-LR_r1i1p1f1_historical
# NEX-GDDP_UKESM1-0-LL_r1i1p1f2_ssp245
# NEX-GDDP_UKESM1-0-LL_r1i1p1f2_ssp585
# NEX-GDDP_UKESM1-0-LL_r1i1p1f2_ssp370
# NEX-GDDP_UKESM1-0-LL_r1i1p1f2_ssp126
# NEX-GDDP_GFDL-ESM4_r1i1p1f1_historical
# NEX-GDDP_ACCESS-ESM1-5_r1i1p1f1_historical
# NEX-GDDP_MIROC-ES2L_r1i1p1f2_historical
# NEX-GDDP_GISS-E2-1-G_r1i1p1f2_historical
# NEX-GDDP_INM-CM4-8_r1i1p1f1_historical
# NEX-GDDP_EC-Earth3_r1i1p1f1_historical
# NEX-GDDP_BCC-CSM2-MR_r1i1p1f1_historical
# NEX-GDDP_TaiESM1_r1i1p1f1_ssp585
# NEX-GDDP_HadGEM3-GC31-LL_r1i1p1f3_historical
# NEX-GDDP_CNRM-CM6-1_r1i1p1f2_historical
# NEX-GDDP_HadGEM3-GC31-MM_r1i1p1f3_historical
# NEX-GDDP_HadGEM3-GC31-MM_r1i1p1f3_ssp585
# NEX-GDDP_MIROC6_r1i1p1f1_ssp585
# LOCA2_INM-CM5-0_r2i1p1f1_ssp370_mid
# LOCA2_INM-CM5-0_r5i1p1f1_ssp370_mid
# LOCA2_INM-CM5-0_r1i1p1f1_ssp585_mid
# LOCA2_INM-CM5-0_r4i1p1f1_ssp370_mid
# LOCA2_INM-CM5-0_r3i1p1f1_ssp370_mid
# LOCA2_FGOALS-g3_r1i1p1f1_ssp585_mid
# LOCA2_FGOALS-g3_r4i1p1f1_ssp585_mid
# LOCA2_FGOALS-g3_r3i1p1f1_ssp585_mid

# %%
for _, row in df_climate_drivers.iterrows():
    if row['ensemble'] == "OakRidge":
        sim_ID = f"{row['ensemble']}_{row['model']}_{row['member']}_{row['method']}_{row['ssp']}"
        sim_path = main_path + sim_ID
    elif row['ensemble'] == "NEX-GDDP":
        sim_ID = f"{row['ensemble']}_{row['model']}_{row['member']}_{row['ssp']}"
        sim_path = main_path + sim_ID
    elif (row['ensemble'] == "LOCA2") and (row['ssp'] == "historical"):
        sim_ID = f"{row['ensemble']}_{row['model']}_{row['member']}_{row['ssp']}"
        sim_path = main_path + sim_ID
    check_spool_out = subprocess.run(
            ["tail", "-n", "5", f"{sim_path}/check_run_WBM.out"],
            capture_output=True,
            text=True,
        ).stdout.split("\n")
    if len(check_spool_out) > 10:
        if "Destination dataset is up to date! Nothing to do..." in check_spool_out:
            subprocess.run(["touch", f"{sim_path}/spool_done.out"])
            subprocess.run(["touch", f"{sim_path}/run_done.out"])
            
    if (row['ensemble'] == "LOCA2") and (row['ssp'] != "historical"):
        for time_id in ["early", "mid"]:
            sim_ID = f"{row['ensemble']}_{row['model']}_{row['member']}_{row['ssp']}_{time_id}"
            sim_path = main_path + sim_ID
            
            check_spool_out = subprocess.run(
                ["tail", "-n", "5", f"{sim_path}/check_run_WBM.out"],
                capture_output=True, text=True).stdout.split("\n")
            if len(check_spool_out) > 5:
                if "Destination dataset is up to date! Nothing to do..." in check_spool_out:
                    subprocess.run(["touch", f"{sim_path}/spool_done.out"])
                    subprocess.run(["touch", f"{sim_path}/run_done.out"])

# %%
for _, row in df_climate_drivers.iterrows():
    if row['ensemble'] == "OakRidge":
        sim_ID = f"{row['ensemble']}_{row['model']}_{row['member']}_{row['method']}_{row['ssp']}"
        sim_path = main_path + sim_ID
    elif row['ensemble'] == "NEX-GDDP":
        sim_ID = f"{row['ensemble']}_{row['model']}_{row['member']}_{row['ssp']}"
        sim_path = main_path + sim_ID
    elif (row['ensemble'] == "LOCA2") and (row['ssp'] == "historical"):
        sim_ID = f"{row['ensemble']}_{row['model']}_{row['member']}_{row['ssp']}"
        sim_path = main_path + sim_ID
    check_spool_out = subprocess.run(
            ["tail", "-n", "5", f"{sim_path}/spool_WBM.out"],
            capture_output=True,
            text=True,
        ).stdout.split("\n")
    if len(check_spool_out) > 5:
        check_spool_out = check_spool_out[-4]
    if check_spool_out == "All Done!":
        subprocess.run(["touch", f"{sim_path}/spool_done.out"])
            
    if (row['ensemble'] == "LOCA2") and (row['ssp'] != "historical"):
        for time_id in ["early", "mid", "late"]:
            sim_ID = f"{row['ensemble']}_{row['model']}_{row['member']}_{row['ssp']}_{time_id}"
            sim_path = main_path + sim_ID
            
            check_spool_out = subprocess.run(
                ["tail", "-n", "5", f"{sim_path}/spool_WBM.out"],
                capture_output=True, text=True).stdout.split("\n")
            if len(check_spool_out) > 5:
                check_spool_out = check_spool_out[-4]
            if check_spool_out == "All Done!":
                subprocess.run(["touch", f"{sim_path}/spool_done.out"])

# %%
for _, row in df_climate_drivers.iterrows():
    if row['ensemble'] == "OakRidge":
        sim_ID = f"{row['ensemble']}_{row['model']}_{row['member']}_{row['method']}_{row['ssp']}"
        sim_path = main_path + sim_ID
    elif row['ensemble'] == "NEX-GDDP":
        sim_ID = f"{row['ensemble']}_{row['model']}_{row['member']}_{row['ssp']}"
        sim_path = main_path + sim_ID
    elif (row['ensemble'] == "LOCA2") and (row['ssp'] == "historical"):
        sim_ID = f"{row['ensemble']}_{row['model']}_{row['member']}_{row['ssp']}"
        sim_path = main_path + sim_ID
    check_job_out = subprocess.run(
                ["tail", "-n", "100", f"{sim_path}/run_WBM.out"],
                capture_output=True, text=True,
            ).stdout.split("\n")
    if len(check_job_out) < 100:
        pass
    else:
        check_message = "* INFO: WBM model runs completed with exit code"
        check_job_out = [line for line in check_job_out if check_message in line]
        if len(check_job_out) > 0 and check_job_out[0][-1] == "0":
                    # print(sim_ID)
                    subprocess.run(["touch", f"{sim_path}/run_done.out"])
                    
    if (row['ensemble'] == "LOCA2") and (row['ssp'] != "historical"):
        for time_id in ["early", "mid", "late"]:
            sim_ID = f"{row['ensemble']}_{row['model']}_{row['member']}_{row['ssp']}_{time_id}"
            sim_path = main_path + sim_ID
            
            check_job_out = subprocess.run(
                ["tail", "-n", "100", f"{sim_path}/run_WBM.out"],
                capture_output=True, text=True,
            ).stdout.split("\n")
            if len(check_job_out) < 50:
                pass
            else:
                check_message = "* INFO: WBM model runs completed with exit code"
                check_job_out = [line for line in check_job_out if check_message in line]
                if len(check_job_out) > 0 and check_job_out[0][-1] == "0":
                    # print(sim_ID)
                    subprocess.run(["touch", f"{sim_path}/run_done.out"])

# %%
######################
# Common to all runs #
######################

# Main directory
main_path = "/gpfs/group/kaf26/default/dcl5300/wbm_soilM_crop_uc_lafferty-etal-2024-tbd_DATA/wbm/"

# Output variables
output_vars=["soilMoist", "soilMoistFrac"]

# PET method
pet_method = "Hamon"

# Rooting depth
rootingDepth = "Effective_Rooting_Depth_mod.init"

# Available water capacity
# soilAWC = "/gpfs/group/kaf26/default/private/WBM_data/squam.sr.unh.edu/US_CDL_v3_data/soil/SSURGO_SoilData_awc_frac_mm_m_CONUS_1km.tif"
soilAWC = "SSURGO_HARMON_AWC_05min_NAM_US.init"

# Canopy height
canopyHt = "/gpfs/group/kaf26/default/private/WBM_data/squam.sr.unh.edu/US_CDL_v3_data/canopy/Simard_Pinto_3DGlobalVeg_JGR_10km.tif"

# Leaf Area Index
lai = "merra2_lai2_dc.init"

# Lan collapse method
land_collapse="average"

# Project ID
project_ID = "PCHES_crop_yield_UC_climate_param"

# %% [markdown]
# # Historical runs (observational data)

# %%
#######################
# Common to hist runs #
#######################

# Simulation length
run_start="1980-01-01"
run_end="2014-12-31"

# Spinup
spinup_start="1980-01-01"
spinup_end="1980-12-31"
spinup_loops = 5

# Cloud fraction
cloudFr_primary = "merra2_cldtot_d.init"

# Crop parameter file
crop_par = "CDL-US-M_CropParameters_hist.csv"

# Crop area timeseries
crop_area_frac="cdl_cropland_hist.init"

# %%
########
# GMFD #
########
run_WBM(
    run_type="obs",
    main_path=main_path,
    sim_ID="OBS_GMFD_historical",
    model_info={},
    project_ID=project_ID,
    
    
    run_start=run_start,
    run_end=run_end,
    spinup_start=spinup_start,
    spinup_end=spinup_end,
    spinup_loops=spinup_loops,
    output_vars=output_vars,
    pet_method=pet_method,
    airT_primary="GMFD_tas_daily.init",
    airT_secondary="",
    airT_min="",
    airT_max="",
    precip_primary="GMFD_prcp_daily.init",
    precip_secondary="",
    cloudFr_primary=cloudFr_primary,
    windU_primary="",
    windV_primary="",
    humidity_primary="",
    albedo_primary="",
    rootingDepth=rootingDepth,
    soilAWC=soilAWC,
    canopyHt=canopyHt,
    lai=lai,
    land_collapse=land_collapse,
    crop_area_frac=crop_area_frac,
    crop_area_frac_patch="",
    crop_par=crop_par,
    crop_par_patch=""
)
# Out:
# check jobid: 44106071
# spool jobid: 44106096
# run jobid: 44106098

# %%
###########
# Livneh2 #
###########
run_WBM(
    run_type="obs",
    main_path=main_path,
    sim_ID="OBS_Livneh2_historical",
    model_info={},
    project_ID=project_ID,
    
    
    run_start=run_start,
    run_end=run_end,
    spinup_start=spinup_start,
    spinup_end=spinup_end,
    spinup_loops=spinup_loops,
    output_vars=output_vars,
    pet_method=pet_method,
    airT_primary="XXX",
    airT_secondary="XXX",
    airT_min="Livneh2_Tmax_daily.init",
    airT_max="Livneh2_Tmin_daily.init",
    precip_primary="Livneh2_precip_daily.init",
    precip_secondary="",
    cloudFr_primary=cloudFr_primary,
    windU_primary="",
    windV_primary="",
    humidity_primary="",
    albedo_primary="",
    rootingDepth=rootingDepth,
    soilAWC=soilAWC,
    canopyHt=canopyHt,
    lai=lai,
    land_collapse=land_collapse,
    crop_area_frac=crop_area_frac,
    crop_area_frac_patch="",
    crop_par=crop_par,
    crop_par_patch="",
    
)
# Out:
# check jobid: 44106100
# spool jobid: 44106122
# run jobid: 44106123

# %%
###########
# gridMET #
###########
run_WBM(
    run_type="obs",
    main_path=main_path,
    sim_ID="OBS_gridMET_historical",
    model_info={},
    project_ID=project_ID,
    
    
    run_start=run_start,
    run_end=run_end,
    spinup_start=spinup_start,
    spinup_end=spinup_end,
    spinup_loops=spinup_loops,
    output_vars=output_vars,
    pet_method=pet_method,
    airT_primary="XXX",
    airT_secondary="XXX",
    airT_min="gridMET_tmmn_daily.init",
    airT_max="gridMET_tmmx_daily.init",
    precip_primary="gridMET_pr_daily.init",
    precip_secondary="",
    cloudFr_primary=cloudFr_primary,
    windU_primary="",
    windV_primary="",
    humidity_primary="",
    albedo_primary="",
    rootingDepth=rootingDepth,
    soilAWC=soilAWC,
    canopyHt=canopyHt,
    lai=lai,
    land_collapse=land_collapse,
    crop_area_frac=crop_area_frac,
    crop_area_frac_patch="",
    crop_par=crop_par,
    crop_par_patch="",
    
)
# Out:
# check jobid: 44106135
# spool jobid: 44106160
# run jobid: 44106162

# %%
#########
# PRISM #
#########
run_start="1981-01-01" # only PRISM

spinup_start="1981-01-01"
spinup_end="1981-12-31"
spinup_loops = 5

run_WBM(
    run_type="obs",
    main_path=main_path,
    sim_ID="OBS_PRISM_historical",
    model_info={},
    project_ID=project_ID,
    
    
    run_start=run_start,
    run_end=run_end,
    spinup_start=spinup_start,
    spinup_end=spinup_end,
    spinup_loops=spinup_loops,
    output_vars=output_vars,
    pet_method=pet_method,
    airT_primary="PRISM_tmean_4kmD2_d.init",
    airT_secondary="",
    airT_min="",
    airT_max="",
    precip_primary="PRISM_ppt_4kmD2_d.init",
    precip_secondary="",
    cloudFr_primary=cloudFr_primary,
    windU_primary="",
    windV_primary="",
    humidity_primary="",
    albedo_primary="",
    rootingDepth=rootingDepth,
    soilAWC=soilAWC,
    canopyHt=canopyHt,
    lai=lai,
    land_collapse=land_collapse,
    crop_area_frac=crop_area_frac,
    crop_area_frac_patch="",
    crop_par=crop_par,
    crop_par_patch="",
    
)
# Out:
# check jobid: 44106124
# spool jobid: 44106130
# run jobid: 44106132

# %% [markdown]
# # Hindcast runs (climate models)

# %%
#######################
# Common to hindcasts #
#######################

# Simulation length
run_start="1980-01-01"
run_end="2014-12-31"

# Spunup
spinup_start="1980-01-01"
spinup_end="1980-12-31"
spinup_loops = 5

# Cloud fraction
cloudFr_primary = "merra2_cldtot_d.init"

# Crop parameter file
crop_par = "CDL-US-M_CropParameters_hist.csv"

# Crop area timeseries
crop_area_frac="cdl_cropland_hist.init"

# Only used for LOCA projections
state_id = ""

# %% [markdown]
# ### NEX-GDDP

# %%
# Constants
ensemble = "NEX-GDDP"
vars_ = ["tasmin", "tasmax", "pr"]

# Get run infos
run_info = df_climate_drivers[(df_climate_drivers.ensemble == ensemble) & (df_climate_drivers.ssp == "historical")].copy()

# %%
#################
# NEX hindcasts #
#################
for _, info in run_info.iterrows():
    
    print(info['model'])
    sim_ID = f"{info['ensemble']}_{info['model']}_{info['member']}_{info['ssp']}"
    
    run_WBM(
        run_type="model",
        main_path=main_path,
        sim_ID=sim_ID,
        run_info=info,
        project_ID=project_ID,
        run_start=run_start,
        run_end=run_end,
        spinup_start=spinup_start,
        spinup_end=spinup_end,
        spinup_loops=spinup_loops,
        state_id=state_id,
        output_vars=output_vars,
        pet_method=pet_method,
        vars_=vars_,
        airT_primary="XXX",
        airT_secondary="XXX",
        airT_min=f"{sim_ID}_tasmin_daily.init",
        airT_max=f"{sim_ID}_tasmax_daily.init",
        precip_primary=f"{sim_ID}_pr_daily.init",
        precip_secondary="",
        cloudFr_primary=cloudFr_primary,
        windU_primary="",
        windV_primary="",
        humidity_primary="",
        albedo_primary="",
        rootingDepth=rootingDepth,
        soilAWC=soilAWC,
        canopyHt=canopyHt,
        lai=lai,
        land_collapse=land_collapse,
        crop_area_frac=crop_area_frac,
        crop_area_frac_patch="",
        crop_par=crop_par,
        crop_par_patch="",
    )
    
    print('\n')
# Out:
# IPSL-CM6A-LR
# Directory already exists!
# spool jobid: 44245328
# run jobid: 44245329
#
#
# ACCESS-CM2
# Directory already exists!
# spooling already done.
# run already done.
#
#
# GFDL-CM4_gr2
# Directory already exists!
# spool jobid: 44245330
# run jobid: 44245331
#
#
# INM-CM5-0
# Directory already exists!
# spool jobid: 44245332
# run jobid: 44245333
#
#
# KACE-1-0-G
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR
# Directory already exists!
# spool jobid: 44245335
# run jobid: 44245337
#
#
# NorESM2-LM
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5
# Directory already exists!
# spooling already done.
# run already done.
#
#
# UKESM1-0-LL
# Directory already exists!
# spooling already done.
# run already done.
#
#
# GFDL-ESM4
# Directory already exists!
# spool jobid: 44245339
# run jobid: 44245341
#
#
# ACCESS-ESM1-5
# Directory already exists!
# spool jobid: 44245343
# run jobid: 44245344
#
#
# GFDL-CM4
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC-ES2L
# Directory already exists!
# spool jobid: 44245345
# run jobid: 44245346
#
#
# GISS-E2-1-G
# Directory already exists!
# spool jobid: 44245347
# run jobid: 44245348
#
#
# CMCC-ESM2
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg-LR
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM4-8
# Directory already exists!
# spool jobid: 44245350
# run jobid: 44245353
#
#
# KIOST-ESM
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3
# Directory already exists!
# spool jobid: 44245355
# run jobid: 44245357
#
#
# BCC-CSM2-MR
# Directory already exists!
# spool jobid: 44245360
# run jobid: 44245362
#
#
# MPI-ESM1-2-HR
# Directory already exists!
# spooling already done.
# run already done.
#
#
# TaiESM1
# Directory already exists!
# spooling already done.
# run already done.
#
#
# HadGEM3-GC31-LL
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-CM6-1
# Directory already exists!
# spool jobid: 44245364
# run jobid: 44245366
#
#
# FGOALS-g3
# Directory already exists!
# spooling already done.
# run already done.
#
#
# HadGEM3-GC31-MM
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CMCC-CM2-SR5
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-ESM2-1
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-MM
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0
# Directory already exists!
# spooling already done.
# run already done.

# %% [markdown]
# ### LOCA2

# %%
# Constants
ensemble = "LOCA2"
vars_ = ["tasmax","tasmin","pr"]

# Get run infos
run_info = df_climate_drivers[(df_climate_drivers.ensemble == ensemble) & (df_climate_drivers.ssp == "historical")].copy()

# %%
##################
# LOCA2 hindcasts
##################
for _, info in run_info.iterrows():
    
    print(f"{info['model']} {info['member']}")
    sim_ID = f"{ensemble}_{info['model']}_{info['member']}_{info['ssp']}"
    
    run_WBM(
        run_type="model",
        main_path=main_path,
        sim_ID=sim_ID,
        run_info=info,
        project_ID=project_ID,
        run_start=run_start,
        run_end=run_end,
        spinup_start=spinup_start,
        spinup_end=spinup_end,
        spinup_loops=spinup_loops,
        state_id=state_id,
        output_vars=output_vars,
        pet_method=pet_method,
        vars_=vars_,
        airT_primary="XXX",
        airT_secondary="XXX",
        airT_min=f"{sim_ID}_tasmin_daily.init",
        airT_max=f"{sim_ID}_tasmax_daily.init",
        precip_primary=f"{sim_ID}_pr_daily.init",
        precip_secondary="",
        cloudFr_primary=cloudFr_primary,
        windU_primary="",
        windV_primary="",
        humidity_primary="",
        albedo_primary="",
        rootingDepth=rootingDepth,
        soilAWC=soilAWC,
        canopyHt=canopyHt,
        lai=lai,
        land_collapse=land_collapse,
        crop_area_frac=crop_area_frac,
        crop_area_frac_patch="",
        crop_par=crop_par,
        crop_par_patch=""
    )
    
    print('\n')

# %% [markdown]
# ### OakRidge

# %%
# Get NEX historical run infos
run_info = df_climate_drivers[(df_climate_drivers.ensemble == "OakRidge") & (df_climate_drivers.ssp == "historical")].copy()

# Constants
ensemble = "OakRidge"
vars_ = ["tmax","tmin","prcp"]

# %%
#####################
# OakRidge hindcasts
#####################
for _, info in run_info.iterrows():
        
    print(f"{info['model']} {info['method']}")
    sim_ID = f"{ensemble}_{info['model']}_{info['member']}_{info['method']}_{info['ssp']}"
        
    run_WBM(
        run_type="model",
        main_path=main_path,
        sim_ID=sim_ID,
        run_info=info,
        project_ID=project_ID,
        run_start=run_start,
        run_end=run_end,
        spinup_start=spinup_start,
        spinup_end=spinup_end,
        spinup_loops=spinup_loops,
        state_id=state_id,
        output_vars=output_vars,
        pet_method=pet_method,
        vars_=vars_,
        airT_primary="XXX",
        airT_secondary="XXX",
        airT_min=f"{sim_ID}_tmin_daily.init",
        airT_max=f"{sim_ID}_tmax_daily.init",
        precip_primary=f"{sim_ID}_prcp_daily.init",
        precip_secondary="",
        cloudFr_primary=cloudFr_primary,
        windU_primary="",
        windV_primary="",
        humidity_primary="",
        albedo_primary="",
        rootingDepth=rootingDepth,
        soilAWC=soilAWC,
        canopyHt=canopyHt,
        lai=lai,
        land_collapse=land_collapse,
        crop_area_frac=crop_area_frac,
        crop_area_frac_patch="",
        crop_par=crop_par,
        crop_par_patch="",
    )
    print('\n')
# Out:
# ACCESS-CM2 DBCCA_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# BCC-CSM2-MR DBCCA_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-ESM2-1 DBCCA_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR DBCCA_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 DBCCA_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-MM DBCCA_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 RegCM_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# BCC-CSM2-MR RegCM_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-ESM2-1 RegCM_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR RegCM_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 RegCM_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-MM RegCM_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 DBCCA_Livneh
# Directory already exists!
# spooling already done.
# run already done.
#
#
# BCC-CSM2-MR DBCCA_Livneh
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-ESM2-1 DBCCA_Livneh
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR DBCCA_Livneh
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 DBCCA_Livneh
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-MM DBCCA_Livneh
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 RegCM_Livneh
# Directory already exists!
# spooling already done.
# run already done.
#
#
# BCC-CSM2-MR RegCM_Livneh
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-ESM2-1 RegCM_Livneh
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR RegCM_Livneh
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 RegCM_Livneh
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-MM RegCM_Livneh
# Directory already exists!
# spooling already done.
# run already done.

# %% [markdown]
# # Projections

# %% [markdown]
# ### NEX-GDDP

# %%
# Constants
ensemble = "NEX-GDDP"
vars_ = ["tasmin", "tasmax", "pr"]

# Get run infos
run_info = df_climate_drivers[(df_climate_drivers.ensemble == ensemble) & (df_climate_drivers.ssp != "historical")].copy()

# %%
# Simulation length
run_start="2015-01-01"
run_end="2099-12-31"

# Spin up
spinup_start="2015-01-01"
spinup_end="2015-12-31"
spinup_loops = 5

# Cloud fraction
cloudFr_primary = "merra2_cldtot_dc.init"

# Crop parameter file
crop_par = "CDL-US-M_CropParameters_proj.csv"

# Crop area timeseries
crop_area_frac="cdl_cropland_proj.init"

# Only used for LOCA2 projections
state_id = ""

# %%
##################
# NEX projections
##################
for _, info in run_info.iterrows():
    
    print(f"{info['model']} {info['ssp']}")
    sim_ID = f"{info['ensemble']}_{info['model']}_{info['member']}_{info['ssp']}"
    
    if info['model'] in ["HadGEM3-GC31-LL","HadGEM3-GC31-MM","KACE-1-0-G","UKESM1-0-LL"]:
    
        run_WBM(
        run_type="model",
        main_path=main_path,
        sim_ID=sim_ID,
        run_info=info,
        project_ID=project_ID,
        run_start=run_start,
        run_end=run_end,
        spinup_start=spinup_start,
        spinup_end=spinup_end,
        spinup_loops=spinup_loops,
        state_id=state_id,
        output_vars=output_vars,
        pet_method=pet_method,
        vars_=vars_,
        airT_primary="XXX",
        airT_secondary="XXX",
        airT_min=f"{sim_ID}_tasmin_daily.init",
        airT_max=f"{sim_ID}_tasmax_daily.init",
        precip_primary=f"{sim_ID}_pr_daily.init",
        precip_secondary="",
        cloudFr_primary=cloudFr_primary,
        windU_primary="",
        windV_primary="",
        humidity_primary="",
        albedo_primary="",
        rootingDepth=rootingDepth,
        soilAWC=soilAWC,
        canopyHt=canopyHt,
        lai=lai,
        land_collapse=land_collapse,
        crop_area_frac=crop_area_frac,
        crop_area_frac_patch="",
        crop_par=crop_par,
        crop_par_patch="",
        )
    
        print('\n')
# Out:
# IPSL-CM6A-LR ssp245
# IPSL-CM6A-LR ssp585
# IPSL-CM6A-LR ssp370
# IPSL-CM6A-LR ssp126
# ACCESS-CM2 ssp245
# ACCESS-CM2 ssp585
# ACCESS-CM2 ssp370
# ACCESS-CM2 ssp126
# GFDL-CM4_gr2 ssp245
# GFDL-CM4_gr2 ssp585
# INM-CM5-0 ssp245
# INM-CM5-0 ssp585
# INM-CM5-0 ssp370
# INM-CM5-0 ssp126
# NESM3 ssp245
# NESM3 ssp585
# NESM3 ssp126
# KACE-1-0-G ssp245
# Directory already exists!
# spooling already done.
# run jobid: 44245636
#
#
# KACE-1-0-G ssp585
# Directory already exists!
# spooling already done.
# run jobid: 44245637
#
#
# KACE-1-0-G ssp370
# Directory already exists!
# spooling already done.
# run jobid: 44245638
#
#
# KACE-1-0-G ssp126
# Directory already exists!
# spooling already done.
# run jobid: 44245639
#
#
# MPI-ESM1-2-LR ssp245
# MPI-ESM1-2-LR ssp585
# MPI-ESM1-2-LR ssp370
# MPI-ESM1-2-LR ssp126
# NorESM2-LM ssp245
# NorESM2-LM ssp585
# NorESM2-LM ssp370
# NorESM2-LM ssp126
# CanESM5 ssp245
# CanESM5 ssp585
# CanESM5 ssp370
# CanESM5 ssp126
# UKESM1-0-LL ssp245
# Directory already exists!
# spooling already done.
# run jobid: 44245640
#
#
# UKESM1-0-LL ssp585
# Directory already exists!
# spooling already done.
# run jobid: 44245641
#
#
# UKESM1-0-LL ssp370
# Directory already exists!
# spooling already done.
# run jobid: 44245642
#
#
# UKESM1-0-LL ssp126
# Directory already exists!
# spooling already done.
# run jobid: 44245644
#
#
# GFDL-ESM4 ssp245
# GFDL-ESM4 ssp585
# GFDL-ESM4 ssp370
# GFDL-ESM4 ssp126
# ACCESS-ESM1-5 ssp245
# ACCESS-ESM1-5 ssp585
# ACCESS-ESM1-5 ssp370
# ACCESS-ESM1-5 ssp126
# GFDL-CM4 ssp245
# GFDL-CM4 ssp585
# MIROC-ES2L ssp245
# MIROC-ES2L ssp585
# MIROC-ES2L ssp370
# MIROC-ES2L ssp126
# GISS-E2-1-G ssp245
# GISS-E2-1-G ssp585
# GISS-E2-1-G ssp370
# GISS-E2-1-G ssp126
# CMCC-ESM2 ssp245
# CMCC-ESM2 ssp585
# CMCC-ESM2 ssp370
# CMCC-ESM2 ssp126
# EC-Earth3-Veg-LR ssp245
# EC-Earth3-Veg-LR ssp585
# EC-Earth3-Veg-LR ssp370
# EC-Earth3-Veg-LR ssp126
# INM-CM4-8 ssp245
# INM-CM4-8 ssp585
# INM-CM4-8 ssp370
# INM-CM4-8 ssp126
# KIOST-ESM ssp245
# KIOST-ESM ssp585
# KIOST-ESM ssp126
# EC-Earth3 ssp245
# EC-Earth3 ssp585
# EC-Earth3 ssp370
# EC-Earth3 ssp126
# BCC-CSM2-MR ssp245
# BCC-CSM2-MR ssp585
# BCC-CSM2-MR ssp370
# BCC-CSM2-MR ssp126
# MPI-ESM1-2-HR ssp245
# MPI-ESM1-2-HR ssp585
# MPI-ESM1-2-HR ssp370
# MPI-ESM1-2-HR ssp126
# TaiESM1 ssp245
# TaiESM1 ssp585
# TaiESM1 ssp370
# TaiESM1 ssp126
# HadGEM3-GC31-LL ssp245
# Directory already exists!
# spool jobid: 44245645
# run jobid: 44245646
#
#
# HadGEM3-GC31-LL ssp585
# Directory already exists!
# spool jobid: 44245647
# run jobid: 44245648
#
#
# HadGEM3-GC31-LL ssp126
# Directory already exists!
# spool jobid: 44245649
# run jobid: 44245650
#
#
# CNRM-CM6-1 ssp245
# CNRM-CM6-1 ssp585
# CNRM-CM6-1 ssp370
# CNRM-CM6-1 ssp126
# FGOALS-g3 ssp245
# FGOALS-g3 ssp585
# FGOALS-g3 ssp370
# FGOALS-g3 ssp126
# HadGEM3-GC31-MM ssp585
# Directory already exists!
# spool jobid: 44245651
# run jobid: 44245652
#
#
# HadGEM3-GC31-MM ssp126
# Directory already exists!
# spool jobid: 44245653
# run jobid: 44245654
#
#
# CMCC-CM2-SR5 ssp245
# CMCC-CM2-SR5 ssp585
# CMCC-CM2-SR5 ssp370
# CMCC-CM2-SR5 ssp126
# MIROC6 ssp245
# MIROC6 ssp585
# MIROC6 ssp370
# MIROC6 ssp126
# CNRM-ESM2-1 ssp245
# CNRM-ESM2-1 ssp585
# CNRM-ESM2-1 ssp370
# CNRM-ESM2-1 ssp126
# NorESM2-MM ssp245
# NorESM2-MM ssp585
# NorESM2-MM ssp370
# NorESM2-MM ssp126
# MRI-ESM2-0 ssp245
# MRI-ESM2-0 ssp585
# MRI-ESM2-0 ssp370
# MRI-ESM2-0 ssp126

# %% [markdown]
# ### LOCA

# %%
# Constants
ensemble = "LOCA2"
vars_ = ["tasmax","tasmin","pr"]

# Get run infos
run_info = df_climate_drivers[(df_climate_drivers.ensemble == ensemble) & (df_climate_drivers.ssp != "historical")].copy()

# %%
### Constant for all runs
# Simulation length
run_starts = ["2015-01-01", "2045-01-01", "2075-01-01"]
run_ends = ["2044-12-31", "2074-12-31", "2100-12-31"]
run_IDs = ["early", "mid", "late"]

# Cloud fraction
cloudFr_primary = "merra2_cldtot_dc.init"

# Crop parameter file
crop_par = "CDL-US-M_CropParameters_proj.csv"

# Crop area timeseries
crop_area_frac="cdl_cropland_proj.init"

# %%
############################
# LOCA projections: EARLY
############################
# Spin up
spinup_start="2015-01-01"
spinup_end="2015-12-31"
spinup_loops = 5
state_id = ""

# Early
time_id = 0

for _, info in run_info.iterrows():
    
    print(f"{info['model']} {info['member']} {info['ssp']}")
    sim_ID = f"{info['ensemble']}_{info['model']}_{info['member']}_{info['ssp']}_{run_IDs[time_id]}"

    run_WBM(
        run_type="model",
        main_path=main_path,
        sim_ID=sim_ID,
        run_info=info,
        project_ID=project_ID,
        run_start=run_starts[time_id],
        run_end=run_ends[time_id],
        spinup_start=spinup_start,
        spinup_end=spinup_end,
        spinup_loops=spinup_loops,
        state_id = state_id,
        output_vars=output_vars,
        pet_method=pet_method,
        vars_=vars_,
        airT_primary="XXX",
        airT_secondary="XXX",
        airT_min=f"{sim_ID}_tasmin_daily.init",
        airT_max=f"{sim_ID}_tasmax_daily.init",
        precip_primary=f"{sim_ID}_pr_daily.init",
        precip_secondary="",
        cloudFr_primary=cloudFr_primary,
        windU_primary="",
        windV_primary="",
        humidity_primary="",
        albedo_primary="",
        rootingDepth=rootingDepth,
        soilAWC=soilAWC,
        canopyHt=canopyHt,
        lai=lai,
        land_collapse=land_collapse,
        crop_area_frac=crop_area_frac,
        crop_area_frac_patch="",
        crop_par=crop_par,
        crop_par_patch=""
    )
    print('\n')
# Out:
# AWI-CM-1-1-MR r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# AWI-CM-1-1-MR r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# AWI-CM-1-1-MR r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# AWI-CM-1-1-MR r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# AWI-CM-1-1-MR r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# AWI-CM-1-1-MR r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# AWI-CM-1-1-MR r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r5i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r4i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r4i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r9i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r8i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r10i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r7i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r6i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r1i1p1f1 ssp585
# Directory already exists!
# check jobid: 44238055
# Something went wrong!
#
#
# ACCESS-CM2 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM5-0 r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM5-0 r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM5-0 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM5-0 r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM5-0 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM5-0 r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM5-0 r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# KACE-1-0-G r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# KACE-1-0-G r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# KACE-1-0-G r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# KACE-1-0-G r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# KACE-1-0-G r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# KACE-1-0-G r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# KACE-1-0-G r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# KACE-1-0-G r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# KACE-1-0-G r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r5i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r5i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r4i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r4i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r8i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r8i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r8i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r10i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r10i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r10i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r7i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r7i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r7i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r6i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r6i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-LM r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-LM r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-LM r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-LM r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-LM r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r5i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r5i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r4i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r4i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r7i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r7i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r7i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r6i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r6i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r6i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-CM6-1-HR r1i1p1f2 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# GFDL-ESM4 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# GFDL-ESM4 r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# GFDL-ESM4 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r9i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r8i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r10i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r7i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r6i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r5i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r5i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r4i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r4i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# GFDL-CM4 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# GFDL-CM4 r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM4-8 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM4-8 r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM4-8 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3 r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3 r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3 r4i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3 r4i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3 r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3 r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# BCC-CSM2-MR r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# BCC-CSM2-MR r1i1p1f1 ssp585
# Directory already exists!
# check jobid: 44238057
# Something went wrong!
#
#
# BCC-CSM2-MR r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r1i1p1f1 ssp585
# Directory already exists!
# check jobid: 44238058
# Something went wrong!
#
#
# MPI-ESM1-2-HR r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r9i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r8i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r10i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r7i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r6i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# TaiESM1 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# TaiESM1 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# HadGEM3-GC31-LL r2i1p1f3 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# HadGEM3-GC31-LL r1i1p1f3 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# HadGEM3-GC31-LL r1i1p1f3 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# HadGEM3-GC31-LL r3i1p1f3 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r5i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r4i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r4i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-CM6-1 r1i1p1f2 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-CM6-1 r1i1p1f2 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-CM6-1 r1i1p1f2 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# FGOALS-g3 r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# FGOALS-g3 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# FGOALS-g3 r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# FGOALS-g3 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# FGOALS-g3 r4i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# FGOALS-g3 r4i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# FGOALS-g3 r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# FGOALS-g3 r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# FGOALS-g3 r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# FGOALS-g3 r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# HadGEM3-GC31-MM r2i1p1f3 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# HadGEM3-GC31-MM r1i1p1f3 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r5i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r4i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-ESM2-1 r1i1p1f2 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-ESM2-1 r1i1p1f2 ssp585
# Directory already exists!
# check jobid: 44238059
# Something went wrong!
#
#
# CNRM-ESM2-1 r1i1p1f2 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-MM r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-MM r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run jobid: 44238060
#
#
# NorESM2-MM r1i1p1f1 ssp585
# Directory already exists!
# check jobid: 44238061
# Something went wrong!
#
#
# NorESM2-MM r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run jobid: 44238062
#
#
# MRI-ESM2-0 r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 r1i1p1f1 ssp585
# Directory already exists!
# check jobid: 44238063
# Something went wrong!
#
#
# MRI-ESM2-0 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.

# %%
############################
# LOCA projections: MID
############################
# Spin up
spinup_start = ""
spinup_end = ""
spinup_loops = ""
state_id = ""

# Mid
time_id = 1

for _, info in run_info.iterrows():
    
    print(f"{info['model']} {info['member']} {info['ssp']}")
    sim_ID = f"{info['ensemble']}_{info['model']}_{info['member']}_{info['ssp']}_{run_IDs[time_id]}"

    run_WBM(
        run_type="model",
        main_path=main_path,
        sim_ID=sim_ID,
        run_info=info,
        project_ID=project_ID,
        run_start=run_starts[time_id],
        run_end=run_ends[time_id],
        spinup_start=spinup_start,
        spinup_end=spinup_end,
        spinup_loops=spinup_loops,
        state_id=f"{info['ensemble']}_{info['model']}_{info['member']}_{info['ssp']}_{run_IDs[time_id-1]}",
        output_vars=output_vars,
        pet_method=pet_method,
        vars_=vars_,
        airT_primary="XXX",
        airT_secondary="XXX",
        airT_min=f"{sim_ID}_tasmin_daily.init",
        airT_max=f"{sim_ID}_tasmax_daily.init",
        precip_primary=f"{sim_ID}_pr_daily.init",
        precip_secondary="",
        cloudFr_primary=cloudFr_primary,
        windU_primary="",
        windV_primary="",
        humidity_primary="",
        albedo_primary="",
        rootingDepth=rootingDepth,
        soilAWC=soilAWC,
        canopyHt=canopyHt,
        lai=lai,
        land_collapse=land_collapse,
        crop_area_frac=crop_area_frac,
        crop_area_frac_patch="",
        crop_par=crop_par,
        crop_par_patch=""
    )
    print('\n')
# Out:
# AWI-CM-1-1-MR r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# AWI-CM-1-1-MR r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# AWI-CM-1-1-MR r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# AWI-CM-1-1-MR r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# AWI-CM-1-1-MR r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# AWI-CM-1-1-MR r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# AWI-CM-1-1-MR r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r5i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r4i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r4i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r9i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r8i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r10i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r7i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r6i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r1i1p1f1 ssp585
# Directory already exists!
# check jobid: 44245371
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM5-0 r2i1p1f1 ssp370
# Directory already exists!
# spool jobid: 44245373
# run jobid: 44245375
#
#
# INM-CM5-0 r5i1p1f1 ssp370
# Directory already exists!
# spool jobid: 44245378
# run jobid: 44245380
#
#
# INM-CM5-0 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM5-0 r1i1p1f1 ssp585
# Directory already exists!
# spool jobid: 44245382
# run jobid: 44245384
#
#
# INM-CM5-0 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM5-0 r4i1p1f1 ssp370
# Directory already exists!
# spool jobid: 44245386
# run jobid: 44245388
#
#
# INM-CM5-0 r3i1p1f1 ssp370
# Directory already exists!
# spool jobid: 44245390
# run jobid: 44245392
#
#
# KACE-1-0-G r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# KACE-1-0-G r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# KACE-1-0-G r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# KACE-1-0-G r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# KACE-1-0-G r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# KACE-1-0-G r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# KACE-1-0-G r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# KACE-1-0-G r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# KACE-1-0-G r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r5i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r4i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r8i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r8i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r10i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r10i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r7i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r7i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r6i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-LM r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-LM r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-LM r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-LM r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-LM r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r5i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r5i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r4i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r4i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r7i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r7i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r7i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r6i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r6i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r6i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-CM6-1-HR r1i1p1f2 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# GFDL-ESM4 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# GFDL-ESM4 r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# GFDL-ESM4 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r9i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r8i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r10i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r7i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r6i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r5i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r5i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r4i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r4i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# GFDL-CM4 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# GFDL-CM4 r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM4-8 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM4-8 r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM4-8 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3 r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3 r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3 r4i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3 r4i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3 r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3 r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# BCC-CSM2-MR r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# BCC-CSM2-MR r1i1p1f1 ssp585
# Directory already exists!
# check jobid: 44245396
# spooling already done.
# run already done.
#
#
# BCC-CSM2-MR r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r1i1p1f1 ssp585
# Directory already exists!
# check jobid: 44245399
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r9i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r8i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r10i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r7i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r6i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# TaiESM1 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# TaiESM1 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# HadGEM3-GC31-LL r2i1p1f3 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# HadGEM3-GC31-LL r1i1p1f3 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# HadGEM3-GC31-LL r1i1p1f3 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# HadGEM3-GC31-LL r3i1p1f3 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r5i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r4i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r4i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-CM6-1 r1i1p1f2 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-CM6-1 r1i1p1f2 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-CM6-1 r1i1p1f2 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# FGOALS-g3 r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# FGOALS-g3 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# FGOALS-g3 r1i1p1f1 ssp585
# Directory already exists!
# spool jobid: 44245401
# run jobid: 44245403
#
#
# FGOALS-g3 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# FGOALS-g3 r4i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# FGOALS-g3 r4i1p1f1 ssp585
# Directory already exists!
# spool jobid: 44245405
# run jobid: 44245407
#
#
# FGOALS-g3 r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# FGOALS-g3 r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# FGOALS-g3 r3i1p1f1 ssp585
# Directory already exists!
# spool jobid: 44245409
# run jobid: 44245411
#
#
# FGOALS-g3 r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# HadGEM3-GC31-MM r2i1p1f3 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# HadGEM3-GC31-MM r1i1p1f3 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r5i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r4i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-ESM2-1 r1i1p1f2 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-ESM2-1 r1i1p1f2 ssp585
# Directory already exists!
# check jobid: 44245413
# spooling already done.
# run already done.
#
#
# CNRM-ESM2-1 r1i1p1f2 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-MM r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-MM r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-MM r1i1p1f1 ssp585
# Directory already exists!
# check jobid: 44245415
# spooling already done.
# run already done.
#
#
# NorESM2-MM r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 r1i1p1f1 ssp585
# Directory already exists!
# check jobid: 44245416
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.

# %%
############################
# LOCA projections: LATE
############################
# Spin up
spinup_start=""
spinup_end=""
spinup_loops = ""
state_id = ""

# Late
time_id = 2

for model_info in model_infos:
    print(model_info['model'])

    sim_ID = f"{ensemble}_{model_info['model']}_{model_info['member']}_{ssp}_{run_IDs[time_id]}"

    run_WBM(
        run_type="model",
        main_path=main_path,
        sim_ID=sim_ID,
        model_info=model_info,
        project_ID=project_ID,
        
        
        run_start=run_starts[time_id],
        run_end=run_ends[time_id],
        spinup_start=spinup_start,
        spinup_end=spinup_end,
        spinup_loops=spinup_loops,
        state_id = f"{ensemble}_{model_info['model']}_{model_info['member']}_{ssp}_{run_IDs[time_id-1]}",
        output_vars=output_vars,
        pet_method=pet_method,
        airT_primary="XXX",
        airT_secondary="XXX",
        airT_min=f"{sim_ID}_tasmin_daily.init",
        airT_max=f"{sim_ID}_tasmax_daily.init",
        precip_primary=f"{sim_ID}_pr_daily.init",
        precip_secondary="",
        cloudFr_primary=cloudFr_primary,
        windU_primary="",
        windV_primary="",
        humidity_primary="",
        albedo_primary="",
        rootingDepth=rootingDepth,
        soilAWC=soilAWC,
        canopyHt=canopyHt,
        lai=lai,
        land_collapse=land_collapse,
        crop_area_frac=crop_area_frac,
        crop_area_frac_patch="",
        crop_par=crop_par,
        crop_par_patch=""
    )
    print('\n')
# Out:
# ACCESS-CM2
# check jobid: 44162124
# spool jobid: 44162125
# run jobid: 44162127
#
#
# BCC-CSM2-MR
# check jobid: 44162129
# spool jobid: 44162139
# run jobid: 44162141
#
#
# CNRM-ESM2-1
# check jobid: 44162143
# spool jobid: 44162167
# run jobid: 44162169
#
#
# MPI-ESM1-2-HR
# check jobid: 44162172
# spool jobid: 44162198
# run jobid: 44162200
#
#
# MRI-ESM2-0
# check jobid: 44162202
# spool jobid: 44162236
# run jobid: 44162238
#
#
# NorESM2-MM
# check jobid: 44162240
# spool jobid: 44162254
# run jobid: 44162256

# %% [markdown]
# ### OakRidge

# %%
# Get run infos
run_info = df_climate_drivers[(df_climate_drivers.ensemble == "OakRidge") & (df_climate_drivers.ssp == "ssp585")].copy()

# Constants
ensemble = "OakRidge"
vars_ = ["tmax","tmin","prcp"]

# %%
#####################
# OakRidge hindcasts
#####################
for _, info in run_info.iterrows():
        
    print(f"{model} {method}")
    sim_ID = f"{info['ensemble']}_{info['model']}_{info['member']}_{info['method']}_{info['ssp']}"
        
    run_WBM(
        run_type="model",
        main_path=main_path,
        sim_ID=sim_ID,
        run_info=info,
        project_ID=project_ID,
        run_start=run_start,
        run_end=run_end,
        spinup_start=spinup_start,
        spinup_end=spinup_end,
        spinup_loops=spinup_loops,
        state_id=state_id,
        output_vars=output_vars,
        pet_method=pet_method,
        vars_=vars_,
        airT_primary="XXX",
        airT_secondary="XXX",
        airT_min=f"{sim_ID}_tmin_daily.init",
        airT_max=f"{sim_ID}_tmax_daily.init",
        precip_primary=f"{sim_ID}_prcp_daily.init",
        precip_secondary="",
        cloudFr_primary=cloudFr_primary,
        windU_primary="",
        windV_primary="",
        humidity_primary="",
        albedo_primary="",
        rootingDepth=rootingDepth,
        soilAWC=soilAWC,
        canopyHt=canopyHt,
        lai=lai,
        land_collapse=land_collapse,
        crop_area_frac=crop_area_frac,
        crop_area_frac_patch="",
        crop_par=crop_par,
        crop_par_patch="",
    )
    print('\n')
